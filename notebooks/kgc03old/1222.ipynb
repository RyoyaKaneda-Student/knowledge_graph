# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
# ========== python ==========
import os
from logging import Logger
from pathlib import Path
import gc
# noinspection PyUnresolvedReferences
from typing import List, Dict, Tuple, Optional, Union, Callable, Final, Literal, get_args
import torch
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
PROJECT_DIR = Path().resolve().parents[0]
os.chdir(PROJECT_DIR)
SEED: Final = 42

# %%
from utils.setup import load_param, easy_logger, get_device
from utils.torch import load_model, torch_fix_seed
from torch.utils.tensorboard.writer import SummaryWriter
from ignite.handlers import Checkpoint
from run_for_KGC import main_function
logger = easy_logger('log/test.log')

# %%
args = load_param('saved_models/1229/01/param.pkl')
device = get_device(device_name='cpu', logger=logger)
# args.pre_train = True
args.logger = logger
args.device = device
args.batch_size = 1
args.no_use_pe = False
args.max_len=512
args.tensorboard_dir=None
args.only_load_trainer_evaluator=True
args.pre_train=False
args.use_for_challenge090 = False
del args.optuna_file, args.device_name, args.pid
del args.study_name, args.n_trials
logger.info(args)
# Out:
# 2022-12-30 21:19:47 - INFO - 991045332.py - 15 - Namespace(notebook=False, train_anyway=False, logfile='saved_models/1229/01/log.log', param_file='saved_models/1229/01/param.pkl', tensorboard_dir=None, checkpoint_dir='saved_models/1229/01/checkpoint/', model_path='saved_models/1229/01/model.pth', model_version='03', resume_from_checkpoint=False, resume_from_last_point=False, only_load_trainer_evaluator=True, resume_checkpoint_path=None, console_level='info', pre_train=False, train_valid_test=True, only_train=False, use_for_challenge100=False, use_for_challenge075=False, use_title=None, do_optuna=False, story_special_num=5, relation_special_num=5, entity_special_num=5, padding_token_e=0, cls_token_e=1, mask_token_e=2, sep_token_e=3, bos_token_e=4, padding_token_r=0, cls_token_r=1, mask_token_r=2, sep_token_r=3, bos_token_r=4, padding_token_s=0, cls_token_s=1, mask_token_s=2, sep_token_s=3, bos_token_s=4, embedding_dim=128, entity_embedding_dim=128, relation_embedding_dim=64, separate_head_and_tail=False, batch_size=1, max_len=512, mask_percent=0.15, mask_mask_percent=0.8, mask_random_percent=0.1, mask_nomask_percent=0.1, no_use_pe=False, epoch=5000, lr=5e-05, lr_story=0.0001, lr_relation=1e-06, lr_entity=1e-06, valid_interval=50, loss_weight_story=1.0, loss_weight_relation=1.0, loss_weight_entity=1.0, nhead=4, num_layers=4, dim_feedforward=1028, transformer_drop=0.1, position_encoder_drop=0.1, project_dir=PosixPath('/var/www'), logger=<Logger log (DEBUG)>, device=device(type='cpu'), use_for_challenge090=False)

# %%
torch_fix_seed(seed=SEED)
model, data_dict = main_function(args, logger=logger)
encoder_last_layer = model.transformer.layers[-1]
model.eval()
dataset_train, dataset_valid, dataset_test = data_dict['datasets']
triple = dataset_train.triple
data_helper = data_dict['data_helper']
evaluator = data_dict['train_items']['evaluator']
load_model(model, args.model_path, device)
print(len(data_helper.processed_train_triple), len(triple))

# %%
entities = data_helper.processed_entities
d_e = {e: i for i, e in enumerate(entities)}
relations = data_helper.processed_relations
d_r = {r: i for i, r in enumerate(relations)}
triple_df = pd.DataFrame([(entities[_t[0]], relations[_t[1]], entities[_t[2]]) for _t in triple], columns=['head', 'relation', 'tail']) 
# story_entities = triple_df
# triple_df

# %%
def extract(model, target, inputs):
    feature = None

    def forward_hook(module, inputs, _):
        # 順伝搬の出力を features というグローバル変数に記録する
        global features
        # 1. detach でグラフから切り離す。
        # 2. clone() でテンソルを複製する。モデルのレイヤーで ReLU(inplace=True) のように
        #    inplace で行う層があると、値がその後のレイヤーで書き換えられてまい、
        #    指定した層の出力が取得できない可能性があるため、clone() が必要。
        x, _, _ = inputs
        outputs = module.forward(x, x, x, need_weights=True)[1]
        features = outputs.detach().clone()

    # コールバック関数を登録する。
    handle = target.register_forward_hook(forward_hook)

    # 推論する
    model.eval()
    model(inputs, torch.LongTensor([[]]), torch.LongTensor([[]]), torch.LongTensor([[]]))

    # コールバック関数を解除する。
    handle.remove()

    return features

# %%
def heatmap_(index):
    input_ = dataset[index]
    # display([(i, entities[h], relations[r], entities[t]) for i, (h, r, t) in enumerate(input_)])
    features = extract(model, encoder_last_layer.self_attn, dataset[0][None, :])[0]
    df_atten = pd.DataFrame([[entities[h], relations[r], entities[t]]+[features[j, i].item() for j in range(len(features))] for i, (h, r, t) in enumerate(input_)])
    df_atten.columns=['head', 'relation', 'tail',] + [f'atten_from{i}' for i in range(len(df_atten.columns)-3)]
    display(df_atten)
    # ヒートマップの作成
    # sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
    for i in range(len(df_atten)):
        display(i, df_atten.iloc[i,:3].tolist())
        display(df_atten.sort_values(f'atten_from{i}', ascending=False).iloc[:10,:3])
        print("----------")
    plt.show()
# heatmap_(300)

# %%
def make_heatmap2_(input_):
    assert len(input_) == 1
    features = extract(model, encoder_last_layer.self_attn, input_)[0]
    df_atten = pd.DataFrame([[entities[h], relations[r], entities[t]]+[features[j, i].item() for j in range(len(features))] for i, (h, r, t) in enumerate(input_[0])])
    df_atten.columns=['head', 'relation', 'tail',] + [f'atten_from{i}' for i in range(len(df_atten.columns)-3)]
    return df_atten

# %%
story_entities = triple_df['head'].tolist()
print(len(story_entities))
# Out:
# 14546

# %%
def make_ranking(_from, _to, _predicate, _whom, _subject, _why, _what, _where):
    if not (_from is None and _to is None):
        _start_index = story_entities.index(_from)-1 
        _end_index = len(story_entities) - story_entities[::-1].index(_to)
    else: 
        _start_index = 0
        _end_index = 0
    question_ = torch.tensor(
        [
            [d_e['<bos_e>'],d_r['<bos_r>'],d_e['<bos_e>']],
            [d_e['<mask_e>'],d_r['kgc:hasPredicate'],d_e[_predicate]],
            [d_e['<mask_e>'],d_r['kgc:whom'],d_e[_whom]],
            [d_e['<mask_e>'],d_r['kgc:subject'],d_e[_subject]],
            [d_e['<mask_e>'],d_r['kgc:why'],d_e[_why]],
            [d_e['<mask_e>'],d_r['kgc:what'],d_e[_what]],
            [d_e['<mask_e>'],d_r['kgc:where'],d_e[_where]],
        ]
    )
    mask_ = torch.tensor(
        [
            [False, False, False],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
        ]
    )
    questions = torch.cat([triple[_start_index: _end_index], question_], dim=0).unsqueeze(0)
    masks = torch.cat([torch.zeros(_end_index-_start_index,3), mask_], dim=0).to(torch.bool).transpose(1,0).unsqueeze(0)
    tmp = []
    with torch.no_grad():
        _, (story_pred, relation_pred, entity_pred) = model(questions, masks[:,0], masks[:,1], masks[:,2])
        sorted_ = torch.argsort(entity_pred.to('cpu'), dim=1, descending=True)
        for i in range(sorted_.shape[1]):
            ans_= sorted_[:, i]
            predicate_, whom_, subj_, why_, what_, where_ = ans_
            tmp.append([entities[predicate_], entities[whom_], entities[subj_], entities[why_], entities[what_], entities[where_]])
    df_ranking = pd.DataFrame(tmp, columns=['predicate', 'whom', 'subject', 'why', 'what', 'where'])
    df_attension = make_heatmap2_(questions)
    return df_ranking, df_attension

# %%
MASK_E = '<mask_e>'
KILL = 'word.predicate:kill'
TAKE = 'word.predicate:take'
BRING = 'word.predicate:bring'
DIE = 'word.predicate:die'
HIDE = 'word.predicate:hide'

# %% [markdown]
# ### まだらの紐
# Who killed Julia? (criminal & explanation)
# 被害者: Julia
# 犯人: Roylott
# 犯行に用いたもの: snake
# 犯行動機: 母の相続財産を独占したい

# %%
victim = 'SpeckledBand:Julia'
killer = 'SpeckledBand:Roylott'
df_ranking_SpeckledBand, df_attension_SpeckledBand = make_ranking(
    'SpeckledBand:340', 'SpeckledBand:400', KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

print(f"{killer}, ranking", df_ranking_SpeckledBand.index[df_ranking_SpeckledBand['subject']==killer].tolist())
display(df_ranking_SpeckledBand.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_SpeckledBand)
for i in range(len_):
    display(i, df_attension_SpeckledBand.iloc[i,:3].tolist())
    display(df_attension_SpeckledBand.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %%
victim = 'SpeckledBand:Julia'
df_ranking_SpeckledBand, df_attension_SpeckledBand = make_ranking(
    'SpeckledBand:330', 'SpeckledBand:400', KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_SpeckledBand.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_SpeckledBand)
for i in range(len_-20, len_):
    display(i, df_attension_SpeckledBand.iloc[i,:3].tolist())
    display(df_attension_SpeckledBand.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %% [markdown]
# ### 悪魔の足跡１
# Who killed the victims? (criminal & explanation)
# 被害者: Brenda
# 犯人: Mortimer
# 犯行動機: 財産

# %%
victim = 'DevilsFoot:Brenda'
killer = 'DevilsFoot:Mortimer'
df_ranking_DevilsFoot1, df_attension_DevilsFoot1 = make_ranking(
    None, None, KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

print(f"{killer}, ranking", df_ranking_DevilsFoot1.index[df_ranking_DevilsFoot1['subject'] == killer].tolist()[0])
display(df_ranking_DevilsFoot1.iloc[:20,:])

# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_DevilsFoot1)
for i in range(len_):
    display(i, df_attension_DevilsFoot1.iloc[i,:3].tolist())
    display(df_attension_DevilsFoot1.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %%
victim = 'DevilsFoot:Brenda'
df_ranking_DevilsFoot1, df_attension_DevilsFoot1 = make_ranking(
    'DevilsFoot:400', 'DevilsFoot:488', KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_DevilsFoot1.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_DevilsFoot1)
for i in range(len_-20, len_):
    display(i, df_attension_DevilsFoot1.iloc[i,:3].tolist())
    display(df_attension_DevilsFoot1.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")
# Out:
#                       predicate                         whom  \
# 0       word.predicate:notExist          DevilsFoot:Mortimer
# 1                       <bos_e>         DevilsFoot:Sterndale
# 2           word.predicate:open              AllTitle:Holmes
# 3            word.predicate:say              AllTitle:Watson
# 4          word.predicate:exist    ACaseOfIdentity:Windibank
# 5             word.predicate:go            DevilsFoot:Brenda
# 6          DevilsFoot:Sterndale  ResidentPatient:Blessington
# 7           word.predicate:have            DancingMen:Cubitt
# 8               AllTitle:Watson       word.predicate:examine
# 9        word.predicate:notWant         SpeckledBand:Roylott
# 10         word.predicate:enter          DevilsFoot:Roundhay
# 11    word.predicate:cannotFind      AbbeyGrange:Jack_Croker
# 12          word.predicate:come           word.predicate:say
# 13              AllTitle:Holmes   SpeckledBand:1883-04-01T14
# 14    ACaseOfIdentity:Windibank         word.predicate:think
# 15   SpeckledBand:1883-04-01T14            DevilsFoot:Porter
# 16         AbbeyGrange:Criminal     SilverBlaze:Silver_Blaze
# 17  ResidentPatient:Blessington                      <bos_e>
# 18          DevilsFoot:Roundhay         AbbeyGrange:Criminal
# 19        word.predicate:arrive             CrookedMan:Nancy
#
#                          subject                                why  \
# 0           DevilsFoot:Sterndale          ACaseOfIdentity:Windibank
# 1            DevilsFoot:Mortimer                  DevilsFoot:Case_1
# 2      ACaseOfIdentity:Windibank               SpeckledBand:Roylott
# 3                AllTitle:Holmes               DevilsFoot:Sterndale
# 4              DancingMen:Cubitt                  DevilsFoot:Brenda
# 5              DevilsFoot:Brenda                DevilsFoot:Mortimer
# 6                        <bos_e>            word.predicate:notExist
# 7        AbbeyGrange:Jack_Croker        ResidentPatient:Blessington
# 8    ResidentPatient:Blessington                 SilverBlaze:police
# 9            DevilsFoot:Roundhay                word.predicate:wear
# 10               AllTitle:Watson                  DevilsFoot:window
# 11          SpeckledBand:Roylott             word.predicate:examine
# 12              CrookedMan:Nancy    ResidentPatient:Percy_Trevelyan
# 13        word.predicate:examine                    DevilsFoot:room
# 14             DevilsFoot:George                   CrookedMan:Henry
# 15    SpeckledBand:1883-04-01T14         SpeckledBand:1883-04-01T14
# 16          word.predicate:exist  DevilsFoot:cottage_of_Pordeux_Bay
# 17  DateTime:1883-04-02T04:00:00             DancingMen:casual_wear
# 18        word.predicate:notKnow                    AllTitle:Holmes
# 19         DancingMen:Abe_Slaney                  DancingMen:Cubitt
#
#                              what                            where
# 0       ACaseOfIdentity:Windibank             DevilsFoot:Sterndale
# 1                 AllTitle:Watson                DancingMen:Cubitt
# 2               DancingMen:Cubitt        ACaseOfIdentity:Windibank
# 3            DevilsFoot:Sterndale             word.predicate:exist
# 4            SpeckledBand:Roylott             SpeckledBand:Roylott
# 5    DateTime:1883-04-02T04:00:00           word.predicate:examine
# 6             DevilsFoot:Mortimer               SilverBlaze:police
# 7        DevilsFoot:Paper_package                 CrookedMan:Nancy
# 8             word.predicate:wear                  AllTitle:Watson
# 9                CrookedMan:Henry          word.predicate:notExist
# 10                AllTitle:Holmes                          <bos_e>
# 11              DevilsFoot:Porter  ResidentPatient:Percy_Trevelyan
# 12               SpeckledBand:bed                DevilsFoot:Case_1
# 13           word.predicate:exist              DevilsFoot:Mortimer
# 14  AbbeyGrange:Thought_of_Holmes                DevilsFoot:window
# 15         word.predicate:receive                  DevilsFoot:room
# 16             SilverBlaze:police      ResidentPatient:Blessington
# 17              CrookedMan:rebels           word.predicate:notKnow
# 18          word.predicate:engage                DevilsFoot:Brenda
# 19     SpeckledBand:1883-04-01T14             AbbeyGrange:Criminal
# 385
# ['DevilsFoot:485', 'kgc:what', 'DevilsFoot:gun']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 392  DevilsFoot:487      kgc:subject
# 386  DevilsFoot:485   kgc:infoSource
# 389  DevilsFoot:486   kgc:infoSource
# 163  DevilsFoot:436      kgc:subject
# 374  DevilsFoot:482         kgc:what
# 167  DevilsFoot:436   kgc:infoSource
# 388  DevilsFoot:486      kgc:subject
# 344  DevilsFoot:474   kgc:infoSource
# 384  DevilsFoot:485      kgc:subject
# 379  DevilsFoot:483   kgc:infoSource
# 157  DevilsFoot:434   kgc:infoSource
#
# ['<bos_e>', '<bos_r>', '<bos_e>']
#         head relation     tail  atten_from387
# 61   <bos_e>  <bos_r>  <bos_e>       0.006970
# 46   <bos_e>  <bos_r>  <bos_e>       0.006672
# 67   <bos_e>  <bos_r>  <bos_e>       0.006439
# 341  <bos_e>  <bos_r>  <bos_e>       0.006397
# 274  <bos_e>  <bos_r>  <bos_e>       0.006290
# 103  <bos_e>  <bos_r>  <bos_e>       0.006183
# 77   <bos_e>  <bos_r>  <bos_e>       0.006149
# 82   <bos_e>  <bos_r>  <bos_e>       0.006145
# 23   <bos_e>  <bos_r>  <bos_e>       0.006116
# 222  <bos_e>  <bos_r>  <bos_e>       0.006116
# 283  <bos_e>  <bos_r>  <bos_e>       0.006052
# 89   <bos_e>  <bos_r>  <bos_e>       0.006030
# 26   <bos_e>  <bos_r>  <bos_e>       0.005992
# 327  <bos_e>  <bos_r>  <bos_e>       0.005978
# 70   <bos_e>  <bos_r>  <bos_e>       0.005924
# 278  <bos_e>  <bos_r>  <bos_e>       0.005914
# 270  <bos_e>  <bos_r>  <bos_e>       0.005912
# 42   <bos_e>  <bos_r>  <bos_e>       0.005912
# 230  <bos_e>  <bos_r>  <bos_e>       0.005909
# 74   <bos_e>  <bos_r>  <bos_e>       0.005867
# ----------
# 388
# ['DevilsFoot:486', 'kgc:subject', 'DevilsFoot:Mortimer']
#                head          relation  \
# 386  DevilsFoot:485    kgc:infoSource
# 167  DevilsFoot:436    kgc:infoSource
# 389  DevilsFoot:486    kgc:infoSource
# 163  DevilsFoot:436       kgc:subject
# 159  DevilsFoot:435       kgc:subject
# 186  DevilsFoot:440       kgc:subject
# 173  DevilsFoot:438       kgc:subject
# 392  DevilsFoot:487       kgc:subject
# 192  DevilsFoot:441    kgc:infoSource
# 249  DevilsFoot:454       kgc:subject
# 388  DevilsFoot:486       kgc:subject
# 344  DevilsFoot:474    kgc:infoSource
# 376  DevilsFoot:482    kgc:infoSource
# 189  DevilsFoot:440    kgc:infoSource
# 243  DevilsFoot:452       kgc:subject
# 200  DevilsFoot:443  kgc:hasPredicate
# 296  DevilsFoot:466       kgc:subject
# 176  DevilsFoot:438    kgc:infoSource
# 157  DevilsFoot:434    kgc:infoSource
# 194  DevilsFoot:442       kgc:subject
#
#                                            tail  atten_from388
# 386                        DevilsFoot:Sterndale       0.012814
# 167                        DevilsFoot:Sterndale       0.012775
# 389                        DevilsFoot:Sterndale       0.012695
# 163                        DevilsFoot:Sterndale       0.011713
# 159                  DevilsFoot:powder_medicine       0.011202
# 186                        DevilsFoot:Sterndale       0.009643
# 173                        DevilsFoot:Sterndale       0.009598
# 392  DevilsFoot:Starting_point_of_investigation       0.009431
# 192                        DevilsFoot:Sterndale       0.009357
# 249                        DevilsFoot:Sterndale       0.009305
# 388                         DevilsFoot:Mortimer       0.009216
# 344                        DevilsFoot:Sterndale       0.009067
# 376                        DevilsFoot:Sterndale       0.009051
# 189                        DevilsFoot:Sterndale       0.008685
# 243                        DevilsFoot:Sterndale       0.008615
# 200                        word.predicate:teach       0.008556
# 296                        DevilsFoot:Sterndale       0.008549
# 176                        DevilsFoot:Sterndale       0.008421
# ['<bos_e>', '<bos_r>', '<bos_e>']
#         head relation     tail  atten_from398
# 61   <bos_e>  <bos_r>  <bos_e>       0.006681
# 46   <bos_e>  <bos_r>  <bos_e>       0.006401
# 67   <bos_e>  <bos_r>  <bos_e>       0.006204
# 274  <bos_e>  <bos_r>  <bos_e>       0.006069
# 341  <bos_e>  <bos_r>  <bos_e>       0.006000
# 77   <bos_e>  <bos_r>  <bos_e>       0.005995
# 103  <bos_e>  <bos_r>  <bos_e>       0.005974
# 82   <bos_e>  <bos_r>  <bos_e>       0.005963
# 23   <bos_e>  <bos_r>  <bos_e>       0.005945
# 89   <bos_e>  <bos_r>  <bos_e>       0.005915
# 26   <bos_e>  <bos_r>  <bos_e>       0.005869
# 283  <bos_e>  <bos_r>  <bos_e>       0.005812
# 222  <bos_e>  <bos_r>  <bos_e>       0.005807
# 70   <bos_e>  <bos_r>  <bos_e>       0.005800
# 270  <bos_e>  <bos_r>  <bos_e>       0.005789
# 42   <bos_e>  <bos_r>  <bos_e>       0.005778
# 74   <bos_e>  <bos_r>  <bos_e>       0.005769
# 230  <bos_e>  <bos_r>  <bos_e>       0.005746
# 0    <bos_e>  <bos_r>  <bos_e>       0.005695
# 327  <bos_e>  <bos_r>  <bos_e>       0.005687
# ----------
# 399
# ['<mask_e>', 'kgc:hasPredicate', 'word.predicate:kill']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 392  DevilsFoot:487      kgc:subject
# 374  DevilsFoot:482         kgc:what
# 372  DevilsFoot:482      kgc:subject
# 375  DevilsFoot:482           kgc:to
# 157  DevilsFoot:434   kgc:infoSource
# 152  DevilsFoot:433   kgc:infoSource
# 400        <mask_e>         kgc:whom
# 180  DevilsFoot:439           kgc:to
# 163  DevilsFoot:436      kgc:subject
# 367  DevilsFoot:481      kgc:subject
# 376  DevilsFoot:482   kgc:infoSource
# 388  DevilsFoot:486      kgc:subject
# 178  DevilsFoot:439      kgc:subject
# 369  DevilsFoot:481   kgc:infoSource
# 401        <mask_e>      kgc:subject
# 154  DevilsFoot:434      kgc:subject
# 161  DevilsFoot:435        kgc:where
# 181  DevilsFoot:439   kgc:infoSource
# 393  DevilsFoot:487  kgc:hasProperty
#
#                                            tail  atten_from399
# 159                  DevilsFoot:powder_medicine       0.014959
# 392  DevilsFoot:Starting_point_of_investigation       0.010838
# 374                             DevilsFoot:fire       0.010110
# 372                        DevilsFoot:Sterndale       0.009164
# 375                             DevilsFoot:lamp       0.009040
# 157                        DevilsFoot:Sterndale       0.008325
# 152                        DevilsFoot:Sterndale       0.008185
# 400                           DevilsFoot:Brenda       0.007653
# 180             DevilsFoot:cottage_of_Sterndale       0.007623
# 163                        DevilsFoot:Sterndale       0.007618
# 367                         DevilsFoot:Mortimer       0.007604
# 376                        DevilsFoot:Sterndale       0.007534
# 388                         DevilsFoot:Mortimer       0.007409
# 178                         DevilsFoot:Mortimer       0.007324
# 369                        DevilsFoot:Sterndale       0.007155
# 401                                    <mask_e>       0.006970
# 154             DevilsFoot:sample_of_magic_foot       0.006943
# 161                     DevilsFoot:paper_packet       0.006651
# 181                        DevilsFoot:Sterndale       0.006556
# 393                       word.predicate:gravel       0.006492
# ----------
# 400
# ['<mask_e>', 'kgc:whom', 'DevilsFoot:Brenda']
#                head        relation  \
# 159  DevilsFoot:435     kgc:subject
# 376  DevilsFoot:482  kgc:infoSource
# 372  DevilsFoot:482     kgc:subject
# 392  DevilsFoot:487     kgc:subject
# 375  DevilsFoot:482          kgc:to
# 400        <mask_e>        kgc:whom
# 157  DevilsFoot:434  kgc:infoSource
# 176  DevilsFoot:438  kgc:infoSource
# 369  DevilsFoot:481  kgc:infoSource
# 367  DevilsFoot:481     kgc:subject
# 374  DevilsFoot:482        kgc:what
# 178  DevilsFoot:439     kgc:subject
# 252  DevilsFoot:455     kgc:subject
# 388  DevilsFoot:486     kgc:subject
# 163  DevilsFoot:436     kgc:subject
#
'<mask_e>']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 374  DevilsFoot:482         kgc:what
# 372  DevilsFoot:482      kgc:subject
# 392  DevilsFoot:487      kgc:subject
# 393  DevilsFoot:487  kgc:hasProperty
# 194  DevilsFoot:442      kgc:subject
# 376  DevilsFoot:482   kgc:infoSource
# 15   DevilsFoot:404      kgc:subject
# 379  DevilsFoot:483   kgc:infoSource
# 375  DevilsFoot:482           kgc:to
# 388  DevilsFoot:486      kgc:subject
# 401        <mask_e>      kgc:subject
# 249  DevilsFoot:454      kgc:subject
# 378  DevilsFoot:483      kgc:subject
# 369  DevilsFoot:481   kgc:infoSource
# 163  DevilsFoot:436      kgc:subject
# 296  DevilsFoot:466      kgc:subject
# 367  DevilsFoot:481      kgc:subject
# 358  DevilsFoot:478      kgc:subject
# 359  DevilsFoot:478   kgc:infoSource
#
#                                            tail  atten_from402
# 159                  DevilsFoot:powder_medicine       0.015707
# 374                             DevilsFoot:fire       0.013643
# 372                        DevilsFoot:Sterndale       0.012038
# 392  DevilsFoot:Starting_point_of_investigation       0.011228
# 393                       word.predicate:gravel       0.008813
# 194                        DevilsFoot:Sterndale       0.008324
# 376                        DevilsFoot:Sterndale       0.008001
# 15                         DevilsFoot:Sterndale       0.007715
# 379                        DevilsFoot:Sterndale       0.007395
# 375                             DevilsFoot:lamp       0.007251
# 388                         DevilsFoot:Mortimer       0.007227
# 401                                    <mask_e>       0.007098
# 249                        DevilsFoot:Sterndale       0.007088
# 378                        DevilsFoot:Sterndale       0.007071
# 369                        DevilsFoot:Sterndale       0.007052
# 163                        DevilsFoot:Sterndale       0.007031
# 296                        DevilsFoot:Sterndale       0.006795
# 367                         DevilsFoot:Mortimer       0.006757
# 358                         DevilsFoot:Mortimer       0.006727
# 359                        DevilsFoot:Sterndale       0.006354
# ----------
# 403
# ['<mask_e>', 'kgc:what', '<mask_e>']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 374  DevilsFoot:482         kgc:what
# 392  DevilsFoot:487      kgc:subject
# 403        <mask_e>         kgc:what
# 393  DevilsFoot:487  kgc:hasProperty
# 163  DevilsFoot:436      kgc:subject
# 372  DevilsFoot:482      kgc:subject
# 379  DevilsFoot:483   kgc:infoSource
# 388  DevilsFoot:486      kgc:subject
# 389  DevilsFoot:486   kgc:infoSource
# 376  DevilsFoot:482   kgc:infoSource
# 157  DevilsFoot:434   kgc:infoSource
# 161  DevilsFoot:435        kgc:where
# 401        <mask_e>      kgc:subject
# 386  DevilsFoot:485   kgc:infoSource
# 394  DevilsFoot:487           kgc:on
# 397  DevilsFoot:488        kgc:where
# 167  DevilsFoot:436   kgc:infoSource
# 404        <mask_e>        kgc:where
# 186  DevilsFoot:440      kgc:subject
#
#                                            tail  atten_from403
# 159                  DevilsFoot:powder_medicine       0.020337
# 374                             DevilsFoot:fire       0.015192
# 392  DevilsFoot:Starting_point_of_investigation       0.014294
# 403                                    <mask_e>       0.009744
# 393                       word.predicate:gravel       0.009722
# 163                        DevilsFoot:Sterndale       0.009016
# 372                        DevilsFoot:Sterndale       0.008711
# 379                        DevilsFoot:Sterndale       0.008155
# 388                         DevilsFoot:Mortimer       0.007990
# 389                        DevilsFoot:Sterndale       0.007498
# 376                        DevilsFoot:Sterndale       0.007495
# 157                        DevilsFoot:Sterndale       0.007471
# 161                     DevilsFoot:paper_packet       0.007423
# 401                                    <mask_e>       0.007417
# 386                        DevilsFoot:Sterndale       0.007373
# 394                  DevilsFoot:frame_of_Window       0.007217
# 397          DevilsFoot:garden_of_pastoral_hall       0.007197
# 167                        DevilsFoot:Sterndale       0.006906
# 404                                    <mask_e>       0.006848
# 186                        DevilsFoot:Sterndale       0.006715
# ----------
# 404
# ['<mask_e>', 'kgc:where', '<mask_e>']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 392  DevilsFoot:487      kgc:subject
# 374  DevilsFoot:482         kgc:what
# 393  DevilsFoot:487  kgc:hasProperty
# 372  DevilsFoot:482      kgc:subject
# 163  DevilsFoot:436      kgc:subject
# 167  DevilsFoot:436   kgc:infoSource
# 157  DevilsFoot:434   kgc:infoSource
# 379  DevilsFoot:483   kgc:infoSource
# 376  DevilsFoot:482   kgc:infoSource
# 389  DevilsFoot:486   kgc:infoSource
# 388  DevilsFoot:486      kgc:subject
# 386  DevilsFoot:485   kgc:infoSource
# 262  DevilsFoot:457   kgc:infoSource
# 296  DevilsFoot:466      kgc:subject
# 249  DevilsFoot:454      kgc:subject
# 252  DevilsFoot:455      kgc:subject
# 369  DevilsFoot:481   kgc:infoSource
# 176  DevilsFoot:438   kgc:infoSource
# 378  DevilsFoot:483      kgc:subject
#
#                                            tail  atten_from404
# 159                  DevilsFoot:powder_medicine       0.021879
# 392  DevilsFoot:Starting_point_of_investigation       0.014640
# 374                             DevilsFoot:fire       0.010904
# 393                       word.predicate:gravel       0.010760
# 372                        DevilsFoot:Sterndale       0.009997
# 163                        DevilsFoot:Sterndale       0.009357
# 167                        DevilsFoot:Sterndale       0.009331
# 157                        DevilsFoot:Sterndale       0.009146
# 379                        DevilsFoot:Sterndale       0.009112
# 376                        DevilsFoot:Sterndale       0.008720
# 389                        DevilsFoot:Sterndale       0.008665
# 388                         DevilsFoot:Mortimer       0.008305
# 386                        DevilsFoot:Sterndale       0.008191
# 262                        DevilsFoot:Sterndale       0.008145
# 296                        DevilsFoot:Sterndale       0.007993
# 249                        DevilsFoot:Sterndale       0.007955
# 252                        DevilsFoot:Sterndale       0.007516
# 369                        DevilsFoot:Sterndale       0.007490
# 176                        DevilsFoot:Sterndale       0.007184
# 378                        DevilsFoot:Sterndale       0.007105
# ----------

# %% [markdown]
# ### 悪魔の足跡2
# Who killed the victims? (criminal & explanation)
# 被害者: Mortimer
# 犯人:
# 犯行動機: 恋人の敵

# %%
victim = 'DevilsFoot:Mortimer'
killer = 'DevilsFoot:Sterndale'
df_ranking_DevilsFoot1, df_attension_DevilsFoot1 = make_ranking(
    None, None, KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

print(f"{killer}, ranking", df_ranking_DevilsFoot1.index[df_ranking_DevilsFoot1['subject'] == killer].tolist()[0])
display(df_ranking_DevilsFoot1.iloc[:20,:])

# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_DevilsFoot1)
for i in range(len_):
    display(i, df_attension_DevilsFoot1.iloc[i,:3].tolist())
    display(df_attension_DevilsFoot1.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %%
victim = 'DevilsFoot:Mortimer'
df_ranking_DevilsFoot2, df_attension_DevilsFoot2 = make_ranking(
    'DevilsFoot:400', 'DevilsFoot:488', KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_DevilsFoot2.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_DevilsFoot2)
for i in range(len_-20, len_):
    display(i, df_attension_DevilsFoot2.iloc[i,:3].tolist())
    display(df_attension_DevilsFoot2.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")
# Out:
#                       predicate                             whom  \
# 0       word.predicate:notExist              DevilsFoot:Mortimer
# 1                       <bos_e>             DevilsFoot:Sterndale
# 2            word.predicate:say        ACaseOfIdentity:Windibank
# 3           word.predicate:open                DevilsFoot:Brenda
# 4             word.predicate:go                  AllTitle:Holmes
# 5          word.predicate:exist      ResidentPatient:Blessington
# 6          DevilsFoot:Sterndale              DevilsFoot:Roundhay
# 7        word.predicate:notWant                  AllTitle:Watson
# 8           word.predicate:have             SpeckledBand:Roylott
# 9           word.predicate:come                DancingMen:Cubitt
# 10              AllTitle:Watson          AbbeyGrange:Jack_Croker
# 11          DevilsFoot:Roundhay       SpeckledBand:1883-04-01T14
# 12         word.predicate:enter           word.predicate:examine
# 13    word.predicate:cannotFind               word.predicate:say
# 14          word.predicate:live               SilverBlaze:police
# 15   SpeckledBand:1883-04-01T14                          <bos_e>
# 16          AbbeyGrange:Theresa             AbbeyGrange:Criminal
# 17  ResidentPatient:Blessington                DevilsFoot:George
# 18         AbbeyGrange:Criminal      ResidentPatient:Elderly_man
# 19              AllTitle:Holmes  ResidentPatient:Percy_Trevelyan
#
#                          subject                           why  \
# 0           DevilsFoot:Sterndale     ACaseOfIdentity:Windibank
# 1            DevilsFoot:Mortimer          DevilsFoot:Sterndale
# 2      ACaseOfIdentity:Windibank             DevilsFoot:Brenda
# 3                AllTitle:Holmes          SpeckledBand:Roylott
# 4                        <bos_e>             DevilsFoot:Case_1
# 5        AbbeyGrange:Jack_Croker       word.predicate:notExist
# 6              DevilsFoot:Brenda   ResidentPatient:Blessington
# 7            DevilsFoot:Roundhay             DevilsFoot:window
# 8              DancingMen:Cubitt           DevilsFoot:Mortimer
# 9               CrookedMan:Nancy            SilverBlaze:police
# 10               AllTitle:Watson           word.predicate:wear
# 11   ResidentPatient:Blessington        word.predicate:examine
# 12          SpeckledBand:Roylott    SpeckledBand:1883-04-01T14
# 13             DevilsFoot:George             DancingMen:Cubitt
# 14    SpeckledBand:1883-04-01T14           DevilsFoot:Roundhay
# 15        word.predicate:examine  SpeckledBand:VentilationHole
# 16          word.predicate:exist              CrookedMan:Henry
# 17        word.predicate:notKnow          AbbeyGrange:Criminal
# 18  DateTime:1883-04-02T04:00:00        DancingMen:casual_wear
# 19   ResidentPatient:Elderly_man               DevilsFoot:room
#
#                              what                            where
# 0       ACaseOfIdentity:Windibank             DevilsFoot:Sterndale
# 1                 AllTitle:Watson                DancingMen:Cubitt
# 2            DevilsFoot:Sterndale        ACaseOfIdentity:Windibank
# 3               DancingMen:Cubitt             SpeckledBand:Roylott
# 4             DevilsFoot:Mortimer             word.predicate:exist
# 5    DateTime:1883-04-02T04:00:00           word.predicate:examine
# 6            SpeckledBand:Roylott               SilverBlaze:police
# 7             word.predicate:wear                 CrookedMan:Nancy
# 8        DevilsFoot:Paper_package                  AllTitle:Watson
# 9               DevilsFoot:Porter              DevilsFoot:Mortimer
# 10               CrookedMan:Henry          word.predicate:notExist
# 11                AllTitle:Holmes                          <bos_e>
# 12         word.predicate:receive                DevilsFoot:window
# 13               SpeckledBand:bed                DevilsFoot:Brenda
# 14  AbbeyGrange:Thought_of_Holmes  ResidentPatient:Percy_Trevelyan
# 15     SpeckledBand:1883-04-01T14                  DevilsFoot:room
# 16           word.predicate:exist      ResidentPatient:Blessington
# 17              DevilsFoot:Brenda           word.predicate:notKnow
# 18             SilverBlaze:police             AbbeyGrange:Criminal
# 19              CrookedMan:rebels                DevilsFoot:Case_1
# 385
# ['DevilsFoot:485', 'kgc:what', 'DevilsFoot:gun']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 392  DevilsFoot:487      kgc:subject
# 386  DevilsFoot:485   kgc:infoSource
# 389  DevilsFoot:486   kgc:infoSource
# 163  DevilsFoot:436      kgc:subject
# 374  DevilsFoot:482         kgc:what
# 167  DevilsFoot:436   kgc:infoSource
# 388  DevilsFoot:486      kgc:subject
#
# 67   <bos_e>  <bos_r>  <bos_e>       0.006226
# 274  <bos_e>  <bos_r>  <bos_e>       0.006095
# 341  <bos_e>  <bos_r>  <bos_e>       0.006029
# 77   <bos_e>  <bos_r>  <bos_e>       0.006012
# 103  <bos_e>  <bos_r>  <bos_e>       0.005994
# 82   <bos_e>  <bos_r>  <bos_e>       0.005980
# 23   <bos_e>  <bos_r>  <bos_e>       0.005961
# 89   <bos_e>  <bos_r>  <bos_e>       0.005926
# 26   <bos_e>  <bos_r>  <bos_e>       0.005883
# 222  <bos_e>  <bos_r>  <bos_e>       0.005838
# 283  <bos_e>  <bos_r>  <bos_e>       0.005833
# 70   <bos_e>  <bos_r>  <bos_e>       0.005817
# 270  <bos_e>  <bos_r>  <bos_e>       0.005809
# 42   <bos_e>  <bos_r>  <bos_e>       0.005788
# 74   <bos_e>  <bos_r>  <bos_e>       0.005782
# 230  <bos_e>  <bos_r>  <bos_e>       0.005758
# 327  <bos_e>  <bos_r>  <bos_e>       0.005716
# 278  <bos_e>  <bos_r>  <bos_e>       0.005709
# ----------
# 399
# ['<mask_e>', 'kgc:hasPredicate', 'word.predicate:kill']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 400        <mask_e>         kgc:whom
# 392  DevilsFoot:487      kgc:subject
# 152  DevilsFoot:433   kgc:infoSource
# 157  DevilsFoot:434   kgc:infoSource
# 374  DevilsFoot:482         kgc:what
# 372  DevilsFoot:482      kgc:subject
# 163  DevilsFoot:436      kgc:subject
# 401        <mask_e>      kgc:subject
# 388  DevilsFoot:486      kgc:subject
# 154  DevilsFoot:434      kgc:subject
# 178  DevilsFoot:439      kgc:subject
# 376  DevilsFoot:482   kgc:infoSource
# 180  DevilsFoot:439           kgc:to
# 375  DevilsFoot:482           kgc:to
# 186  DevilsFoot:440      kgc:subject
# 393  DevilsFoot:487  kgc:hasProperty
# 384  DevilsFoot:485      kgc:subject
# 367  DevilsFoot:481      kgc:subject
# 161  DevilsFoot:435        kgc:where
#
#                                            tail  atten_from399
# 159                  DevilsFoot:powder_medicine       0.014244
# 400                         DevilsFoot:Mortimer       0.012346
# 392  DevilsFoot:Starting_point_of_investigation       0.011024
# 152                        DevilsFoot:Sterndale       0.009669
# 157                        DevilsFoot:Sterndale       0.009654
# 374                             DevilsFoot:fire       0.009443
# 372                        DevilsFoot:Sterndale       0.008490
# 163                        DevilsFoot:Sterndale       0.008163
# 401                                    <mask_e>       0.007776
# 388                         DevilsFoot:Mortimer       0.007742
# 154             DevilsFoot:sample_of_magic_foot       0.007706
# 178                         DevilsFoot:Mortimer       0.007526
# 376                        DevilsFoot:Sterndale       0.007294
# 180             DevilsFoot:cottage_of_Sterndale       0.007263
# 375                             DevilsFoot:lamp       0.007241
# 186                        DevilsFoot:Sterndale       0.007114
# 393                       word.predicate:gravel       0.007091
# 384                        DevilsFoot:Sterndale       0.006862
# 367                         DevilsFoot:Mortimer       0.006755
# 161                     DevilsFoot:paper_packet       0.006557
# ----------
# 400
# ['<mask_e>', 'kgc:whom', 'DevilsFoot:Mortimer']
#                head        relation  \
# 159  DevilsFoot:435     kgc:subject
# 392  DevilsFoot:487     kgc:subject
# 400        <mask_e>        kgc:whom
# 376  DevilsFoot:482  kgc:infoSource
# 372  DevilsFoot:482     kgc:subject
# 388  DevilsFoot:486     kgc:subject
# 157  DevilsFoot:434  kgc:infoSource
# 376                        DevilsFoot:Sterndale       0.007539
# 167                        DevilsFoot:Sterndale       0.007484
# 161                     DevilsFoot:paper_packet       0.007187
# 186                        DevilsFoot:Sterndale       0.007086
# 400                         DevilsFoot:Mortimer       0.006768
# 394                  DevilsFoot:frame_of_Window       0.006750
# 384                        DevilsFoot:Sterndale       0.006719
# ----------
# 404
# ['<mask_e>', 'kgc:where', '<mask_e>']
#                head         relation  \
# 159  DevilsFoot:435      kgc:subject
# 392  DevilsFoot:487      kgc:subject
# 393  DevilsFoot:487  kgc:hasProperty
# 372  DevilsFoot:482      kgc:subject
# 374  DevilsFoot:482         kgc:what
# 167  DevilsFoot:436   kgc:infoSource
# 163  DevilsFoot:436      kgc:subject
# 157  DevilsFoot:434   kgc:infoSource
# 379  DevilsFoot:483   kgc:infoSource
# 376  DevilsFoot:482   kgc:infoSource
# 389  DevilsFoot:486   kgc:infoSource
# 386  DevilsFoot:485   kgc:infoSource
# 249  DevilsFoot:454      kgc:subject
# 296  DevilsFoot:466      kgc:subject
# 388  DevilsFoot:486      kgc:subject
# 262  DevilsFoot:457   kgc:infoSource
# 252  DevilsFoot:455      kgc:subject
# 369  DevilsFoot:481   kgc:infoSource
# 176  DevilsFoot:438   kgc:infoSource
# 192  DevilsFoot:441   kgc:infoSource
#
#                                            tail  atten_from404
# 159                  DevilsFoot:powder_medicine       0.022143
# 392  DevilsFoot:Starting_point_of_investigation       0.013943
# 393                       word.predicate:gravel       0.010018
# 372                        DevilsFoot:Sterndale       0.009976
# 374                             DevilsFoot:fire       0.009647
# 167                        DevilsFoot:Sterndale       0.009636
# 163                        DevilsFoot:Sterndale       0.009596
# 157                        DevilsFoot:Sterndale       0.009151
# 379                        DevilsFoot:Sterndale       0.009140
# 376                        DevilsFoot:Sterndale       0.008515
# 389                        DevilsFoot:Sterndale       0.008500
# 386                        DevilsFoot:Sterndale       0.008121
# 249                        DevilsFoot:Sterndale       0.008078
# 296                        DevilsFoot:Sterndale       0.008003
# 388                         DevilsFoot:Mortimer       0.007985
# 262                        DevilsFoot:Sterndale       0.007914
# 252                        DevilsFoot:Sterndale       0.007667
# 369                        DevilsFoot:Sterndale       0.007448
# 176                        DevilsFoot:Sterndale       0.007306
# 192                        DevilsFoot:Sterndale       0.007254
# ----------

# %% [markdown]
# ### 背中の曲がった男:
# Why did Barclay die?
# 被害者: Barclay
# 犯人:
# 犯行動機:

# %%
victim = 'CrookedMan:Barclay'
killer = 'CrookedMan:apoplexia'
df_ranking_CrookedMan, df_attension_CrookedMan = make_ranking(
    None, None, DIE, MASK_E, victim, MASK_E, MASK_E, MASK_E)

print(f"{killer}, ranking", df_ranking_CrookedMan.index[df_ranking_CrookedMan['why'] == killer].tolist()[0])
display(df_ranking_CrookedMan.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_CrookedMan)
for i in range(len_-20, len_):
    display(i, df_attension_CrookedMan.iloc[i,:3].tolist())
    display(df_attension_CrookedMan.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %%
victim = 'CrookedMan:Barclay'
df_ranking_CrookedMan, df_attension_CrookedMan = make_ranking(
    'CrookedMan:300', 'CrookedMan:372', DIE, MASK_E, victim, MASK_E, MASK_E, MASK_E)

display(df_ranking_CrookedMan.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_CrookedMan)
for i in range(len_-20, len_):
    display(i, df_attension_CrookedMan.iloc[i,:3].tolist())
    display(df_attension_CrookedMan.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %% [markdown]
# ### 僧坊荘園
# Who killed Lord Blackenstall? (criminal & explanation)
# 被害者: Sir_Eustace_Brackenstall
# 犯人:
# 犯行動機:

# %%
victim = 'AbbeyGrange:Sir_Eustace_Brackenstall'
killer = 'AbbeyGrange:Jack_Croker'
df_ranking_AbbeyGrange, df_attension_AbbeyGrange = make_ranking(
    None, None, KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

print(f"{killer}, ranking", df_ranking_AbbeyGrange.index[df_ranking_AbbeyGrange['subject'] == killer].tolist()[0])
display(df_ranking_AbbeyGrange.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_AbbeyGrange)
for i in range(len_):
    display(i, df_attension_AbbeyGrange.iloc[i,:3].tolist())
    display(df_attension_AbbeyGrange.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %%
victim = 'AbbeyGrange:Sir_Eustace_Brackenstall'
df_ranking_AbbeyGrange, df_attension_AbbeyGrange = make_ranking(
    'AbbeyGrange:350', 'AbbeyGrange:413', KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_AbbeyGrange.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_AbbeyGrange)
for i in range(len_-20, len_):
    display(i, df_attension_AbbeyGrange.iloc[i,:3].tolist())
    display(df_attension_AbbeyGrange.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %% [markdown]
# ### 入院患者
# Who killed Blessington? (criminal & explanation)
# 被害者: Blessington
# 犯人: 3人
# 犯行動機:

# %%
victim = 'ResidentPatient:Blessington'
df_ranking_Blessington, df_attension_Blessington = make_ranking(
    'ResidentPatient:250', 'ResidentPatient:323', KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_Blessington.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_Blessington)
for i in range(len_-20, len_):
    display(i, df_attension_Blessington.iloc[i,:3].tolist())
    display(df_attension_Blessington.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %% [markdown]
# ### 白銀
# Who took out the White Silver Blaze? (criminal & explanation)
# 被害者: Silver_Blaze
# 犯人:
# 犯行動機:

# %%
victim = 'SilverBlaze:Silver_Blaze'
df_ranking_SilverBlaze, df_attension_SilverBlaze = make_ranking(
    'SilverBlaze:330', 'SilverBlaze:396', BRING, MASK_E, MASK_E, MASK_E, victim, MASK_E)

display(df_ranking_SilverBlaze.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_SilverBlaze)
for i in range(len_-20, len_):
    display(i, df_attension_SilverBlaze.iloc[i,:3].tolist())
    display(df_attension_SilverBlaze.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %% [markdown]
# ### 花嫁失踪事件（同一事件）
# hozmaの失踪の名瀬を探る
# 被害者: ACaseOfIdentity:Hozma
# 犯人:
# 犯行動機:

# %%
victim = 'ACaseOfIdentity:Hosmer'
df_ranking_ACaseOfIdentity, df_attension_ACaseOfIdentity = make_ranking(
    'ACaseOfIdentity:510', 'ACaseOfIdentity:578', HIDE, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_ACaseOfIdentity.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_ACaseOfIdentity)
for i in range(len_-20, len_):
    display(i, df_attension_ACaseOfIdentity.iloc[i,:3].tolist())
    display(df_attension_ACaseOfIdentity.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")
