# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
# ========== python ==========
import os
from pathlib import Path
from logging import Logger
from typing import List, Dict, Tuple, Optional, Union, Callable, Final, Literal, get_args
from operator import itemgetter, attrgetter
import itertools
from IPython import display

from utils.setup import setup_logger, get_device
from const.const_values import PROJECT_DIR

os.chdir(PROJECT_DIR)
logger: Logger = setup_logger(__name__, f'{PROJECT_DIR}/log/jupyter_run.log')
device = get_device(device_name='cpu', logger=logger)

# %%
# jupyter
import seaborn as sns
import matplotlib.pyplot as plt
# Machine learning
import numpy as np
import pandas as pd
import h5py
import optuna
# torch
import torch
from torch.nn import CrossEntropyLoss
from torch.utils.data import Dataset
from torch.utils.data.dataloader import DataLoader
from torch.utils.tensorboard.writer import SummaryWriter
# torch ignite
from ignite.engine import Engine
from ignite.handlers import Checkpoint
# My items
from models.datasets.data_helper import MyDataHelper, MyDataLoaderHelper, DefaultTokens
from models.datasets.datasets_for_story import StoryTriple
# My utils
from utils.setup import load_param
from utils.torch import load_model, torch_fix_seed
# main function
from run_for_KGC import main_function

# %%
from const.const_values import CPU, MODEL
from models.KGModel.kg_model import HEAD, RELATION, TAIL
from utils.torch_ignite import TRAINER, EVALUATOR
from const.const_values import DATASETS, DATA_HELPER, DATA_LOADERS, TRAIN_RETURNS

# %%
SEED: Final[int] = 42

args_path = f'{PROJECT_DIR}/saved_models/kgc/all100/03/param.pkl'
model_path = f'{PROJECT_DIR}/saved_models/kgc/all100/03/model.pth'

# %%
args = load_param(args_path)

args.logger = logger
args.device = device
args.batch_size = 1
args.no_use_pe = False
args.max_len=512
args.tensorboard_dir=None
args.only_load_trainer_evaluator=True
args.pre_train=False
args.use_for_challenge090=False
args.use_for_challenge075=False
args.old_data = 2

del args.optuna_file, args.device_name, args.pid
del args.study_name, args.n_trials
logger.info(args)
# Out:
# 2023-02-03 02:55:35 - INFO - 2779886530.py - 17 - Namespace(notebook=False, train_anyway=False, logfile='saved_models/kgc/all100/03/log.log', param_file='saved_models/kgc/all100/03/param.pkl', tensorboard_dir=None, checkpoint_dir='saved_models/kgc/all100/03/checkpoint/', model_path='saved_models/kgc/all100/03/model.pth', model_version='03', resume_from_checkpoint=False, resume_from_last_point=False, only_load_trainer_evaluator=True, resume_checkpoint_path=None, console_level='info', pre_train=False, train_valid_test=False, only_train=True, use_for_challenge100=False, use_for_challenge075=False, use_title=None, do_optuna=False, story_special_num=5, relation_special_num=5, entity_special_num=5, padding_token_e=0, cls_token_e=1, mask_token_e=2, sep_token_e=3, bos_token_e=4, padding_token_r=0, cls_token_r=1, mask_token_r=2, sep_token_r=3, bos_token_r=4, padding_token_s=0, cls_token_s=1, mask_token_s=2, sep_token_s=3, bos_token_s=4, embedding_dim=128, entity_embedding_dim=128, relation_embedding_dim=64, separate_head_and_tail=False, batch_size=1, max_len=512, mask_percent=0.15, mask_mask_percent=0.8, mask_random_percent=0.1, mask_nomask_percent=0.1, no_use_pe=False, epoch=1500, lr=5e-05, lr_story=0.0001, lr_relation=1e-06, lr_entity=1e-06, valid_interval=10000, loss_weight_story=1.0, loss_weight_relation=1.0, loss_weight_entity=1.0, nhead=4, num_layers=4, dim_feedforward=1028, transformer_drop=0.1, position_encoder_drop=0.1, project_dir=PosixPath('/var/www'), logger=<Logger __main__ (DEBUG)>, device=device(type='cpu'), use_for_challenge090=False, old_data=2)

# %%
torch_fix_seed(seed=SEED)
return_dict = main_function(args, logger=logger)
# Out:
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 892 - ----- make datahelper start. -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 591 - ----- use old data (version 2) -----
# 2023-02-03 02:57:07 - INFO - data_helper.py - 333 - ====== Show MyRawData ======
# 2023-02-03 02:57:07 - INFO - data_helper.py - 334 - entity num: 7857
# 2023-02-03 02:57:07 - INFO - data_helper.py - 335 - relation num: 63
# 2023-02-03 02:57:07 - INFO - data_helper.py - 336 - ====== Show MyRawData ======
# 2023-02-03 02:57:07 - INFO - data_helper.py - 607 - ========== Show DataHelper ==========
# 2023-02-03 02:57:07 - INFO - data_helper.py - 333 - ====== Show MyRawData ======
# 2023-02-03 02:57:07 - INFO - data_helper.py - 334 - entity num: 7857
# 2023-02-03 02:57:07 - INFO - data_helper.py - 335 - relation num: 63
# 2023-02-03 02:57:07 - INFO - data_helper.py - 336 - ====== Show MyRawData ======
# 2023-02-03 02:57:07 - INFO - data_helper.py - 609 - entity_special_dicts: {0: '<pad_e>', 1: '<cls_e>', 2: '<mask_e>', 3: '<sep_e>', 4: '<bos_e>'}
# 2023-02-03 02:57:07 - INFO - data_helper.py - 610 - relation_special_dicts: {0: '<pad_r>', 1: '<cls_r>', 2: '<mask_r>', 3: '<sep_r>', 4: '<bos_r>'}
# 2023-02-03 02:57:07 - INFO - data_helper.py - 611 - processed entity num: 7862
# 2023-02-03 02:57:07 - INFO - data_helper.py - 612 - processed relation num: 68
# 2023-02-03 02:57:07 - INFO - data_helper.py - 613 - ========== Show DataHelper ==========
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 894 - ----- make datahelper complete. -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 896 - ----- make datasets start. -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 898 - ----- make datasets complete. -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 900 - ----- make dataloader start. -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 902 - ----- make dataloader complete. -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 904 - ----- make model start -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 747 -
# KgStoryTransformer03(
#   (entity_embeddings): Embedding(7862, 128, padding_idx=0)
#   (relation_embeddings): Embedding(68, 64, padding_idx=0)
#   (pe): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#     )
#   )
#   (norm_after_transformer): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (head_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7862, bias=True)
#   )
#   (relation_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=68, bias=True)
#   )
#   (tail_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7862, bias=True)
#   )
#   (input_activate): Feedforward(
#     (linear1): Linear(in_features=320, out_features=128, bias=False)
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 906 - ----- make model complete. -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 908 - ----- do train start -----
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 550 - load trainer and evaluator. then end
# 2023-02-03 02:57:07 - INFO - run_for_KGC.py - 911 - ----- do train complete -----

# %%
data_helper: MyDataHelper = return_dict[DATA_HELPER]
# Out:
# ['<pad_e>',
#  '<cls_e>',
#  '<mask_e>',
#  '<sep_e>',
#  '<bos_e>',
#  'AllTitle:Holmes',
#  'AllTitle:Watson',
#  'CrookedMan:slave_of_dwellers_of_mountain',
#  'SilverBlaze:Gypsy',
#  'ACaseOfIdentity:mother_of_Sutherland',
#  'DevilsFoot:George',
#  'SilverBlaze:William_Derbyshire',
#  'SilverBlaze:Stableman',
#  'SilverBlaze:Fitzroy_Simpson',
#  'SilverBlaze:Wasteland',
#  'SilverBlaze:Ned_Hunter_and_two_young_men',
#  'AbbeyGrange:Stanley_Hopkins',
#  'ACaseOfIdentity:Etheridge',
#  'ResidentPatient:Aspiring_specialists',
#  'AbbeyGrange:Only_one_woman',
#  'SilverBlaze:Edith_Baxter',
#  'AbbeyGrange:bracket',
#  'SpeckledBand:sister',
#  'SpeckledBand:Roylott',
#  'AbbeyGrange:Maid',
#  'CrookedMan:criminal',
#  'CrookedMan:Jane',
#  'CrookedMan:witness_of_Henry',
#  'DevilsFoot:Roundhay',
#  'SilverBlaze:Owner',
#  'SpeckledBand:Sleeping_Woman',
#  'DancingMen:New_face',
#  'SpeckledBand:housekeeper',
#  'DancingMen:Elsie',
#  'SpeckledBand:mother_of_Helen',
#  'AbbeyGrange:police',
#  'AbbeyGrange:accomplice',
#  'CrookedMan:criminal_of_incident',
#  'ACaseOfIdentity:father_of_Sutherland',
#  'SpeckledBand:man',
#  'SilverBlaze:Subordinates_of_Silas_Brown',
#  'CrookedMan:police',
#  'SilverBlaze:Jockey',
#  'SilverBlaze:Silas_Brown',
#  'AbbeyGrange:Burglary_team_of_Lewisham',
#  'AbbeyGrange:Lady_Brackenstall',
#  'AbbeyGrange:use',
#  'DevilsFoot:Doctor_Richard',
#  'SpeckledBand:culprit',
#  'CrookedMan:cook',
#  'CrookedMan:Morrison',
#  'ResidentPatient:Outpatients',
#  'ResidentPatient:The_identity_of_the_intruder',
#  'CrookedMan:resident',
#  'ResidentPatient:Cartwright',
#  'CrookedMan:Morison',
#  'CrookedMan:witness_of_Holmes',
#  'ACaseOfIdentity:Boy',
#  'AbbeyGrange:Jack_Croker',
#  'AbbeyGrange:appearance',
#  'ResidentPatient:others',
#  'ACaseOfIdentity:Woman',
#  'AbbeyGrange:The_Bays_Rock',
#  'DevilsFoot:Brenda',
#  'ResidentPatient:Conspirators',
#  'ResidentPatient:Russian_nobility',
#  'AbbeyGrange:maid',
#  'CrookedMan:owner_of_lodge',
#  'ResidentPatient:Corpses_enclosed_the_neck',
#  'ResidentPatient:Worthington_bank_Robbers',
#  'SilverBlaze:horse_trainer',
#  'SilverBlaze:horse_trainer_of_Colonel_Ross',
#  'SilverBlaze:Two_young_men',
#  'AbbeyGrange:All_of_maids',
#  'SpeckledBand:craftsman',
#  'ResidentPatient:Lanner_Inspector',
#  'SilverBlaze:People',
#  'SilverBlaze:A_group_of_Gypsy',
#  'ACaseOfIdentity:Windibank',
#  'ACaseOfIdentity:Sutherland',
#  'SilverBlaze:John_Straker',
#  'AbbeyGrange:Sailor',
#  'ResidentPatient:Criminal',
#  'ResidentPatient:Sutton',
#  'ACaseOfIdentity:Single_women',
#  'CrookedMan:Murphy',
#  'CrookedMan:dwellers_of_mountain',
#  'CrookedMan:someone',
#  'DancingMen:Horse_boy',
#  'DancingMen:Local_doctor',
#  'CrookedMan:father_of_Nancy',
#  'DevilsFoot:Mortimer',
#  'ResidentPatient:Elderly_man',
#  'AbbeyGrange:everyone',
#  'CrookedMan:anyone',
#  'CrookedMan:guest',
#  'SilverBlaze:Jockey_of_Colonel_Ross',
#  'SilverBlaze:murderer',
#  'ResidentPatient:Evidence_of_the_major_events_of_Worthingdon_bank',
#  'SilverBlaze:jockey',
#  'CrookedMan:old_friends_of_Henry',
#  'DancingMen:Criminal',
#  'ResidentPatient:living_person',
#  'SilverBlaze:Bookmaker_of_a_small_gambling',
#  'ResidentPatient:someone',
#  'AbbeyGrange:Behavior_of_Jack_Croker',
#  'DancingMen:Third_person',
#  'ACaseOfIdentity:hansom_carriage',
#  'AbbeyGrange:siblings_of_Lady_Brackenstall',
#  'ResidentPatient:Young_man',
#  'AbbeyGrange:criminal',
#  'ResidentPatient:Moderator_of_Tobin',
#  'AbbeyGrange:eight_maids',
#  'AbbeyGrange:sailor',
#  'CrookedMan:Nancy',
#  'DevilsFoot:Owen',
#  'DancingMen:Maid',
#  'CrookedMan:Henry',
#  'AbbeyGrange:Comparable_Officer',
#  'CrookedMan:soldier',
#  'CrookedMan:child',
#  'SilverBlaze:Inspector_Gregory',
#  'ResidentPatient:Major_event_of_Worthingdon_bank',
#  'SilverBlaze:Criminal',
#  'CrookedMan:coward',
#  'ResidentPatient:police',
#  'SpeckledBand:lieutenant_commander',
#  'SpeckledBand:Percy_Armitage',
#  'ResidentPatient:5th_man',
#  'SpeckledBand:sister_of_mother_of_Helen',
#  'ResidentPatient:invader',
#  'ResidentPatient:chest_of_Young_man',
#  'AbbeyGrange:Two_people',
#  'SpeckledBand:Roma',
#  'ResidentPatient:Man_entered_the_room_of_Blessington',
#  'AbbeyGrange:Train_crew',
#  'ResidentPatient:Blessington',
#  'SilverBlaze:Various_people',
#  'DancingMen:Cubitt',
#  'AbbeyGrange:Mary',
#  'DevilsFoot:Former_wife',
#  'SilverBlaze:Lord_Backwater',
#  'CrookedMan:David',
#  'AbbeyGrange:acrobat',
#  'ACaseOfIdentity:Ned',
#  'ResidentPatient:patient',
#  'CrookedMan:10000_rebels',
#  'SpeckledBand:mother_of_sister',
#  'SilverBlaze:Wife_of_John_Straker',
#  'ACaseOfIdentity:police',
#  'SilverBlaze:Ned_Hunter',
#  'CrookedMan:doctor',
#  'ResidentPatient:Helper_boy',
#  'ResidentPatient:Elderly_man_and_Young_man',
#  'DancingMen:father_of_Elsie',
#  'SilverBlaze:Silver_Blaze',
#  'ResidentPatient:cadaver',
#  'AbbeyGrange:Residents_of_Abbey_Grange',
#  'ACaseOfIdentity:Man',
#  'ResidentPatient:Robbery_of_the_indentation',
#  'AbbeyGrange:The_local_police',
#  'CrookedMan:Herny',
#  'AbbeyGrange:favorite_man',
#  'SpeckledBand:Julia',
#  'CrookedMan:coachman',
#  'AbbeyGrange:False_charge_person',
#  'ACaseOfIdentity:husband_of_Etheridge',
#  'ACaseOfIdentity:Hosmer',
#  'AbbeyGrange:Criminal',
#  'AbbeyGrange:Sir_Eustace_Brackenstall',
#  'DancingMen:Abe_Slaney',
#  'ACaseOfIdentity:parent',
#  'SilverBlaze:Man',
#  'SpeckledBand:villager_of_Stoke_Moran',
#  'DancingMen:Someone',
#  'SilverBlaze:children',
#  'AbbeyGrange:Old_man',
#  'ResidentPatient:police_officer',
#  'ResidentPatient:Face_of_elderly_man',
#  'SpeckledBand:coroner',
#  'DancingMen:Willson',
#  'CrookedMan:Barclay',
#  'CrookedMan:Simpson',
#  'AbbeyGrange:three_people',
#  'SilverBlaze:two_young_men',
#  'ResidentPatient:maid',
#  'CrookedMan:civilian',
#  'SilverBlaze:Colonel_Ross',
#  'ResidentPatient:face_of_young_man',
#  'SilverBlaze:Gypsy_of_Dartmoor',
#  'SilverBlaze:Gregory_Inspector',
#  'SilverBlaze:Youth_stables_number',
#  'DancingMen:Martin',
#  'ResidentPatient:The_third_person',
#  'CrookedMan:dwelleers_of_mountain',
#  'AbbeyGrange:Sir_Eustace_brackenstall',
#  'CrookedMan:Davide',
#  'CrookedMan:Monday',
#  'SpeckledBand:doctor_of_Stoke_Moran',
#  'SilverBlaze:police',
#  'ResidentPatient:Percy_Trevelyan',
#  'AbbeyGrange:Theresa',
#  'ACaseOfIdentity:Hardy',
#  'CrookedMan:rebels',
#  'SpeckledBand:Helen',
#  'CrookedMan:man',
#  'AbbeyGrange:001',
#  'AbbeyGrange:002',
#  'AbbeyGrange:003',
#  'AbbeyGrange:004',
#  'AbbeyGrange:005',
#  'AbbeyGrange:006',
#  'AbbeyGrange:007',
#  'AbbeyGrange:008',
#  'AbbeyGrange:009',
#  'AbbeyGrange:009a',
#  'AbbeyGrange:009b',
#  'AbbeyGrange:010',
#  'AbbeyGrange:011',
#  'AbbeyGrange:012',
#  'AbbeyGrange:013',
#  'AbbeyGrange:014',
#  'AbbeyGrange:015',
#  'AbbeyGrange:016',
#  'AbbeyGrange:017',
#  'AbbeyGrange:018',
#  'AbbeyGrange:018a',
#  'AbbeyGrange:019',
#  'AbbeyGrange:020',
#  'AbbeyGrange:021',
#  'AbbeyGrange:022',
#  'AbbeyGrange:023',
#  'AbbeyGrange:024',
#  'AbbeyGrange:025',
#  'AbbeyGrange:026',
#  'AbbeyGrange:027',
#  'AbbeyGrange:028',
#  'AbbeyGrange:028a',
#  'AbbeyGrange:029',
#  'AbbeyGrange:030',
#  'AbbeyGrange:031',
#  'AbbeyGrange:032',
#  'AbbeyGrange:033',
#  'AbbeyGrange:034',
#  'AbbeyGrange:035',
#  'AbbeyGrange:036',
#  'AbbeyGrange:037',
#  'AbbeyGrange:038',
#  'AbbeyGrange:039',
#  'AbbeyGrange:040',
#  'AbbeyGrange:041',
#  'AbbeyGrange:042',
#  'AbbeyGrange:043',
#  'AbbeyGrange:044',
#  'AbbeyGrange:045',
#  'AbbeyGrange:046',
#  'AbbeyGrange:047',
#  'AbbeyGrange:048',
#  'AbbeyGrange:049',
#  'AbbeyGrange:050',
#  'AbbeyGrange:051',
#  'AbbeyGrange:052',
#  'AbbeyGrange:053',
#  'AbbeyGrange:054',
#  'AbbeyGrange:055',
#  'AbbeyGrange:056',
#  'AbbeyGrange:057',
#  'AbbeyGrange:058',
#  'AbbeyGrange:059',
#  'AbbeyGrange:060',
#  'AbbeyGrange:061',
#  'AbbeyGrange:062',
#  'AbbeyGrange:063',
#  'AbbeyGrange:063a',
#  'AbbeyGrange:064',
#  'AbbeyGrange:065',
#  'AbbeyGrange:066',
#  'AbbeyGrange:067',
#  'AbbeyGrange:068',
#  'AbbeyGrange:069',
#  'AbbeyGrange:070',
#  'AbbeyGrange:071',
#  'AbbeyGrange:072',
#  'AbbeyGrange:073',
#  'AbbeyGrange:074',
#  'AbbeyGrange:075',
#  'AbbeyGrange:076',
#  'AbbeyGrange:077',
#  'AbbeyGrange:078',
#  'AbbeyGrange:079',
#  'AbbeyGrange:080',
#  'AbbeyGrange:081',
#  'AbbeyGrange:082',
#  'AbbeyGrange:083',
#  'AbbeyGrange:084',
#  'AbbeyGrange:085',
#  'AbbeyGrange:086',
#  'AbbeyGrange:087',
#  'AbbeyGrange:088',
#  'AbbeyGrange:089',
#  'AbbeyGrange:090',
#  'AbbeyGrange:090a',
#  'AbbeyGrange:091',
#  'AbbeyGrange:092',
#  'AbbeyGrange:093',
#  'AbbeyGrange:094',
#  'AbbeyGrange:095',
#  'AbbeyGrange:096',
#  'AbbeyGrange:097',
#  'AbbeyGrange:098',
#  'AbbeyGrange:099',
#  'AbbeyGrange:100',
#  'AbbeyGrange:101',
#  'AbbeyGrange:102',
#  'AbbeyGrange:103',
#  'AbbeyGrange:104',
#  'AbbeyGrange:105',
#  'AbbeyGrange:106',
#  'AbbeyGrange:107',
#  'AbbeyGrange:108',
#  'AbbeyGrange:109',
#  'AbbeyGrange:110',
#  'AbbeyGrange:111',
#  'AbbeyGrange:112',
#  'AbbeyGrange:113',
#  'AbbeyGrange:114',
#  'AbbeyGrange:115',
#  'AbbeyGrange:116',
#  'AbbeyGrange:117',
#  'AbbeyGrange:118',
#  'AbbeyGrange:119',
#  'AbbeyGrange:120',
#  'AbbeyGrange:121',
#  'AbbeyGrange:122',
#  'AbbeyGrange:123',
#  'AbbeyGrange:124',
#  'AbbeyGrange:125',
#  'AbbeyGrange:126',
#  'AbbeyGrange:127',
#  'AbbeyGrange:128',
#  'AbbeyGrange:129',
#  'AbbeyGrange:130',
#  'AbbeyGrange:131',
#  'AbbeyGrange:132',
#  'AbbeyGrange:133',
#  'AbbeyGrange:134',
#  'AbbeyGrange:135',
#  'AbbeyGrange:136',
#  'AbbeyGrange:137',
#  'AbbeyGrange:138',
#  'AbbeyGrange:139',
#  'AbbeyGrange:140',
#  'AbbeyGrange:141',
#  'AbbeyGrange:142',
#  'AbbeyGrange:143',
#  'AbbeyGrange:144',
#  'AbbeyGrange:145',
#  'AbbeyGrange:146',
#  'AbbeyGrange:147',
#  'AbbeyGrange:148',
#  'AbbeyGrange:149',
#  'AbbeyGrange:150',
#  'AbbeyGrange:151',
#  'AbbeyGrange:152',
#  'AbbeyGrange:153',
#  'AbbeyGrange:154',
#  'AbbeyGrange:155',
#  'AbbeyGrange:156',
#  'AbbeyGrange:157',
#  'AbbeyGrange:157a',
#  'AbbeyGrange:158',
#  'AbbeyGrange:159',
#  'AbbeyGrange:160',
#  'AbbeyGrange:161',
#  'AbbeyGrange:161a',
#  'AbbeyGrange:162',
#  'AbbeyGrange:163',
#  'AbbeyGrange:164',
#  'AbbeyGrange:165',
#  'AbbeyGrange:166',
#  'AbbeyGrange:167',
#  'AbbeyGrange:168',
#  'AbbeyGrange:169',
#  'AbbeyGrange:170',
#  'AbbeyGrange:171',
#  'AbbeyGrange:172',
#  'AbbeyGrange:173',
#  'AbbeyGrange:174',
#  'AbbeyGrange:175',
#  'AbbeyGrange:176',
#  'AbbeyGrange:177',
#  'AbbeyGrange:178',
#  'AbbeyGrange:179',
#  'AbbeyGrange:180',
#  'AbbeyGrange:180a',
#  'AbbeyGrange:181',
#  'AbbeyGrange:182',
#  'AbbeyGrange:183',
#  'AbbeyGrange:184',
#  'AbbeyGrange:185',
#  'AbbeyGrange:186',
#  'AbbeyGrange:187',
#  'AbbeyGrange:188',
#  'AbbeyGrange:189',
#  'AbbeyGrange:190',
#  'AbbeyGrange:191',
#  'AbbeyGrange:192',
#  'AbbeyGrange:193',
#  'AbbeyGrange:194',
#  'AbbeyGrange:195',
#  'AbbeyGrange:196',
#  'AbbeyGrange:197',
#  'AbbeyGrange:198',
#  'AbbeyGrange:199',
#  'AbbeyGrange:200',
#  'AbbeyGrange:201',
#  'AbbeyGrange:202',
#  'AbbeyGrange:203',
#  'AbbeyGrange:204',
#  'AbbeyGrange:205',
#  'AbbeyGrange:206',
#  'AbbeyGrange:207',
#  'AbbeyGrange:208',
#  'AbbeyGrange:209',
#  'AbbeyGrange:210',
#  'AbbeyGrange:211',
#  'AbbeyGrange:212',
#  'AbbeyGrange:213',
#  'AbbeyGrange:214',
#  'AbbeyGrange:215',
#  'AbbeyGrange:216',
#  'AbbeyGrange:217',
#  'AbbeyGrange:218',
#  'AbbeyGrange:219',
#  'AbbeyGrange:220',
#  'AbbeyGrange:221',
#  'AbbeyGrange:222',
#  'AbbeyGrange:223',
#  'AbbeyGrange:224',
#  'AbbeyGrange:225',
#  'AbbeyGrange:226',
#  'AbbeyGrange:227',
#  'AbbeyGrange:228',
#  'AbbeyGrange:229',
#  'AbbeyGrange:230',
#  'AbbeyGrange:231',
#  'AbbeyGrange:232',
#  'AbbeyGrange:233',
#  'AbbeyGrange:234',
#  'AbbeyGrange:235',
#  'AbbeyGrange:236',
#  'AbbeyGrange:237',
#  'AbbeyGrange:238',
#  'AbbeyGrange:239',
#  'AbbeyGrange:240',
#  'AbbeyGrange:241',
#  'AbbeyGrange:242',
#  'AbbeyGrange:243',
#  'AbbeyGrange:244',
#  'AbbeyGrange:245',
#  'AbbeyGrange:246',
#  'AbbeyGrange:247',
#  'AbbeyGrange:248',
#  'AbbeyGrange:249',
#  'AbbeyGrange:250',
#  'AbbeyGrange:251',
#  'AbbeyGrange:252',
#  'AbbeyGrange:252a',
#  'AbbeyGrange:253',
#  'AbbeyGrange:254',
#  'AbbeyGrange:254a',
#  'AbbeyGrange:255',
#  'AbbeyGrange:256',
#  'AbbeyGrange:257',
#  'AbbeyGrange:258',
#  'AbbeyGrange:259',
#  'AbbeyGrange:260',
#  'AbbeyGrange:261',
#  'AbbeyGrange:262',
#  'AbbeyGrange:263',
#  'AbbeyGrange:264',
#  'AbbeyGrange:265',
#  'AbbeyGrange:266',
#  'AbbeyGrange:267',
#  'AbbeyGrange:268',
#  'AbbeyGrange:269',
#  'AbbeyGrange:270',
#  'AbbeyGrange:271',
#  'AbbeyGrange:272',
#  'AbbeyGrange:273',
#  'AbbeyGrange:274',
#  'AbbeyGrange:275',
#  'AbbeyGrange:276',
#  'AbbeyGrange:277',
#  'AbbeyGrange:278',
#  'AbbeyGrange:279',
#  'AbbeyGrange:280',
#  'AbbeyGrange:281',
#  'AbbeyGrange:282',
#  'AbbeyGrange:283',
#  'AbbeyGrange:284',
#  'AbbeyGrange:285',
#  'AbbeyGrange:286',
#  'AbbeyGrange:287',
#  'AbbeyGrange:288',
#  'AbbeyGrange:288a',
#  'AbbeyGrange:289',
#  'AbbeyGrange:289a',
#  'AbbeyGrange:290',
#  'AbbeyGrange:291',
#  'AbbeyGrange:292',
#  'AbbeyGrange:292a',
#  'AbbeyGrange:293',
#  'AbbeyGrange:294',
#  'AbbeyGrange:295',
#  'AbbeyGrange:296',
#  'AbbeyGrange:297',
#  'AbbeyGrange:298',
#  'AbbeyGrange:299',
#  'AbbeyGrange:300',
#  'AbbeyGrange:301',
#  'AbbeyGrange:302',
#  'AbbeyGrange:303',
#  'AbbeyGrange:304',
#  'AbbeyGrange:305',
#  'AbbeyGrange:306',
#  'AbbeyGrange:307',
#  'AbbeyGrange:308',
#  'AbbeyGrange:309',
#  'AbbeyGrange:310',
#  'AbbeyGrange:311',
#  'AbbeyGrange:312',
#  'AbbeyGrange:312a',
#  'AbbeyGrange:313',
#  'AbbeyGrange:314',
#  'AbbeyGrange:315',
#  'AbbeyGrange:316',
#  'AbbeyGrange:316a',
#  'AbbeyGrange:317',
#  'AbbeyGrange:318',
#  'AbbeyGrange:319',
#  'AbbeyGrange:319a',
#  'AbbeyGrange:320',
#  'AbbeyGrange:321',
#  'AbbeyGrange:322',
#  'AbbeyGrange:323',
#  'AbbeyGrange:324',
#  'AbbeyGrange:325',
#  'AbbeyGrange:326',
#  'AbbeyGrange:327',
#  'AbbeyGrange:328',
#  'AbbeyGrange:329',
#  'AbbeyGrange:330',
#  'AbbeyGrange:331',
#  'AbbeyGrange:332',
#  'AbbeyGrange:333',
#  'AbbeyGrange:334',
#  'AbbeyGrange:335',
#  'AbbeyGrange:336',
#  'AbbeyGrange:337',
#  'AbbeyGrange:338',
#  'AbbeyGrange:339',
#  'AbbeyGrange:340',
#  'AbbeyGrange:341',
#  'AbbeyGrange:342',
#  'AbbeyGrange:343',
#  'AbbeyGrange:344',
#  'AbbeyGrange:345',
#  'AbbeyGrange:346',
#  'AbbeyGrange:347',
#  'AbbeyGrange:348',
#  'AbbeyGrange:349',
#  'AbbeyGrange:350',
#  'AbbeyGrange:351',
#  'AbbeyGrange:352',
#  'AbbeyGrange:353',
#  'AbbeyGrange:354',
#  'AbbeyGrange:355',
#  'AbbeyGrange:356',
#  'AbbeyGrange:357',
#  'AbbeyGrange:358',
#  'AbbeyGrange:359',
#  'AbbeyGrange:360',
#  'AbbeyGrange:361',
#  'AbbeyGrange:362',
#  'AbbeyGrange:363',
#  'AbbeyGrange:364',
#  'AbbeyGrange:365',
#  'AbbeyGrange:366',
#  'AbbeyGrange:367',
#  'AbbeyGrange:368',
#  'AbbeyGrange:369',
#  'AbbeyGrange:370',
#  'AbbeyGrange:371',
#  'AbbeyGrange:372',
#  'AbbeyGrange:373',
#  'AbbeyGrange:374',
#  'AbbeyGrange:375',
#  'AbbeyGrange:376',
#  'AbbeyGrange:377',
#  'AbbeyGrange:378',
#  'AbbeyGrange:379',
#  'AbbeyGrange:380',
#  'AbbeyGrange:381',
#  'AbbeyGrange:382',
#  'AbbeyGrange:383',
#  'AbbeyGrange:384',
#  'AbbeyGrange:385',
#  'AbbeyGrange:386',
#  'AbbeyGrange:387',
#  'AbbeyGrange:388',
#  'AbbeyGrange:389',
#  'AbbeyGrange:390',
#  'AbbeyGrange:391',
#  'AbbeyGrange:392',
#  'AbbeyGrange:392a',
#  'AbbeyGrange:393',
#  'AbbeyGrange:394',
#  'AbbeyGrange:395',
#  'AbbeyGrange:396',
#  'AbbeyGrange:397',
#  'AbbeyGrange:398',
#  'AbbeyGrange:399',
#  'AbbeyGrange:399a',
#  'AbbeyGrange:400',
#  'AbbeyGrange:401',
#  'AbbeyGrange:402',
#  'AbbeyGrange:403',
#  'AbbeyGrange:404',
#  'AbbeyGrange:405',
#  'AbbeyGrange:406',
#  'AbbeyGrange:407',
#  'AbbeyGrange:408',
#  'AbbeyGrange:409',
#  'AbbeyGrange:410',
#  'AbbeyGrange:411',
#  'AbbeyGrange:412',
#  'AbbeyGrange:413',
#  'AbbeyGrange:414',
#  'ACaseOfIdentity:001',
#  'ACaseOfIdentity:002',
#  'ACaseOfIdentity:004',
#  'ACaseOfIdentity:004a',
#  'ACaseOfIdentity:005',
#  'ACaseOfIdentity:006',
#  'ACaseOfIdentity:007',
#  'ACaseOfIdentity:008',
#  'ACaseOfIdentity:010',
#  'ACaseOfIdentity:011',
#  'ACaseOfIdentity:012',
#  'ACaseOfIdentity:013',
#  'ACaseOfIdentity:014',
#  'ACaseOfIdentity:015',
#  'ACaseOfIdentity:016',
#  'ACaseOfIdentity:017',
#  'ACaseOfIdentity:018',
#  'ACaseOfIdentity:019',
#  'ACaseOfIdentity:020',
#  'ACaseOfIdentity:021',
#  'ACaseOfIdentity:021a',
#  'ACaseOfIdentity:022',
#  'ACaseOfIdentity:023',
#  'ACaseOfIdentity:024',
#  'ACaseOfIdentity:025',
#  'ACaseOfIdentity:026',
#  'ACaseOfIdentity:027',
#  'ACaseOfIdentity:028',
#  'ACaseOfIdentity:029',
#  'ACaseOfIdentity:030',
#  'ACaseOfIdentity:031',
#  'ACaseOfIdentity:032',
#  'ACaseOfIdentity:033',
#  'ACaseOfIdentity:033a',
#  'ACaseOfIdentity:034',
#  'ACaseOfIdentity:035',
#  'ACaseOfIdentity:036',
#  'ACaseOfIdentity:037',
#  'ACaseOfIdentity:038',
#  'ACaseOfIdentity:039',
#  'ACaseOfIdentity:040',
#  'ACaseOfIdentity:041',
#  'ACaseOfIdentity:042',
#  'ACaseOfIdentity:043',
#  'ACaseOfIdentity:044',
#  'ACaseOfIdentity:045',
#  'ACaseOfIdentity:047',
#  'ACaseOfIdentity:048',
#  'ACaseOfIdentity:049',
#  'ACaseOfIdentity:051',
#  'ACaseOfIdentity:052',
#  'ACaseOfIdentity:053',
#  'ACaseOfIdentity:054',
#  'ACaseOfIdentity:055',
#  'ACaseOfIdentity:056',
#  'ACaseOfIdentity:057',
#  'ACaseOfIdentity:058',
#  'ACaseOfIdentity:060',
#  'ACaseOfIdentity:062',
#  'ACaseOfIdentity:063',
#  'ACaseOfIdentity:064',
#  'ACaseOfIdentity:065',
#  'ACaseOfIdentity:066',
#  'ACaseOfIdentity:067',
#  'ACaseOfIdentity:067a',
#  'ACaseOfIdentity:068',
#  'ACaseOfIdentity:069',
#  'ACaseOfIdentity:070',
#  'ACaseOfIdentity:071',
#  'ACaseOfIdentity:071a',
#  'ACaseOfIdentity:072',
#  'ACaseOfIdentity:073',
#  'ACaseOfIdentity:074',
#  'ACaseOfIdentity:075',
#  'ACaseOfIdentity:076',
#  'ACaseOfIdentity:077',
#  'ACaseOfIdentity:078',
#  'ACaseOfIdentity:079',
#  'ACaseOfIdentity:079a',
#  'ACaseOfIdentity:080',
#  'ACaseOfIdentity:081',
#  'ACaseOfIdentity:082',
#  'ACaseOfIdentity:083',
#  'ACaseOfIdentity:084',
#  'ACaseOfIdentity:085',
#  'ACaseOfIdentity:086',
#  'ACaseOfIdentity:087',
#  'ACaseOfIdentity:088',
#  'ACaseOfIdentity:089',
#  'ACaseOfIdentity:090',
#  'ACaseOfIdentity:091',
#  'ACaseOfIdentity:092',
#  'ACaseOfIdentity:093',
#  'ACaseOfIdentity:094',
#  'ACaseOfIdentity:095',
#  'ACaseOfIdentity:096',
#  'ACaseOfIdentity:097',
#  'ACaseOfIdentity:098',
#  'ACaseOfIdentity:099',
#  'ACaseOfIdentity:100',
#  'ACaseOfIdentity:101',
#  'ACaseOfIdentity:102',
#  'ACaseOfIdentity:103',
#  'ACaseOfIdentity:104',
#  'ACaseOfIdentity:105',
#  'ACaseOfIdentity:106',
#  'ACaseOfIdentity:107',
#  'ACaseOfIdentity:108',
#  'ACaseOfIdentity:109',
#  'ACaseOfIdentity:110',
#  'ACaseOfIdentity:111',
#  'ACaseOfIdentity:112',
#  'ACaseOfIdentity:113',
#  'ACaseOfIdentity:114',
#  'ACaseOfIdentity:115',
#  'ACaseOfIdentity:116',
#  'ACaseOfIdentity:117',
#  'ACaseOfIdentity:118',
#  'ACaseOfIdentity:119',
#  'ACaseOfIdentity:120',
#  'ACaseOfIdentity:121',
#  'ACaseOfIdentity:122',
#  'ACaseOfIdentity:122a',
#  'ACaseOfIdentity:123',
#  'ACaseOfIdentity:124',
#  'ACaseOfIdentity:125',
#  'ACaseOfIdentity:126',
#  'ACaseOfIdentity:127',
#  'ACaseOfIdentity:128',
#  'ACaseOfIdentity:130',
#  'ACaseOfIdentity:131',
#  'ACaseOfIdentity:132',
#  'ACaseOfIdentity:133',
#  'ACaseOfIdentity:134',
#  'ACaseOfIdentity:135',
#  'ACaseOfIdentity:136',
#  'ACaseOfIdentity:137',
#  'ACaseOfIdentity:138',
#  'ACaseOfIdentity:139',
#  'ACaseOfIdentity:140',
#  'ACaseOfIdentity:141',
#  'ACaseOfIdentity:142',
#  'ACaseOfIdentity:143',
#  'ACaseOfIdentity:144',
#  'ACaseOfIdentity:145',
#  'ACaseOfIdentity:146',
#  'ACaseOfIdentity:147',
#  'ACaseOfIdentity:148',
#  'ACaseOfIdentity:149',
#  'ACaseOfIdentity:150',
#  'ACaseOfIdentity:151',
#  'ACaseOfIdentity:152',
#  'ACaseOfIdentity:153',
#  'ACaseOfIdentity:154',
#  'ACaseOfIdentity:155',
#  'ACaseOfIdentity:156',
#  'ACaseOfIdentity:157',
#  'ACaseOfIdentity:158',
#  'ACaseOfIdentity:159',
#  'ACaseOfIdentity:160',
#  'ACaseOfIdentity:161',
#  'ACaseOfIdentity:163',
#  'ACaseOfIdentity:164',
#  'ACaseOfIdentity:165',
#  'ACaseOfIdentity:166',
#  'ACaseOfIdentity:167',
#  'ACaseOfIdentity:168',
#  'ACaseOfIdentity:169',
#  'ACaseOfIdentity:170',
#  'ACaseOfIdentity:171',
#  'ACaseOfIdentity:172',
#  'ACaseOfIdentity:173',
#  'ACaseOfIdentity:174',
#  'ACaseOfIdentity:176',
#  'ACaseOfIdentity:178',
#  'ACaseOfIdentity:179',
#  'ACaseOfIdentity:179a',
#  'ACaseOfIdentity:180',
#  'ACaseOfIdentity:181',
#  'ACaseOfIdentity:182',
#  'ACaseOfIdentity:183',
#  'ACaseOfIdentity:184',
#  'ACaseOfIdentity:185',
#  'ACaseOfIdentity:186',
#  'ACaseOfIdentity:187',
#  'ACaseOfIdentity:188',
#  'ACaseOfIdentity:192',
#  'ACaseOfIdentity:193',
#  'ACaseOfIdentity:194',
#  'ACaseOfIdentity:195',
#  'ACaseOfIdentity:196',
#  'ACaseOfIdentity:197',
#  'ACaseOfIdentity:198',
#  'ACaseOfIdentity:199',
#  'ACaseOfIdentity:200',
#  'ACaseOfIdentity:201',
#  'ACaseOfIdentity:202',
#  'ACaseOfIdentity:203',
#  'ACaseOfIdentity:203a',
#  'ACaseOfIdentity:204',
#  'ACaseOfIdentity:205',
#  'ACaseOfIdentity:205a',
#  'ACaseOfIdentity:206',
#  'ACaseOfIdentity:207',
#  'ACaseOfIdentity:208',
#  'ACaseOfIdentity:209',
#  'ACaseOfIdentity:210',
#  'ACaseOfIdentity:211',
#  'ACaseOfIdentity:212',
#  'ACaseOfIdentity:213',
#  'ACaseOfIdentity:214',
#  'ACaseOfIdentity:215',
#  'ACaseOfIdentity:216',
#  'ACaseOfIdentity:216a',
#  'ACaseOfIdentity:217',
#  'ACaseOfIdentity:218',
#  'ACaseOfIdentity:219',
#  'ACaseOfIdentity:220',
#  'ACaseOfIdentity:221',
#  'ACaseOfIdentity:223',
#  'ACaseOfIdentity:224',
#  'ACaseOfIdentity:226',
#  'ACaseOfIdentity:227',
#  'ACaseOfIdentity:228',
#  'ACaseOfIdentity:228a',
#  'ACaseOfIdentity:229',
#  'ACaseOfIdentity:230',
#  'ACaseOfIdentity:231',
#  'ACaseOfIdentity:232',
#  'ACaseOfIdentity:233',
#  'ACaseOfIdentity:234',
#  'ACaseOfIdentity:235',
#  'ACaseOfIdentity:236',
#  'ACaseOfIdentity:237',
#  'ACaseOfIdentity:239',
#  'ACaseOfIdentity:240',
#  'ACaseOfIdentity:241',
#  'ACaseOfIdentity:242',
#  'ACaseOfIdentity:243',
#  'ACaseOfIdentity:244',
#  'ACaseOfIdentity:245',
#  'ACaseOfIdentity:247',
#  'ACaseOfIdentity:248',
#  'ACaseOfIdentity:249',
#  'ACaseOfIdentity:250',
#  'ACaseOfIdentity:252',
#  'ACaseOfIdentity:253',
#  'ACaseOfIdentity:254',
#  'ACaseOfIdentity:255',
#  'ACaseOfIdentity:256',
#  'ACaseOfIdentity:257',
#  'ACaseOfIdentity:258',
#  'ACaseOfIdentity:259',
#  'ACaseOfIdentity:260',
#  'ACaseOfIdentity:261',
#  'ACaseOfIdentity:262',
#  'ACaseOfIdentity:263',
#  'ACaseOfIdentity:264',
#  'ACaseOfIdentity:265',
#  'ACaseOfIdentity:266',
#  'ACaseOfIdentity:267',
#  'ACaseOfIdentity:268',
#  'ACaseOfIdentity:269',
#  'ACaseOfIdentity:270',
#  'ACaseOfIdentity:271',
#  'ACaseOfIdentity:272',
#  'ACaseOfIdentity:273',
#  'ACaseOfIdentity:274',
#  'ACaseOfIdentity:275',
#  'ACaseOfIdentity:276',
#  'ACaseOfIdentity:277',
#  'ACaseOfIdentity:278',
#  'ACaseOfIdentity:279',
#  'ACaseOfIdentity:280',
#  'ACaseOfIdentity:281',
#  'ACaseOfIdentity:282',
#  'ACaseOfIdentity:283',
#  'ACaseOfIdentity:284',
#  'ACaseOfIdentity:285',
#  'ACaseOfIdentity:286',
#  'ACaseOfIdentity:287',
#  'ACaseOfIdentity:288',
#  'ACaseOfIdentity:289',
#  'ACaseOfIdentity:290',
#  'ACaseOfIdentity:290a',
#  'ACaseOfIdentity:291',
#  'ACaseOfIdentity:292',
#  'ACaseOfIdentity:293',
#  'ACaseOfIdentity:294',
#  'ACaseOfIdentity:295',
#  'ACaseOfIdentity:296',
#  'ACaseOfIdentity:297',
#  'ACaseOfIdentity:298',
#  'ACaseOfIdentity:299',
#  'ACaseOfIdentity:300',
#  'ACaseOfIdentity:301',
#  'ACaseOfIdentity:302',
#  'ACaseOfIdentity:303',
#  'ACaseOfIdentity:304',
#  'ACaseOfIdentity:305',
#  'ACaseOfIdentity:306',
#  'ACaseOfIdentity:307',
#  'ACaseOfIdentity:308',
#  'ACaseOfIdentity:309',
#  'ACaseOfIdentity:310',
#  'ACaseOfIdentity:311',
#  'ACaseOfIdentity:312',
#  'ACaseOfIdentity:313',
#  'ACaseOfIdentity:314',
#  'ACaseOfIdentity:315',
#  'ACaseOfIdentity:316',
#  'ACaseOfIdentity:317',
#  'ACaseOfIdentity:318',
#  'ACaseOfIdentity:319',
#  'ACaseOfIdentity:321',
#  'ACaseOfIdentity:322',
#  'ACaseOfIdentity:323',
#  'ACaseOfIdentity:324',
#  'ACaseOfIdentity:325',
#  'ACaseOfIdentity:326',
#  'ACaseOfIdentity:327',
#  'ACaseOfIdentity:328',
#  'ACaseOfIdentity:329',
#  'ACaseOfIdentity:330',
#  'ACaseOfIdentity:331',
#  'ACaseOfIdentity:332',
#  'ACaseOfIdentity:333',
#  'ACaseOfIdentity:334',
#  'ACaseOfIdentity:335',
#  'ACaseOfIdentity:336',
#  'ACaseOfIdentity:337',
#  'ACaseOfIdentity:339',
#  'ACaseOfIdentity:341',
#  'ACaseOfIdentity:342',
#  'ACaseOfIdentity:343',
#  'ACaseOfIdentity:345',
#  'ACaseOfIdentity:346',
#  'ACaseOfIdentity:348',
#  'ACaseOfIdentity:349',
#  'ACaseOfIdentity:350',
#  'ACaseOfIdentity:351',
#  'ACaseOfIdentity:352',
#  'ACaseOfIdentity:353',
#  'ACaseOfIdentity:354',
#  'ACaseOfIdentity:355',
#  'ACaseOfIdentity:356',
#  'ACaseOfIdentity:357',
#  'ACaseOfIdentity:358',
#  'ACaseOfIdentity:359',
#  'ACaseOfIdentity:360',
#  'ACaseOfIdentity:361',
#  'ACaseOfIdentity:362',
#  'ACaseOfIdentity:363',
#  'ACaseOfIdentity:364',
#  'ACaseOfIdentity:365',
#  'ACaseOfIdentity:366',
#  'ACaseOfIdentity:367',
#  'ACaseOfIdentity:368',
#  'ACaseOfIdentity:369',
#  'ACaseOfIdentity:370',
#  'ACaseOfIdentity:371',
#  ...]

# %%
model
# Out:
# KgStoryTransformer03(
#   (entity_embeddings): Embedding(7862, 128, padding_idx=0)
#   (relation_embeddings): Embedding(68, 64, padding_idx=0)
#   (pe): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#     )
#   )
#   (norm_after_transformer): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (head_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7862, bias=True)
#   )
#   (relation_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=68, bias=True)
#   )
#   (tail_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7862, bias=True)
#   )
#   (input_activate): Feedforward(
#     (linear1): Linear(in_features=320, out_features=128, bias=False)
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=128, bias=True)
#   )
# )

# %%
model = return_dict[MODEL]

dataset_train: StoryTriple = return_dict[DATASETS][0]
triple: torch.Tensor = dataset_train.triple
data_helper: MyDataHelper = return_dict[DATA_HELPER]
evaluator: Checkpoint = return_dict[TRAIN_RETURNS][EVALUATOR]

load_model(model, args.model_path, device)
model.eval()

entities, relations = data_helper.processed_entities, data_helper.processed_relations
d_e, d_r = {e: i for i, e in enumerate(entities)}, {r: i for i, r in enumerate(relations)}

triple_df = pd.DataFrame([(entities[_t[0]], relations[_t[1]], entities[_t[2]]) for _t in triple], columns=[HEAD, RELATION, TAIL])
story_entities = triple_df[HEAD].tolist()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 8
#       5 data_helper: MyDataHelper = return_dict[DATA_HELPER]
#       6 evaluator: Checkpoint = return_dict[TRAIN_RETURNS][EVALUATOR]
# ----> 8 load_model(model, args.model_path, device)
#       9 model.eval()
#      11 entities, relations = data_helper.processed_entities, data_helper.processed_relations
#
# File ~/Documents/学校/M1Study/knowledge_graph/src/utils/torch.py:151, in load_model(model, model_path, device, delete_file)
#     146 """
#     147 load model function. if `delete_file' is True, delete file after loaded.
#     148 Returns: model.
#     149 """
#     150 with force_cpu(model, device):
# --> 151     model.load_state_dict(torch.load(model_path))
#     152     if delete_file:
#     153         os.remove(model_path)
#
# File ~/Library/Caches/pypoetry/virtualenvs/knowledge-graph-GsKW7g2h-py3.10/lib/python3.10/site-packages/torch/nn/modules/module.py:1671, in Module.load_state_dict(self, state_dict, strict)
#    1666         error_msgs.insert(
#    1667             0, 'Missing key(s) in state_dict: {}. '.format(
#    1668                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1670 if len(error_msgs) > 0:
# -> 1671     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1672                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1673 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for KgStoryTransformer03:
# 	size mismatch for entity_embeddings.weight: copying a param with shape torch.Size([7849, 128]) from checkpoint, the shape in current model is torch.Size([7862, 128]).
# 	size mismatch for head_maskdlm.linear2.weight: copying a param with shape torch.Size([7849, 128]) from checkpoint, the shape in current model is torch.Size([7862, 128]).
# 	size mismatch for head_maskdlm.linear2.bias: copying a param with shape torch.Size([7849]) from checkpoint, the shape in current model is torch.Size([7862]).
# 	size mismatch for tail_maskdlm.linear2.weight: copying a param with shape torch.Size([7849, 128]) from checkpoint, the shape in current model is torch.Size([7862, 128]).
# 	size mismatch for tail_maskdlm.linear2.bias: copying a param with shape torch.Size([7849]) from checkpoint, the shape in current model is torch.Size([7862]).

# %%
torch_fix_seed(seed=SEED)
model, data_dict = main_function(args, logger=logger)
encoder_last_layer = model.transformer.layers[-1]
model.eval()
dataset_train, dataset_valid, dataset_test = data_dict['datasets']
triple = dataset_train.triple
data_helper = data_dict['data_helper']
evaluator = data_dict['train_items']['evaluator']
load_model(model, args.model_path, device)
from run_for_KGC import get_all_tokens
to_token = "{}".format
PAD_E = to_token("pad_e")
CLS_E = to_token('cls_e')
MASK_E: Final[str] = to_token('mask_e')
SEP_E: Final[str] = to_token('sep_e')
BOS_E: Final[str] = to_token('bos_e')
PAD_R: Final[str] = to_token('pad_r')
CLS_R: Final[str] = to_token('cls_r')
MASK_R: Final[str] = to_token('mask_r')
SEP_R: Final[str] = to_token('sep_r')
BOS_R: Final[str] = to_token('bos_r')

((pad_token_e, pad_token_r), (cls_token_e, cls_token_r), (mask_token_e, mask_token_r),
     (sep_token_e, sep_token_r), (bos_token_e, bos_token_r)) = get_all_tokens(args)

data_helper.set_special_names(
    index2name_entity={pad_token_e: PAD_E, cls_token_e: CLS_E, mask_token_e: MASK_E, sep_token_e: SEP_E, bos_token_e: BOS_E},
    index2name_relation={pad_token_r: PAD_R, cls_token_r: CLS_R, mask_token_r: MASK_R, sep_token_r: SEP_R, bos_token_r: BOS_R},
)
entities = data_helper.processed_entities
d_e = {e: i for i, e in enumerate(entities)}
relations = data_helper.processed_relations
d_r = {r: i for i, r in enumerate(relations)}
triple_df = pd.DataFrame([(entities[_t[0]], relations[_t[1]], entities[_t[2]]) for _t in triple], columns=['head', 'relation', 'tail']) 
# story_entities = triple_df
# triple_df
# Out:
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 775 - ----- make datahelper start. -----
# 2023-01-01 10:40:47 - INFO - data_helper.py - 207 - ==========Show MyRawData==========
# 2023-01-01 10:40:47 - INFO - data_helper.py - 208 - entity_length: 7844
# 2023-01-01 10:40:47 - INFO - data_helper.py - 209 - relation_length: 63
# 2023-01-01 10:40:47 - INFO - data_helper.py - 212 - ==========Show MyRawData==========
# 2023-01-01 10:40:47 - INFO - data_helper.py - 440 - ==========Show DataHelper==========
# 2023-01-01 10:40:47 - INFO - data_helper.py - 441 - ==========
# 2023-01-01 10:40:47 - INFO - data_helper.py - 207 - ==========Show MyRawData==========
# 2023-01-01 10:40:47 - INFO - data_helper.py - 208 - entity_length: 7844
# 2023-01-01 10:40:47 - INFO - data_helper.py - 209 - relation_length: 63
# 2023-01-01 10:40:47 - INFO - data_helper.py - 212 - ==========Show MyRawData==========
# 2023-01-01 10:40:47 - INFO - data_helper.py - 443 - ==========
# 2023-01-01 10:40:47 - INFO - data_helper.py - 445 - entity_special_num: 5
# 2023-01-01 10:40:47 - INFO - data_helper.py - 446 - relation_special_num: 5
# 2023-01-01 10:40:47 - INFO - data_helper.py - 447 - ==========Show DataHelper==========
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 777 - ----- make datahelper complete. -----
# /var/www/src/run_for_KGC.py:655: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   triple = add_bos(triple, bos_token_e, bos_token_r, bos_token_e)
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 780 - ----- make and set dataloader start. -----
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 782 - ----- make and set dataloader complete. -----
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 784 - ----- make model start -----
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 756 - KgStoryTransformer03(
#   (entity_embeddings): Embedding(7849, 128, padding_idx=0)
#   (relation_embeddings): Embedding(68, 64, padding_idx=0)
#   (pe): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#     )
#   )
#   (norm_after_transformer): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (head_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7849, bias=True)
#   )
#   (relation_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=68, bias=True)
#   )
#   (tail_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7849, bias=True)
#   )
#   (input_activate): Feedforward(
#     (linear1): Linear(in_features=320, out_features=128, bias=False)
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 786 - ----- make model complete. -----
# 2023-01-01 10:40:47 - INFO - run_for_KGC.py - 531 - load trainer and evaluator. then end

# %%
def extract(model, target, inputs):
    feature = None

    def forward_hook(module, inputs, _):
        # 順伝搬の出力を features というグローバル変数に記録する
        global features
        # 1. detach でグラフから切り離す。
        # 2. clone() でテンソルを複製する。モデルのレイヤーで ReLU(inplace=True) のように
        #    inplace で行う層があると、値がその後のレイヤーで書き換えられてまい、
        #    指定した層の出力が取得できない可能性があるため、clone() が必要。
        x, _, _ = inputs
        outputs = module.forward(x, x, x, need_weights=True)[1]
        features = outputs.detach().clone()

    # コールバック関数を登録する。
    handle = target.register_forward_hook(forward_hook)

    # 推論する
    model.eval()
    model(inputs, torch.LongTensor([[]]), torch.LongTensor([[]]), torch.LongTensor([[]]))

    # コールバック関数を解除する。
    handle.remove()

    return features

# %%
def heatmap_(index):
    input_ = dataset[index]
    # display([(i, entities[h], relations[r], entities[t]) for i, (h, r, t) in enumerate(input_)])
    features = extract(model, encoder_last_layer.self_attn, dataset[0][None, :])[0]
    df_atten = pd.DataFrame([[entities[h], relations[r], entities[t]]+[features[j, i].item() for j in range(len(features))] for i, (h, r, t) in enumerate(input_)])
    df_atten.columns=['head', 'relation', 'tail',] + [f'atten_from{i}' for i in range(len(df_atten.columns)-3)]
    display(df_atten)
    # ヒートマップの作成
    # sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
    for i in range(len(df_atten)):
        display(i, df_atten.iloc[i,:3].tolist())
        display(df_atten.sort_values(f'atten_from{i}', ascending=False).iloc[:10,:3])
        print("----------")
    plt.show()
# heatmap_(300)

# %%
def make_heatmap2_(input_):
    assert len(input_) == 1
    features = extract(model, encoder_last_layer.self_attn, input_)[0]
    df_atten = pd.DataFrame([[entities[h], relations[r], entities[t]]+[features[j, i].item() for j in range(len(features))] for i, (h, r, t) in enumerate(input_[0])])
    df_atten.columns=['head', 'relation', 'tail',] + [f'atten_from{i}' for i in range(len(df_atten.columns)-3)]
    sns.heatmap(df_atten.iloc[:,3:])
    plt.show()
    return df_atten

# %%
story_entities = triple_df['head'].tolist()

# %%
def make_ranking(_from, _to, _predicate, _whom, _subject, _why, _what, _where):
    if not (_from is None and _to is None):
        _start_index = story_entities.index(_from)-1 
        _end_index = len(story_entities) - story_entities[::-1].index(_to)
    else: 
        _start_index = 0
        _end_index = 0
    question_ = torch.tensor(
        [
            [d_e['bos_e'],d_r['bos_r'],d_e['bos_e']],
            [d_e['mask_e'],d_r['kgc:infoSource'],d_e['AllTitle:Holmes']],
            [d_e['mask_e'],d_r['kgc:hasPredicate'],d_e[_predicate]],
            [d_e['mask_e'],d_r['kgc:whom'],d_e[_whom]],
            [d_e['mask_e'],d_r['kgc:subject'],d_e[_subject]],
            [d_e['mask_e'],d_r['kgc:why'],d_e[_why]],
            [d_e['mask_e'],d_r['kgc:what'],d_e[_what]],
            [d_e['mask_e'],d_r['kgc:where'],d_e[_where]],
        ]
    )
    mask_ = torch.tensor(
        [
            [False, False, False],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
        ]
    )
    questions = torch.cat([triple[_start_index: _end_index], question_], dim=0).unsqueeze(0)
    masks = torch.cat([torch.zeros(_end_index-_start_index,3), mask_], dim=0).to(torch.bool).transpose(1,0).unsqueeze(0)
    tmp = []
    with torch.no_grad():
        _, (story_pred, relation_pred, entity_pred) = model(questions, masks[:,0], masks[:,1], masks[:,2])
        sorted_ = torch.argsort(entity_pred.to('cpu'), dim=1, descending=True)
        for i in range(sorted_.shape[1]):
            ans_= sorted_[:, i]
            info_source_, predicate_, whom_, subj_, why_, what_, where_ = ans_
            tmp.append([entities[predicate_], entities[whom_], entities[subj_], entities[why_], entities[what_], entities[where_]])
    df_ranking = pd.DataFrame(tmp, columns=['predicate', 'whom', 'subject', 'why', 'what', 'where'])
    df_attension = make_heatmap2_(questions)
    return df_ranking, df_attension

# %%
MASK_E = 'mask_e'
KILL = 'word.predicate:kill'
TAKE = 'word.predicate:take'
BRING = 'word.predicate:bring'
DIE = 'word.predicate:die'
HIDE = 'word.predicate:hide'

# %%
def main_func01(_title, _victim_name, _killer_name, _last_index, _story_len):
    from_ = f'{_title}:{_last_index-_story_len+1}'
    to_ = f'{_title}:{_last_index}'
    victim = f'{_title}:{_victim_name}'
    killer = f'{_title}:{_killer_name}'
    df_ranking, df_attension = make_ranking(
        from_, to_, KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

    print(f"{killer}, ranking", df_ranking.index[df_ranking['subject']==killer].tolist())
    display(df_ranking.iloc[:20,:])
    # display(df_attension_SpeckledBand)
    # ヒートマップの作成
    # sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
    len_ = len(df_attension)
    for i in range(len_-20, len_):
        display(i, df_attension.iloc[i,:3].tolist())
        display(df_attension.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
        print("----------")
    return df_ranking, df_attension

# %% [markdown]
# ### まだらの紐
# Who killed Julia? (criminal & explanation)
# 被害者: Julia
# 犯人: Roylott
# 犯行に用いたもの: snake
# 犯行動機: 母の相続財産を独占したい

# %%
title = 'SpeckledBand'
victim_name = 'Julia'
killer_name = 'Roylott'
last_index = 401
story_len = 80

df_ranking_SpeckledBand, df_attension_SpeckledBand = main_func01(title, victim_name, killer_name, last_index, story_len)

# %% [markdown]
# ### 悪魔の足跡１
# Who killed the victims? (criminal & explanation)
# 被害者: Brenda
# 犯人: Mortimer
# 犯行動機: 財産

# %%
title = 'DevilsFoot'
victim_name = 'Brenda'
killer_name = 'Mortimer'
last_index = 489
story_len = 80
df_ranking_DevilsFoot1, df_attension_DevilsFoot1 = main_func01(title, victim_name, killer_name, last_index, story_len)

# %% [markdown]
# ### 悪魔の足跡2
# Who killed the victims? (criminal & explanation)
# 被害者: Mortimer
# 犯人:
# 犯行動機: 恋人の敵

# %%
title = 'DevilsFoot'
victim_name = 'Mortimer'
killer_name = 'Sterndale'
last_index = 489
story_len = 80
df_ranking_DevilsFoot2, df_attension_DevilsFoot2 = main_func01(title, victim_name, killer_name, last_index, story_len)

# %% [markdown]
# ### 背中の曲がった男:
# Why did Barclay die?
# 被害者: Barclay
# 犯人:
# 犯行動機:

# %%
victim = 'CrookedMan:Barclay'
df_ranking_CrookedMan, df_attension_CrookedMan = make_ranking(
    f'CrookedMan:{373-80+1}', 'CrookedMan:373', DIE, MASK_E, victim, MASK_E, MASK_E, MASK_E)

display(df_ranking_CrookedMan.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_CrookedMan)
for i in range(len_-20, len_):
    display(i, df_attension_CrookedMan.iloc[i,:3].tolist())
    display(df_attension_CrookedMan.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")

# %% [markdown]
# ### 僧坊荘園
# Who killed Lord Blackenstall? (criminal & explanation)
# 被害者: Sir_Eustace_Brackenstall
# 犯人:
# 犯行動機:

# %%
title = 'AbbeyGrange'
victim_name = 'Sir_Eustace_Brackenstall'
killer_name = 'Jack_Croker'
last_index = 414
story_len = 80

df_ranking_AbbeyGrange, df_attension_AbbeyGrange = main_func01(title, victim_name, killer_name, last_index, story_len)

# %% [markdown]
# ### 入院患者
# Who killed Blessington? (criminal & explanation)
# 被害者: Blessington
# 犯人: 3人
# 犯行動機:

# %%
title = 'ResidentPatient'
victim_name = 'Blessington'
killer_name = ''
last_index = 324
story_len = 80

df_ranking_Blessington, df_attension_Blessington = main_func01(title, victim_name, killer_name, last_index, story_len)

# %% [markdown]
# ### 白銀
# Who took out the White Silver Blaze? (criminal & explanation)
# 被害者: Silver_Blaze
# 犯人:
# 犯行動機:

# %%
victim = 'SilverBlaze:Silver_Blaze'
df_ranking_SilverBlaze, df_attension_SilverBlaze = make_ranking(
    'SilverBlaze:330', 'SilverBlaze:396', BRING, MASK_E, MASK_E, MASK_E, victim, MASK_E)

display(df_ranking_SilverBlaze.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_SilverBlaze)
for i in range(len_-20, len_):
    display(i, df_attension_SilverBlaze.iloc[i,:3].tolist())
    display(df_attension_SilverBlaze.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")
# Out:
#                             predicate                             whom  \
# 0                 word.predicate:have         SilverBlaze:Silver_Blaze
# 1   SilverBlaze:Night_of_the_incident      SilverBlaze:Fitzroy_Simpson
# 2                  word.predicate:say         SilverBlaze:John_Straker
# 3                 word.predicate:find                  AllTitle:Holmes
# 4                  word.predicate:ask                  AllTitle:Watson
# 5                   word.predicate:go           ACaseOfIdentity:Hosmer
# 6                  word.predicate:try    AbbeyGrange:Lady_Brackenstall
# 7                word.predicate:exist           SilverBlaze:Ned_Hunter
# 8              word.predicate:examine          SilverBlaze:Silas_Brown
# 9                  word.predicate:get                DevilsFoot:Brenda
# 10                    AllTitle:Holmes               CrookedMan:Barclay
# 11             ACaseOfIdentity:Hosmer    SilverBlaze:Inspector_Gregory
# 12                word.predicate:stop  SpeckledBand:the_day_Julia_died
# 13             word.predicate:confirm      ResidentPatient:Blessington
# 14         ACaseOfIdentity:Sutherland                 DancingMen:Elsie
# 15                 word.predicate:die                 CrookedMan:Nancy
# 16        SilverBlaze:Fitzroy_Simpson     DateTime:1883-04-01T14:00:00
# 17              word.predicate:wakeUp               SpeckledBand:Helen
# 18       SpeckledBand:Julia_s_bedroom              CrookedMan:Morrison
# 19                word.predicate:kill     SpeckledBand:Julia_s_bedroom
#
#                           subject                              why  \
# 0        SilverBlaze:Silver_Blaze  SpeckledBand:mansion_of_Roylott
# 1        SilverBlaze:John_Straker                 SpeckledBand:bed
# 2     SilverBlaze:Fitzroy_Simpson     SpeckledBand:Julia_s_bedroom
# 3                 AllTitle:Holmes                  AllTitle:Holmes
# 4                 AllTitle:Watson         SilverBlaze:Colonel_Ross
# 5         SilverBlaze:Silas_Brown            word.predicate:escape
# 6              CrookedMan:Barclay                  AllTitle:Watson
# 7   SilverBlaze:Gregory_Inspector       ResidentPatient:Helper_boy
# 8          SilverBlaze:Ned_Hunter         SilverBlaze:John_Straker
# 9   AbbeyGrange:Lady_Brackenstall            word.predicate:louder
# 10              SilverBlaze:Gypsy        SilverBlaze:King_s_Pyland
# 11           AbbeyGrange:Criminal      ResidentPatient:Blessington
# 12    ResidentPatient:Blessington       SpeckledBand:1883-04-01T10
# 13         ACaseOfIdentity:Hosmer  ResidentPatient:Percy_Trevelyan
# 14   SpeckledBand:Julia_s_bedroom        SpeckledBand:rope_of_bell
# 15  SilverBlaze:Inspector_Gregory             SpeckledBand:Roylott
# 16       CrookedMan:Royal_Mallows           ACaseOfIdentity:Hosmer
# 17   DateTime:1883-04-01T14:00:00    SilverBlaze:Gregory_Inspector
# 18             SpeckledBand:Helen                  SilverBlaze:365
# 19               DancingMen:Elsie                  SilverBlaze:394
#
#                                what                               where
# 0          SilverBlaze:Silver_Blaze            SilverBlaze:John_Straker
# 1          SilverBlaze:John_Straker                     AllTitle:Holmes
# 2                   AllTitle:Holmes        SpeckledBand:Julia_s_bedroom
# 3       SilverBlaze:Fitzroy_Simpson        DateTime:1881-04-01T00:00:00
# 4                   AllTitle:Watson            SilverBlaze:Silver_Blaze
# 5            ACaseOfIdentity:Hosmer                SpeckledBand:Roylott
# 6                CrookedMan:Barclay            SilverBlaze:Colonel_Ross
# 7      SpeckledBand:Julia_s_bedroom         ResidentPatient:Blessington
# 8     AbbeyGrange:Lady_Brackenstall                  SilverBlaze:stable
# 9                 DancingMen:Cubitt               SpeckledBand:corridor
# 10    SilverBlaze:Gregory_Inspector          ResidentPatient:Helper_boy
# 11       ResidentPatient:Helper_boy         SilverBlaze:Fitzroy_Simpson
# 12              DevilsFoot:Mortimer           SilverBlaze:King_s_Pyland
# 13              word.predicate:have        DateTime:1883-04-01T14:00:00
# 14          SilverBlaze:Silas_Brown               SilverBlaze:Wasteland
# 15  SpeckledBand:the_day_Julia_died     SpeckledBand:mansion_of_Roylott
# 16               word.predicate:ask                   DevilsFoot:Brenda
# 17         CrookedMan:Royal_Mallows              word.predicate:receive
# 18           SilverBlaze:Ned_Hunter                     AllTitle:Watson
# 19           word.predicate:putInto  ResidentPatient:Brook_Street_house
# 364
# ['SilverBlaze:394', 'kgc:hasPredicate', 'word.predicate:buy']
#                  head     relation                              tail  \
# 309   SilverBlaze:384     kgc:what                   SilverBlaze:tie
# 353   SilverBlaze:392     kgc:what     SilverBlaze:Surgery_of_tendon
# 369   SilverBlaze:395     kgc:what                  SilverBlaze:debt
# 246  SilverBlaze:371a     kgc:what          SilverBlaze:Silver_Blaze
# 254   SilverBlaze:373     kgc:what             SilverBlaze:Injustice
# 361  SilverBlaze:393a     kgc:what                   SilverBlaze:394
# 367   SilverBlaze:395  kgc:subject          SilverBlaze:John_Straker
# 250   SilverBlaze:372     kgc:what                  SilverBlaze:Lame
# 314   SilverBlaze:385     kgc:what  SilverBlaze:legs_of_Silver_Blaze
# 53    SilverBlaze:341  kgc:subject          SilverBlaze:Colonel_Ross
# 228   SilverBlaze:367     kgc:what                 SilverBlaze:Horse
# 224   SilverBlaze:366     kgc:what          SilverBlaze:Lot_of_money
# 332   SilverBlaze:388     kgc:what                SilverBlaze:amount
# 258   SilverBlaze:374     kgc:what          SilverBlaze:Silver_Blaze
# 269   SilverBlaze:376     kgc:what                SilverBlaze:candle
# 307   SilverBlaze:384  kgc:subject          SilverBlaze:John_Straker
# 203   SilverBlaze:361     kgc:what                  SilverBlaze:menu
# 365   SilverBlaze:394     kgc:what     SilverBlaze:Expensive_clothes
# 235   SilverBlaze:369     kgc:what                 SilverBlaze:knife
# 363   SilverBlaze:394  kgc:subject          SilverBlaze:John_Straker
#
#      atten_from364
# 309       0.014575
# 353       0.011584
# 369       0.010953
# 246       0.010089
# 254       0.009790
# 361       0.009703
# 367       0.008748
# 250       0.008588
# 314       0.007880
# 53        0.007818
# 228       0.007604
# 224       0.007567
# 332       0.007515
# 258       0.007479
# 269       0.007476
# 307       0.007350
# 203       0.007242
# 365       0.007030
# 235       0.006942
# 363       0.006893
# ----------
# 365
# ['SilverBlaze:394', 'kgc:what', 'SilverBlaze:Expensive_clothes']
#                  head     relation                                tail  \
# 224   SilverBlaze:366     kgc:what            SilverBlaze:Lot_of_money
# 233   SilverBlaze:369  kgc:subject  SilverBlaze:Corpse_of_John_Straker
# 353   SilverBlaze:392     kgc:what       SilverBlaze:Surgery_of_tendon
# 367   SilverBlaze:395  kgc:subject            SilverBlaze:John_Straker
# 53    SilverBlaze:341  kgc:subject            SilverBlaze:Colonel_Ross
# 369   SilverBlaze:395     kgc:what                    SilverBlaze:debt
# 307   SilverBlaze:384  kgc:subject            SilverBlaze:John_Straker
# 309   SilverBlaze:384     kgc:what                     SilverBlaze:tie
# 222   SilverBlaze:366  kgc:subject           SilverBlaze:horse_trainer
# 228   SilverBlaze:367     kgc:what                   SilverBlaze:Horse
# 203   SilverBlaze:361     kgc:what                    SilverBlaze:menu
# 361  SilverBlaze:393a     kgc:what                     SilverBlaze:394
# 372   SilverBlaze:396  kgc:subject            SilverBlaze:Colonel_Ross
# 213   SilverBlaze:364  kgc:subject                SilverBlaze:Criminal
# 104   SilverBlaze:349     kgc:what                SilverBlaze:murderer
# 195   SilverBlaze:360     kgc:what    SilverBlaze:Wife_of_John_Straker
# 166   SilverBlaze:355     kgc:what      SilverBlaze:Taste_of_the_opium
# 117   SilverBlaze:353  kgc:subject            SilverBlaze:Colonel_Ross
# 303  SilverBlaze:383a  kgc:subject         SilverBlaze:Fitzroy_Simpson
# 252   SilverBlaze:373  kgc:subject                  SilverBlaze:People
#
#      atten_from365
# 224       0.019052
# 233       0.014648
# 353       0.013110
# 367       0.012521
# 53        0.009331
# 369       0.009312
# 307       0.008762
# 309       0.008176
# 222       0.007835
# 228       0.007682
# 203       0.007198
# 361       0.007151
# 372       0.006811
# 213       0.006791
# 104       0.006762
# 195       0.006710
# 166       0.006683
# 117       0.006605
# 303       0.006589
# 252       0.006364
# ----------
# 366
# ['bos_e', 'bos_r', 'bos_e']
#                 head          relation                              tail  \
# 42   SilverBlaze:338  kgc:hasPredicate              word.predicate:exist
# 23   SilverBlaze:333            kgc:to  SilverBlaze:Youth_stables_number
# 75             bos_e             bos_r                             bos_e
# 8    SilverBlaze:331          kgc:what                  SilverBlaze:331a
# 85             bos_e             bos_r                             bos_e
# 29             bos_e             bos_r                             bos_e
# 56             bos_e             bos_r                             bos_e
# 0              bos_e             bos_r                             bos_e
# 24             bos_e             bos_r                             bos_e
# 70             bos_e             bos_r                             bos_e
# 5              bos_e             bos_r                             bos_e
# 65             bos_e             bos_r                             bos_e
# 119            bos_e             bos_r                             bos_e
# 329            bos_e             bos_r                             bos_e
# 170  SilverBlaze:356  kgc:hasPredicate              word.predicate:erase
# 212            bos_e             bos_r                             bos_e
# 52             bos_e             bos_r                             bos_e
# 92             bos_e             bos_r                             bos_e
# 88             bos_e             bos_r                             bos_e
# 208            bos_e             bos_r                             bos_e
#
#      atten_from366
# 42        0.006342
# 23        0.005736
# 75        0.005348
# 8         0.005217
# 85        0.005137
# 29        0.005089
# 56        0.005055
# 0         0.004938
# 24        0.004912
# 70        0.004907
# 5         0.004855
# 65        0.004824
# 119       0.004803
# 329       0.004789
# 170       0.004780
# 212       0.004739
# 52        0.004732
# 92        0.004726
# 88        0.004702
# 208       0.004681
# ----------
# 367
# ['SilverBlaze:395', 'kgc:subject', 'SilverBlaze:John_Straker']
#                  head     relation                                 tail  \
# 367   SilverBlaze:395  kgc:subject             SilverBlaze:John_Straker
# 173   SilverBlaze:357  kgc:subject          SilverBlaze:Fitzroy_Simpson
# 369   SilverBlaze:395     kgc:what                     SilverBlaze:debt
# 372   SilverBlaze:396  kgc:subject             SilverBlaze:Colonel_Ross
# 363   SilverBlaze:394  kgc:subject             SilverBlaze:John_Straker
# 307   SilverBlaze:384  kgc:subject             SilverBlaze:John_Straker
# 361  SilverBlaze:393a     kgc:what                      SilverBlaze:394
# 309   SilverBlaze:384     kgc:what                      SilverBlaze:tie
# 353   SilverBlaze:392     kgc:what        SilverBlaze:Surgery_of_tendon
# 365   SilverBlaze:394     kgc:what        SilverBlaze:Expensive_clothes
# 15    SilverBlaze:332  kgc:subject        SilverBlaze:Inspector_Gregory
# 303  SilverBlaze:383a  kgc:subject          SilverBlaze:Fitzroy_Simpson
# 351   SilverBlaze:392  kgc:subject             SilverBlaze:John_Straker
# 312   SilverBlaze:385  kgc:subject             SilverBlaze:John_Straker
# 53    SilverBlaze:341  kgc:subject             SilverBlaze:Colonel_Ross
# 200   SilverBlaze:361  kgc:subject             SilverBlaze:John_Straker
# 348   SilverBlaze:391     kgc:what                    SilverBlaze:cloak
# 357   SilverBlaze:393     kgc:what  SilverBlaze:the_hat_decoration_shop
# 213   SilverBlaze:364  kgc:subject                 SilverBlaze:Criminal
# 11   SilverBlaze:331a  kgc:subject        SilverBlaze:Inspector_Gregory
#
#      atten_from367
# 367       0.015337
# 173       0.014397
# 369       0.011748
# 372       0.011647
# 363       0.011270
# 307       0.010597
# 361       0.010405
# 309       0.009857
# 353       0.009321
# 365       0.008304
# 15        0.008092
# 303       0.008082
# 351       0.007957
# 312       0.007651
# 53        0.007514
# 200       0.007403
# 348       0.007268
# 357       0.006739
# 213       0.006650
# 11        0.006526
# ----------
# 368
# ['SilverBlaze:395', 'kgc:hasPredicate', 'word.predicate:have']
#                  head         relation  \
# 274   SilverBlaze:377  kgc:hasProperty
# 190  SilverBlaze:359b  kgc:hasProperty
# 187  SilverBlaze:359a  kgc:hasProperty
# 369   SilverBlaze:395         kgc:what
# 31    SilverBlaze:335  kgc:hasProperty
# 238   SilverBlaze:370  kgc:hasProperty
# 344  SilverBlaze:390a         kgc:what
# 337   SilverBlaze:389         kgc:what
# 269   SilverBlaze:376         kgc:what
# 235   SilverBlaze:369         kgc:what
# 318   SilverBlaze:386         kgc:what
# 361  SilverBlaze:393a         kgc:what
# 270   SilverBlaze:376         kgc:what
# 365   SilverBlaze:394         kgc:what
# 357   SilverBlaze:393         kgc:what
# 278   SilverBlaze:378         kgc:what
# 309   SilverBlaze:384         kgc:what
# 107   SilverBlaze:350  kgc:hasProperty
# 207   SilverBlaze:362         kgc:what
# 353   SilverBlaze:392         kgc:what
#
#                                          tail  atten_from368
# 274                       word.predicate:dark       0.016944
# 190                 word.predicate:Curry_dish       0.013793
# 187                          SilverBlaze:359b       0.013142
# 369                          SilverBlaze:debt       0.011912
# 31                        word.predicate:lame       0.011335
# 238                      word.predicate:wacky       0.011241
# 344         SilverBlaze:thigh_of_John_Straker       0.010161
# 337  SilverBlaze:The_forehead_of_John_Straker       0.010060
# 269                        SilverBlaze:candle       0.010041
# 235                         SilverBlaze:knife       0.008965
# 318                         SilverBlaze:match       0.008963
# 361                           SilverBlaze:394       0.008800
# 270                         SilverBlaze:Match       0.008545
# 365             SilverBlaze:Expensive_clothes       0.008398
# 357       SilverBlaze:the_hat_decoration_shop       0.008017
# 278                         SilverBlaze:money       0.007892
# 309                           SilverBlaze:tie       0.007577
# 107                word.predicate:notReliable       0.007549
# 207                         SilverBlaze:Opium       0.007298
# 353             SilverBlaze:Surgery_of_tendon       0.007127
# ----------
# 369
# ['SilverBlaze:395', 'kgc:what', 'SilverBlaze:debt']
#                  head     relation                                 tail  \
# 361  SilverBlaze:393a     kgc:what                      SilverBlaze:394
# 369   SilverBlaze:395     kgc:what                     SilverBlaze:debt
# 203   SilverBlaze:361     kgc:what                     SilverBlaze:menu
# 353   SilverBlaze:392     kgc:what        SilverBlaze:Surgery_of_tendon
# 365   SilverBlaze:394     kgc:what        SilverBlaze:Expensive_clothes
# 173   SilverBlaze:357  kgc:subject          SilverBlaze:Fitzroy_Simpson
# 309   SilverBlaze:384     kgc:what                      SilverBlaze:tie
# 357   SilverBlaze:393     kgc:what  SilverBlaze:the_hat_decoration_shop
# 194   SilverBlaze:360     kgc:what             SilverBlaze:John_Straker
# 171   SilverBlaze:356     kgc:what           SilverBlaze:Taste_of_opium
# 195   SilverBlaze:360     kgc:what     SilverBlaze:Wife_of_John_Straker
# 224   SilverBlaze:366     kgc:what             SilverBlaze:Lot_of_money
# 207   SilverBlaze:362     kgc:what                    SilverBlaze:Opium
# 161   SilverBlaze:354     kgc:what                      SilverBlaze:394
# 235   SilverBlaze:369     kgc:what                    SilverBlaze:knife
# 348   SilverBlaze:391     kgc:what                    SilverBlaze:cloak
# 117   SilverBlaze:353  kgc:subject             SilverBlaze:Colonel_Ross
# 184   SilverBlaze:359     kgc:what                     SilverBlaze:359a
# 76    SilverBlaze:345  kgc:subject                      AllTitle:Holmes
# 374   SilverBlaze:396     kgc:what       SilverBlaze:Place_of_the_horse
#
#      atten_from369
# 361       0.009276
# 369       0.009080
# 203       0.008624
# 353       0.008153
# 365       0.007864
# 173       0.007699
# 309       0.007389
# 357       0.007147
# 194       0.006855
# 171       0.006574
# 195       0.006533
# 224       0.006496
# 207       0.006405
# 161       0.006294
# 235       0.006129
# 348       0.006110
# 117       0.006060
# 184       0.005958
# 76        0.005949
# 374       0.005876
# ----------
# 370
# ['SilverBlaze:395', 'kgc:why', 'SilverBlaze:394']
#                  head        relation                                tail  \
# 309   SilverBlaze:384        kgc:what                     SilverBlaze:tie
# 100  SilverBlaze:348a          kgc:to             SilverBlaze:Horseracing
# 369   SilverBlaze:395        kgc:what                    SilverBlaze:debt
# 203   SilverBlaze:361        kgc:what                    SilverBlaze:menu
# 173   SilverBlaze:357     kgc:subject         SilverBlaze:Fitzroy_Simpson
# 250   SilverBlaze:372        kgc:what                    SilverBlaze:Lame
# 117   SilverBlaze:353     kgc:subject            SilverBlaze:Colonel_Ross
# 98   SilverBlaze:348a     kgc:subject            SilverBlaze:Silver_Blaze
# 246  SilverBlaze:371a        kgc:what            SilverBlaze:Silver_Blaze
# 233   SilverBlaze:369     kgc:subject  SilverBlaze:Corpse_of_John_Straker
# 361  SilverBlaze:393a        kgc:what                     SilverBlaze:394
# 269   SilverBlaze:376        kgc:what                  SilverBlaze:candle
# 175   SilverBlaze:357         kgc:why                     SilverBlaze:358
# 114   SilverBlaze:352     kgc:subject            SilverBlaze:Silver_Blaze
# 365   SilverBlaze:394        kgc:what       SilverBlaze:Expensive_clothes
# 158   SilverBlaze:354        kgc:what                     SilverBlaze:391
# 171   SilverBlaze:356        kgc:what          SilverBlaze:Taste_of_opium
# 237   SilverBlaze:370     kgc:subject                   SilverBlaze:knife
# 377            mask_e  kgc:infoSource                     AllTitle:Holmes
# 156   SilverBlaze:354        kgc:what                     SilverBlaze:389
#
#      atten_from370
# 309       0.009316
# 100       0.006814
# 369       0.006530
# 203       0.006339
# 173       0.006055
# 250       0.005971
# 117       0.005858
# 98        0.005810
# 246       0.005702
# 233       0.005674
# 361       0.005665
# 269       0.005391
# 175       0.005390
# 114       0.005374
# 365       0.005366
# 158       0.005267
# 171       0.005241
# 237       0.005217
# 377       0.005176
# 156       0.005162
# ----------
# 371
# ['bos_e', 'bos_r', 'bos_e']
#                 head          relation                              tail  \
# 8    SilverBlaze:331          kgc:what                  SilverBlaze:331a
# 23   SilverBlaze:333            kgc:to  SilverBlaze:Youth_stables_number
# 42   SilverBlaze:338  kgc:hasPredicate              word.predicate:exist
# 75             bos_e             bos_r                             bos_e
# 85             bos_e             bos_r                             bos_e
# 29             bos_e             bos_r                             bos_e
# 56             bos_e             bos_r                             bos_e
# 0              bos_e             bos_r                             bos_e
# 24             bos_e             bos_r                             bos_e
# 70             bos_e             bos_r                             bos_e
# 5              bos_e             bos_r                             bos_e
# 329            bos_e             bos_r                             bos_e
# 119            bos_e             bos_r                             bos_e
# 65             bos_e             bos_r                             bos_e
# 212            bos_e             bos_r                             bos_e
# 92             bos_e             bos_r                             bos_e
# 170  SilverBlaze:356  kgc:hasPredicate              word.predicate:erase
# 52             bos_e             bos_r                             bos_e
# 163            bos_e             bos_r                             bos_e
# 88             bos_e             bos_r                             bos_e
#
#      atten_from371
# 8         0.005822
# 23        0.005690
# 42        0.005676
# 75        0.005191
# 85        0.004991
# 29        0.004908
# 56        0.004901
# 0         0.004796
# 24        0.004764
# 70        0.004742
# 5         0.004731
# 329       0.004709
# 119       0.004702
# 65        0.004670
# 212       0.004640
# 92        0.004635
# 170       0.004616
# 52        0.004616
# 163       0.004589
# 88        0.004572
# ----------
# 372
# ['SilverBlaze:396', 'kgc:subject', 'SilverBlaze:Colonel_Ross']
#                  head     relation                              tail  \
# 372   SilverBlaze:396  kgc:subject          SilverBlaze:Colonel_Ross
# 351   SilverBlaze:392  kgc:subject          SilverBlaze:John_Straker
# 367   SilverBlaze:395  kgc:subject          SilverBlaze:John_Straker
# 307   SilverBlaze:384  kgc:subject          SilverBlaze:John_Straker
# 363   SilverBlaze:394  kgc:subject          SilverBlaze:John_Straker
# 346   SilverBlaze:391  kgc:subject          SilverBlaze:John_Straker
# 312   SilverBlaze:385  kgc:subject          SilverBlaze:John_Straker
# 53    SilverBlaze:341  kgc:subject          SilverBlaze:Colonel_Ross
# 252   SilverBlaze:373  kgc:subject                SilverBlaze:People
# 303  SilverBlaze:383a  kgc:subject       SilverBlaze:Fitzroy_Simpson
# 256   SilverBlaze:374  kgc:subject          SilverBlaze:John_Straker
# 333   SilverBlaze:388     kgc:when                   SilverBlaze:387
# 330   SilverBlaze:388  kgc:subject          SilverBlaze:John_Straker
# 169   SilverBlaze:356  kgc:subject              SilverBlaze:Criminal
# 201   SilverBlaze:361  kgc:subject  SilverBlaze:Wife_of_John_Straker
# 200   SilverBlaze:361  kgc:subject          SilverBlaze:John_Straker
# 353   SilverBlaze:392     kgc:what     SilverBlaze:Surgery_of_tendon
# 248   SilverBlaze:372  kgc:subject         SilverBlaze:Injured_horse
# 222   SilverBlaze:366  kgc:subject         SilverBlaze:horse_trainer
# 326  SilverBlaze:387a  kgc:subject          SilverBlaze:Silver_Blaze
#
#      atten_from372
# 372       0.017832
# 351       0.015255
# 367       0.014331
# 307       0.014249
# 363       0.011662
# 346       0.010835
# 312       0.010788
# 53        0.010689
# 252       0.010213
# 303       0.010033
# 256       0.009652
# 333       0.009536
# 330       0.009389
# 169       0.008235
# 201       0.007979
# 200       0.007927
# 353       0.007860
# 248       0.007748
# 222       0.007635
# 326       0.007512
# ----------
# 373
# ['SilverBlaze:396', 'kgc:hasPredicate', 'word.predicate:ask']
#                  head     relation                                      tail  \
# 353   SilverBlaze:392     kgc:what             SilverBlaze:Surgery_of_tendon
# 344  SilverBlaze:390a     kgc:what         SilverBlaze:thigh_of_John_Straker
# 254   SilverBlaze:373     kgc:what                     SilverBlaze:Injustice
# 348   SilverBlaze:391     kgc:what                         SilverBlaze:cloak
# 374   SilverBlaze:396     kgc:what            SilverBlaze:Place_of_the_horse
# 369   SilverBlaze:395     kgc:what                          SilverBlaze:debt
# 361  SilverBlaze:393a     kgc:what                           SilverBlaze:394
# 309   SilverBlaze:384     kgc:what                           SilverBlaze:tie
# 51    SilverBlaze:340       kgc:on                   SilverBlaze:Brown_horse
# 365   SilverBlaze:394     kgc:what             SilverBlaze:Expensive_clothes
# 258   SilverBlaze:374     kgc:what                  SilverBlaze:Silver_Blaze
# 269   SilverBlaze:376     kgc:what                        SilverBlaze:candle
# 337   SilverBlaze:389     kgc:what  SilverBlaze:The_forehead_of_John_Straker
# 134   SilverBlaze:354     kgc:what                           SilverBlaze:367
# 79    SilverBlaze:345     kgc:what                           SilverBlaze:347
# 148   SilverBlaze:354     kgc:what                           SilverBlaze:381
# 312   SilverBlaze:385  kgc:subject                  SilverBlaze:John_Straker
# 141   SilverBlaze:354     kgc:what                           SilverBlaze:374
# 332   SilverBlaze:388     kgc:what                        SilverBlaze:amount
# 349   SilverBlaze:391     kgc:when                           SilverBlaze:385
#
#      atten_from373
# 353       0.008945
# 344       0.008900
# 254       0.008498
# 348       0.007707
# 374       0.007485
# 369       0.007214
# 361       0.007024
# 309       0.006912
# 51        0.006709
# 365       0.006674
# 258       0.006657
# 269       0.006566
# 337       0.006459
# 134       0.006314
# 79        0.006184
# 148       0.006036
# 312       0.005860
# 141       0.005858
# 332       0.005765
# 349       0.005763
# ----------
# 374
# ['SilverBlaze:396', 'kgc:what', 'SilverBlaze:Place_of_the_horse']
#                 head  relation                            tail  atten_from374
# 374  SilverBlaze:396  kgc:what  SilverBlaze:Place_of_the_horse       0.014151
# 348  SilverBlaze:391  kgc:what               SilverBlaze:cloak       0.010376
# 369  SilverBlaze:395  kgc:what                SilverBlaze:debt       0.008752
# 161  SilverBlaze:354  kgc:what                 SilverBlaze:394       0.008676
# 353  SilverBlaze:392  kgc:what   SilverBlaze:Surgery_of_tendon       0.008308
# 215  SilverBlaze:364  kgc:what  SilverBlaze:Dog_of_the_stables       0.008168
# 171  SilverBlaze:356  kgc:what      SilverBlaze:Taste_of_opium       0.008054
# 153  SilverBlaze:354  kgc:what                 SilverBlaze:386       0.008022
# 135  SilverBlaze:354  kgc:what                 SilverBlaze:368       0.008000
# 151  SilverBlaze:354  kgc:what                 SilverBlaze:384       0.007932
# 162  SilverBlaze:354  kgc:what                 SilverBlaze:395       0.007713
# 129  SilverBlaze:354  kgc:what                 SilverBlaze:362       0.007687
# 138  SilverBlaze:354  kgc:what                 SilverBlaze:371       0.007617
# 160  SilverBlaze:354  kgc:what                 SilverBlaze:393       0.007470
# 154  SilverBlaze:354  kgc:what                 SilverBlaze:387       0.007445
# 152  SilverBlaze:354  kgc:what                 SilverBlaze:385       0.007428
# 203  SilverBlaze:361  kgc:what                SilverBlaze:menu       0.007343
# 158  SilverBlaze:354  kgc:what                 SilverBlaze:391       0.007213
# 139  SilverBlaze:354  kgc:what                 SilverBlaze:372       0.007182
# 211  SilverBlaze:363  kgc:what               SilverBlaze:Opium       0.007138
# ----------
# 375
# ['SilverBlaze:396', 'kgc:to', 'AllTitle:Holmes']
#                  head          relation                        tail  \
# 373   SilverBlaze:396  kgc:hasPredicate          word.predicate:ask
# 352   SilverBlaze:392  kgc:hasPredicate     word.predicate:practice
# 308   SilverBlaze:384  kgc:hasPredicate         word.predicate:pick
# 193   SilverBlaze:360  kgc:hasPredicate      word.predicate:suspect
# 347   SilverBlaze:391  kgc:hasPredicate      word.predicate:takeOff
# 356   SilverBlaze:393  kgc:hasPredicate           word.predicate:go
# 364   SilverBlaze:394  kgc:hasPredicate          word.predicate:buy
# 103   SilverBlaze:349  kgc:hasPredicate        word.predicate:catch
# 360  SilverBlaze:393a  kgc:hasPredicate      word.predicate:confirm
# 223   SilverBlaze:366  kgc:hasPredicate          word.predicate:get
# 257   SilverBlaze:374  kgc:hasPredicate        word.predicate:carry
# 118   SilverBlaze:353  kgc:hasPredicate  word.predicate:beSurprised
# 2     SilverBlaze:330  kgc:hasPredicate      word.predicate:request
# 16    SilverBlaze:332  kgc:hasPredicate         word.predicate:give
# 202   SilverBlaze:361  kgc:hasPredicate    word.predicate:canDecide
# 372   SilverBlaze:396       kgc:subject    SilverBlaze:Colonel_Ross
# 170   SilverBlaze:356  kgc:hasPredicate        word.predicate:erase
# 330   SilverBlaze:388       kgc:subject    SilverBlaze:John_Straker
# 367   SilverBlaze:395       kgc:subject    SilverBlaze:John_Straker
# 304  SilverBlaze:383a  kgc:hasPredicate       word.predicate:escape
#
#      atten_from375
# 373       0.026520
# 352       0.019100
# 308       0.018093
# 193       0.013524
# 347       0.011626
# 356       0.011223
# 364       0.011193
# 103       0.011088
# 360       0.010392
# 223       0.009754
# 257       0.009622
# 118       0.009455
# 2         0.009161
# 16        0.008928
# 202       0.008908
# 372       0.008445
# 170       0.008197
# 330       0.008051
# 367       0.007733
# 304       0.007649
# ----------
# 376
# ['bos_e', 'bos_r', 'bos_e']
#                 head          relation                              tail  \
# 8    SilverBlaze:331          kgc:what                  SilverBlaze:331a
# 23   SilverBlaze:333            kgc:to  SilverBlaze:Youth_stables_number
# 42   SilverBlaze:338  kgc:hasPredicate              word.predicate:exist
# 75             bos_e             bos_r                             bos_e
# 85             bos_e             bos_r                             bos_e
# 29             bos_e             bos_r                             bos_e
# 56             bos_e             bos_r                             bos_e
# 0              bos_e             bos_r                             bos_e
# 24             bos_e             bos_r                             bos_e
# 70             bos_e             bos_r                             bos_e
# 5              bos_e             bos_r                             bos_e
# 65             bos_e             bos_r                             bos_e
# 119            bos_e             bos_r                             bos_e
# 329            bos_e             bos_r                             bos_e
# 52             bos_e             bos_r                             bos_e
# 92             bos_e             bos_r                             bos_e
# 212            bos_e             bos_r                             bos_e
# 88             bos_e             bos_r                             bos_e
# 208            bos_e             bos_r                             bos_e
# 163            bos_e             bos_r                             bos_e
#
#      atten_from376
# 8         0.005739
# 23        0.005704
# 42        0.005367
# 75        0.005252
# 85        0.005039
# 29        0.004998
# 56        0.004986
# 0         0.004870
# 24        0.004864
# 70        0.004863
# 5         0.004795
# 65        0.004775
# 119       0.004737
# 329       0.004724
# 52        0.004698
# 92        0.004679
# 212       0.004678
# 88        0.004623
# 208       0.004620
# 163       0.004618
# ----------
# 377
# ['mask_e', 'kgc:infoSource', 'AllTitle:Holmes']
#                  head          relation                            tail  \
# 367   SilverBlaze:395       kgc:subject        SilverBlaze:John_Straker
# 351   SilverBlaze:392       kgc:subject        SilverBlaze:John_Straker
# 372   SilverBlaze:396       kgc:subject        SilverBlaze:Colonel_Ross
# 346   SilverBlaze:391       kgc:subject        SilverBlaze:John_Straker
# 363   SilverBlaze:394       kgc:subject        SilverBlaze:John_Straker
# 307   SilverBlaze:384       kgc:subject        SilverBlaze:John_Straker
# 353   SilverBlaze:392          kgc:what   SilverBlaze:Surgery_of_tendon
# 369   SilverBlaze:395          kgc:what                SilverBlaze:debt
# 348   SilverBlaze:391          kgc:what               SilverBlaze:cloak
# 374   SilverBlaze:396          kgc:what  SilverBlaze:Place_of_the_horse
# 330   SilverBlaze:388       kgc:subject        SilverBlaze:John_Straker
# 333   SilverBlaze:388          kgc:when                 SilverBlaze:387
# 312   SilverBlaze:385       kgc:subject        SilverBlaze:John_Straker
# 373   SilverBlaze:396  kgc:hasPredicate              word.predicate:ask
# 256   SilverBlaze:374       kgc:subject        SilverBlaze:John_Straker
# 252   SilverBlaze:373       kgc:subject              SilverBlaze:People
# 370   SilverBlaze:395           kgc:why                 SilverBlaze:394
# 326  SilverBlaze:387a       kgc:subject        SilverBlaze:Silver_Blaze
# 200   SilverBlaze:361       kgc:subject        SilverBlaze:John_Straker
# 365   SilverBlaze:394          kgc:what   SilverBlaze:Expensive_clothes
#
#      atten_from377
# 367       0.014056
# 351       0.013245
# 372       0.011891
# 346       0.010760
# 363       0.010337
# 307       0.010254
# 353       0.009763
# 369       0.009464
# 348       0.009124
# 374       0.008249
# 330       0.008031
# 333       0.007956
# 312       0.007697
# 373       0.007067
# 256       0.006817
# 252       0.006698
# 370       0.006298
# 326       0.006267
# 200       0.006196
# 365       0.006098
# ----------
# 378
# ['mask_e', 'kgc:hasPredicate', 'word.predicate:bring']
#                  head  relation                                      tail  \
# 344  SilverBlaze:390a  kgc:what         SilverBlaze:thigh_of_John_Straker
# 353   SilverBlaze:392  kgc:what             SilverBlaze:Surgery_of_tendon
# 361  SilverBlaze:393a  kgc:what                           SilverBlaze:394
# 314   SilverBlaze:385  kgc:what          SilverBlaze:legs_of_Silver_Blaze
# 365   SilverBlaze:394  kgc:what             SilverBlaze:Expensive_clothes
# 309   SilverBlaze:384  kgc:what                           SilverBlaze:tie
# 269   SilverBlaze:376  kgc:what                        SilverBlaze:candle
# 348   SilverBlaze:391  kgc:what                         SilverBlaze:cloak
# 337   SilverBlaze:389  kgc:what  SilverBlaze:The_forehead_of_John_Straker
# 203   SilverBlaze:361  kgc:what                          SilverBlaze:menu
# 369   SilverBlaze:395  kgc:what                          SilverBlaze:debt
# 328  SilverBlaze:387a  kgc:what                        SilverBlaze:Danger
# 332   SilverBlaze:388  kgc:what                        SilverBlaze:amount
# 374   SilverBlaze:396  kgc:what            SilverBlaze:Place_of_the_horse
# 254   SilverBlaze:373  kgc:what                     SilverBlaze:Injustice
# 270   SilverBlaze:376  kgc:what                         SilverBlaze:Match
# 246  SilverBlaze:371a  kgc:what                  SilverBlaze:Silver_Blaze
# 242   SilverBlaze:371  kgc:what                          SilverBlaze:371a
# 318   SilverBlaze:386  kgc:what                         SilverBlaze:match
# 250   SilverBlaze:372  kgc:what                          SilverBlaze:Lame
#
#      atten_from378
# 344       0.013948
# 353       0.013810
# 361       0.013415
# 314       0.012739
# 365       0.012346
# 309       0.011409
# 269       0.010751
# 348       0.010702
# 337       0.010516
# 203       0.010508
# 369       0.010210
# 328       0.009992
# 332       0.009461
# 374       0.009062
# 254       0.008697
# 270       0.008530
# 246       0.008423
# 242       0.008145
# 318       0.008096
# 250       0.007914
# ----------
# 379
# ['mask_e', 'kgc:whom', 'mask_e']
#                  head     relation                           tail  \
# 333   SilverBlaze:388     kgc:when                SilverBlaze:387
# 367   SilverBlaze:395  kgc:subject       SilverBlaze:John_Straker
# 307   SilverBlaze:384  kgc:subject       SilverBlaze:John_Straker
# 326  SilverBlaze:387a  kgc:subject       SilverBlaze:Silver_Blaze
# 330   SilverBlaze:388  kgc:subject       SilverBlaze:John_Straker
# 372   SilverBlaze:396  kgc:subject       SilverBlaze:Colonel_Ross
# 312   SilverBlaze:385  kgc:subject       SilverBlaze:John_Straker
# 363   SilverBlaze:394  kgc:subject       SilverBlaze:John_Straker
# 303  SilverBlaze:383a  kgc:subject    SilverBlaze:Fitzroy_Simpson
# 321   SilverBlaze:387  kgc:subject       SilverBlaze:Silver_Blaze
# 346   SilverBlaze:391  kgc:subject       SilverBlaze:John_Straker
# 351   SilverBlaze:392  kgc:subject       SilverBlaze:John_Straker
# 349   SilverBlaze:391     kgc:when                SilverBlaze:385
# 353   SilverBlaze:392     kgc:what  SilverBlaze:Surgery_of_tendon
# 167   SilverBlaze:355      kgc:why                SilverBlaze:356
# 265   SilverBlaze:375     kgc:when                SilverBlaze:371
# 260   SilverBlaze:374      kgc:why                SilverBlaze:375
# 216   SilverBlaze:364      kgc:why                SilverBlaze:365
# 252   SilverBlaze:373  kgc:subject             SilverBlaze:People
# 348   SilverBlaze:391     kgc:what              SilverBlaze:cloak
#
#      atten_from379
# 333       0.021062
# 367       0.015080
# 307       0.010405
# 326       0.009876
# 330       0.009211
# 372       0.008174
# 312       0.008088
# 363       0.007924
# 303       0.007587
# 321       0.007361
# 346       0.007291
# 351       0.007288
# 349       0.007172
# 353       0.007106
# 167       0.006688
# 265       0.006630
# 260       0.006557
# 216       0.006468
# 252       0.006095
# 348       0.006053
# ----------
# 380
# ['mask_e', 'kgc:subject', 'mask_e']
#                  head     relation                                tail  \
# 333   SilverBlaze:388     kgc:when                     SilverBlaze:387
# 367   SilverBlaze:395  kgc:subject            SilverBlaze:John_Straker
# 353   SilverBlaze:392     kgc:what       SilverBlaze:Surgery_of_tendon
# 307   SilverBlaze:384  kgc:subject            SilverBlaze:John_Straker
# 363   SilverBlaze:394  kgc:subject            SilverBlaze:John_Straker
# 372   SilverBlaze:396  kgc:subject            SilverBlaze:Colonel_Ross
# 348   SilverBlaze:391     kgc:what                   SilverBlaze:cloak
# 173   SilverBlaze:357  kgc:subject         SilverBlaze:Fitzroy_Simpson
# 369   SilverBlaze:395     kgc:what                    SilverBlaze:debt
# 351   SilverBlaze:392  kgc:subject            SilverBlaze:John_Straker
# 303  SilverBlaze:383a  kgc:subject         SilverBlaze:Fitzroy_Simpson
# 312   SilverBlaze:385  kgc:subject            SilverBlaze:John_Straker
# 332   SilverBlaze:388     kgc:what                  SilverBlaze:amount
# 328  SilverBlaze:387a     kgc:what                  SilverBlaze:Danger
# 233   SilverBlaze:369  kgc:subject  SilverBlaze:Corpse_of_John_Straker
# 53    SilverBlaze:341  kgc:subject            SilverBlaze:Colonel_Ross
# 222   SilverBlaze:366  kgc:subject           SilverBlaze:horse_trainer
# 117   SilverBlaze:353  kgc:subject            SilverBlaze:Colonel_Ross
# 252   SilverBlaze:373  kgc:subject                  SilverBlaze:People
# 349   SilverBlaze:391     kgc:when                     SilverBlaze:385
#
#      atten_from380
# 333       0.015483
# 367       0.013277
# 353       0.012219
# 307       0.010644
# 363       0.009703
# 372       0.009697
# 348       0.009206
# 173       0.009035
# 369       0.008144
# 351       0.008122
# 303       0.007367
# 312       0.007327
# 332       0.007101
# 328       0.007013
# 233       0.006831
# 53        0.006587
# 222       0.006344
# 117       0.006257
# 252       0.006250
# 349       0.006071
# ----------
# 381
# ['mask_e', 'kgc:why', 'mask_e']
#                  head     relation                                 tail  \
# 117   SilverBlaze:353  kgc:subject             SilverBlaze:Colonel_Ross
# 374   SilverBlaze:396     kgc:what       SilverBlaze:Place_of_the_horse
# 235   SilverBlaze:369     kgc:what                    SilverBlaze:knife
# 369   SilverBlaze:395     kgc:what                     SilverBlaze:debt
# 365   SilverBlaze:394     kgc:what        SilverBlaze:Expensive_clothes
# 203   SilverBlaze:361     kgc:what                     SilverBlaze:menu
# 361  SilverBlaze:393a     kgc:what                      SilverBlaze:394
# 171   SilverBlaze:356     kgc:what           SilverBlaze:Taste_of_opium
# 100  SilverBlaze:348a       kgc:to              SilverBlaze:Horseracing
# 160   SilverBlaze:354     kgc:what                      SilverBlaze:393
# 246  SilverBlaze:371a     kgc:what             SilverBlaze:Silver_Blaze
# 162   SilverBlaze:354     kgc:what                      SilverBlaze:395
# 194   SilverBlaze:360     kgc:what             SilverBlaze:John_Straker
# 158   SilverBlaze:354     kgc:what                      SilverBlaze:391
# 309   SilverBlaze:384     kgc:what                      SilverBlaze:tie
# 321   SilverBlaze:387  kgc:subject             SilverBlaze:Silver_Blaze
# 131   SilverBlaze:354     kgc:what                      SilverBlaze:364
# 180   SilverBlaze:358     kgc:what                     SilverBlaze:menu
# 357   SilverBlaze:393     kgc:what  SilverBlaze:the_hat_decoration_shop
# 233   SilverBlaze:369  kgc:subject   SilverBlaze:Corpse_of_John_Straker
#
#      atten_from381
# 117       0.007931
# 374       0.007328
# 235       0.007225
# 369       0.007006
# 365       0.006932
# 203       0.006799
# 361       0.006748
# 171       0.006442
# 100       0.006386
# 160       0.006373
# 246       0.006305
# 162       0.006285
# 194       0.006247
# 158       0.006035
# 309       0.005997
# 321       0.005880
# 131       0.005835
# 180       0.005811
# 357       0.005790
# 233       0.005704
# ----------
# 382
# ['mask_e', 'kgc:what', 'SilverBlaze:Silver_Blaze']
#                  head     relation                                tail  \
# 353   SilverBlaze:392     kgc:what       SilverBlaze:Surgery_of_tendon
# 369   SilverBlaze:395     kgc:what                    SilverBlaze:debt
# 365   SilverBlaze:394     kgc:what       SilverBlaze:Expensive_clothes
# 224   SilverBlaze:366     kgc:what            SilverBlaze:Lot_of_money
# 361  SilverBlaze:393a     kgc:what                     SilverBlaze:394
# 117   SilverBlaze:353  kgc:subject            SilverBlaze:Colonel_Ross
# 228   SilverBlaze:367     kgc:what                   SilverBlaze:Horse
# 233   SilverBlaze:369  kgc:subject  SilverBlaze:Corpse_of_John_Straker
# 367   SilverBlaze:395  kgc:subject            SilverBlaze:John_Straker
# 235   SilverBlaze:369     kgc:what                   SilverBlaze:knife
# 321   SilverBlaze:387  kgc:subject            SilverBlaze:Silver_Blaze
# 76    SilverBlaze:345  kgc:subject                     AllTitle:Holmes
# 55    SilverBlaze:341     kgc:what                     SilverBlaze:342
# 120   SilverBlaze:354  kgc:subject                     AllTitle:Holmes
# 252   SilverBlaze:373  kgc:subject                  SilverBlaze:People
# 307   SilverBlaze:384  kgc:subject            SilverBlaze:John_Straker
# 194   SilverBlaze:360     kgc:what            SilverBlaze:John_Straker
# 59    SilverBlaze:342     kgc:what            SilverBlaze:Silver_Blaze
# 374   SilverBlaze:396     kgc:what      SilverBlaze:Place_of_the_horse
# 203   SilverBlaze:361     kgc:what                    SilverBlaze:menu
#
#      atten_from382
# 353       0.013675
# 369       0.012921
# 365       0.011427
# 224       0.010027
# 361       0.010017
# 117       0.009632
# 228       0.009522
# 233       0.008574
# 367       0.008262
# 235       0.007805
# 321       0.007782
# 76        0.007399
# 55        0.007246
# 120       0.006795
# 252       0.006766
# 307       0.006666
# 194       0.006511
# 59        0.006502
# 374       0.006494
# 203       0.006369
# ----------
# 383
# ['mask_e', 'kgc:where', 'mask_e']
#                  head     relation                                tail  \
# 233   SilverBlaze:369  kgc:subject  SilverBlaze:Corpse_of_John_Straker
# 369   SilverBlaze:395     kgc:what                    SilverBlaze:debt
# 224   SilverBlaze:366     kgc:what            SilverBlaze:Lot_of_money
# 117   SilverBlaze:353  kgc:subject            SilverBlaze:Colonel_Ross
# 55    SilverBlaze:341     kgc:what                     SilverBlaze:342
# 321   SilverBlaze:387  kgc:subject            SilverBlaze:Silver_Blaze
# 228   SilverBlaze:367     kgc:what                   SilverBlaze:Horse
# 365   SilverBlaze:394     kgc:what       SilverBlaze:Expensive_clothes
# 171   SilverBlaze:356     kgc:what          SilverBlaze:Taste_of_opium
# 353   SilverBlaze:392     kgc:what       SilverBlaze:Surgery_of_tendon
# 361  SilverBlaze:393a     kgc:what                     SilverBlaze:394
# 131   SilverBlaze:354     kgc:what                     SilverBlaze:364
# 161   SilverBlaze:354     kgc:what                     SilverBlaze:394
# 374   SilverBlaze:396     kgc:what      SilverBlaze:Place_of_the_horse
# 254   SilverBlaze:373     kgc:what               SilverBlaze:Injustice
# 235   SilverBlaze:369     kgc:what                   SilverBlaze:knife
# 162   SilverBlaze:354     kgc:what                     SilverBlaze:395
# 213   SilverBlaze:364  kgc:subject                SilverBlaze:Criminal
# 154   SilverBlaze:354     kgc:what                     SilverBlaze:387
# 160   SilverBlaze:354     kgc:what                     SilverBlaze:393
#
#      atten_from383
# 233       0.008949
# 369       0.008379
# 224       0.008349
# 117       0.008093
# 55        0.007215
# 321       0.007094
# 228       0.007058
# 365       0.006979
# 171       0.006852
# 353       0.006800
# 361       0.006492
# 131       0.006449
# 161       0.006287
# 374       0.005922
# 254       0.005878
# 235       0.005857
# 162       0.005847
# 213       0.005823
# 154       0.005771
# 160       0.005727
# ----------

# %% [markdown]
# ### 花嫁失踪事件（同一事件）
# hozmaの失踪の名瀬を探る
# 被害者: ACaseOfIdentity:Hozma
# 犯人:
# 犯行動機:

# %%
victim = 'ACaseOfIdentity:Hosmer'
df_ranking_ACaseOfIdentity, df_attension_ACaseOfIdentity = make_ranking(
    'ACaseOfIdentity:510', 'ACaseOfIdentity:578', HIDE, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_ACaseOfIdentity.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_ACaseOfIdentity)
for i in range(len_-20, len_):
    display(i, df_attension_ACaseOfIdentity.iloc[i,:3].tolist())
    display(df_attension_ACaseOfIdentity.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")
