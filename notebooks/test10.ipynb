# %%
import h5py

file_=""
with h5py.File(file_, 'r') as f:
    data = f['All']['story_property_subject_predicate_object'][()]
data

# %%
data = [[_s.decode('utf-8') for _s in tmp[2:]] for tmp in data]
data
# Out:
# [['AllTitle:Holmes', 'word.predicate:wakeUp', 'AllTitle:Watson'],
#  ['AllTitle:Holmes', 'word.predicate:wakeUp', 'AbbeyGrange:Winter_of_1897'],
#  ['AllTitle:Holmes', 'word.predicate:wakeUp', 'AbbeyGrange:1897-02-01T08'],
#  ['AllTitle:Holmes', 'word.predicate:wakeUp', 'AbbeyGrange:early_morning'],
#  ['AllTitle:Holmes', 'word.predicate:wakeUp', 'DateTime:1897-02-01T08:00:00'],
#  ['AllTitle:Holmes', 'word.predicate:takeOut', 'AbbeyGrange:letter'],
#  ['AllTitle:Holmes', 'word.predicate:takeOut', 'AbbeyGrange:train'],
#  ['AllTitle:Holmes', 'word.predicate:takeOut', 'AbbeyGrange:1897-02-01T010'],
#  ['AllTitle:Holmes', 'word.predicate:takeOut', 'DateTime:1897-02-01T01:00:00'],
#  ['AllTitle:Holmes', 'word.predicate:readAloud', 'AbbeyGrange:letter'],
#  ['AllTitle:Holmes', 'word.predicate:readAloud', 'AbbeyGrange:004'],
#  ['AllTitle:Holmes', 'word.predicate:readAloud', 'AbbeyGrange:005'],
#  ['AllTitle:Holmes', 'word.predicate:readAloud', 'AbbeyGrange:006'],
# ...

# %%
dict_ = {}
dict_['Sir_Eustace_Brackenstall'] # 20
