# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
# ========== python ==========
import os
from logging import Logger
from pathlib import Path
import gc
# noinspection PyUnresolvedReferences
from typing import List, Dict, Tuple, Optional, Union, Callable, Final, Literal, get_args
import torch
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
PROJECT_DIR = Path().resolve().parents[1]
os.chdir(PROJECT_DIR)
SEED: Final = 42

# %%
from utils.setup import load_param, easy_logger, get_device
from utils.torch import load_model, torch_fix_seed
from torch.utils.tensorboard.writer import SummaryWriter
from ignite.handlers import Checkpoint
from run_for_KGC import main_function
logger = easy_logger('log/test.log')

# %%
args = load_param('saved_models/kgc/AbbeyGrange075/03/param.pkl')
device = get_device(device_name='cpu', logger=logger)
# args.pre_train = True
args.logger = logger
args.device = device
args.batch_size = 1
args.max_len=512
args.tensorboard_dir=None
args.only_load_trainer_evaluator=True
args.pre_train=False
del args.optuna_file, args.device_name, args.pid
del args.study_name, args.n_trials
logger.info(args)
# Out:
# 2022-12-31 18:18:24 - INFO - 3505047770.py - 13 - Namespace(notebook=False, train_anyway=False, logfile='saved_models/kgc/AbbeyGrange075/03/log.log', param_file='saved_models/kgc/AbbeyGrange075/03/param.pkl', tensorboard_dir=None, checkpoint_dir='saved_models/kgc/AbbeyGrange075/03/checkpoint/', model_path='saved_models/kgc/AbbeyGrange075/03/model.pth', model_version='03', resume_from_checkpoint=False, resume_from_last_point=False, only_load_trainer_evaluator=True, resume_checkpoint_path=None, console_level='info', pre_train=False, train_valid_test=False, only_train=True, use_for_challenge100=False, use_for_challenge090=False, use_for_challenge075=True, use_title='AbbeyGrange', do_optuna=False, story_special_num=5, relation_special_num=5, entity_special_num=5, padding_token_e=0, cls_token_e=1, mask_token_e=2, sep_token_e=3, bos_token_e=4, padding_token_r=0, cls_token_r=1, mask_token_r=2, sep_token_r=3, bos_token_r=4, padding_token_s=0, cls_token_s=1, mask_token_s=2, sep_token_s=3, bos_token_s=4, embedding_dim=128, entity_embedding_dim=128, relation_embedding_dim=64, separate_head_and_tail=False, batch_size=1, max_len=512, mask_percent=0.15, mask_mask_percent=0.8, mask_random_percent=0.1, mask_nomask_percent=0.1, no_use_pe=False, epoch=1500, lr=5e-05, lr_story=0.0001, lr_relation=1e-06, lr_entity=1e-06, valid_interval=10000, loss_weight_story=1.0, loss_weight_relation=1.0, loss_weight_entity=1.0, nhead=4, num_layers=4, dim_feedforward=1028, transformer_drop=0.1, position_encoder_drop=0.1, project_dir=PosixPath('/var/www'), logger=<Logger log (DEBUG)>, device=device(type='cpu'))

# %%
torch_fix_seed(seed=SEED)
model, data_dict = main_function(args, logger=logger)
encoder_last_layer = model.transformer.layers[-1]
model.eval()
dataset_train, dataset_valid, dataset_test = data_dict['datasets']
triple = dataset_train.triple
data_helper = data_dict['data_helper']
evaluator = data_dict['train_items']['evaluator']
load_model(model, args.model_path, device)
print(len(data_helper.processed_train_triple), len(triple))
# Out:
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 775 - ----- make datahelper start. -----
# 2022-12-31 18:18:24 - INFO - data_helper.py - 207 - ==========Show MyRawData==========
# 2022-12-31 18:18:24 - INFO - data_helper.py - 208 - entity_length: 7844
# 2022-12-31 18:18:24 - INFO - data_helper.py - 209 - relation_length: 63
# 2022-12-31 18:18:24 - INFO - data_helper.py - 212 - ==========Show MyRawData==========
# 2022-12-31 18:18:24 - INFO - data_helper.py - 440 - ==========Show DataHelper==========
# 2022-12-31 18:18:24 - INFO - data_helper.py - 441 - ==========
# 2022-12-31 18:18:24 - INFO - data_helper.py - 207 - ==========Show MyRawData==========
# 2022-12-31 18:18:24 - INFO - data_helper.py - 208 - entity_length: 7844
# 2022-12-31 18:18:24 - INFO - data_helper.py - 209 - relation_length: 63
# 2022-12-31 18:18:24 - INFO - data_helper.py - 212 - ==========Show MyRawData==========
# 2022-12-31 18:18:24 - INFO - data_helper.py - 443 - ==========
# 2022-12-31 18:18:24 - INFO - data_helper.py - 445 - entity_special_num: 5
# 2022-12-31 18:18:24 - INFO - data_helper.py - 446 - relation_special_num: 5
# 2022-12-31 18:18:24 - INFO - data_helper.py - 447 - ==========Show DataHelper==========
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 777 - ----- make datahelper complete. -----
# /var/www/src/run_for_KGC.py:655: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   triple = add_bos(triple, bos_token_e, bos_token_r, bos_token_e)
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 780 - ----- make and set dataloader start. -----
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 782 - ----- make and set dataloader complete. -----
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 784 - ----- make model start -----
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 756 - KgStoryTransformer03(
#   (entity_embeddings): Embedding(7849, 128, padding_idx=0)
#   (relation_embeddings): Embedding(68, 64, padding_idx=0)
#   (pe): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=1028, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=1028, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (activation): GELU(approximate='none')
#       )
#     )
#   )
#   (norm_after_transformer): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (head_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7849, bias=True)
#   )
#   (relation_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=68, bias=True)
#   )
#   (tail_maskdlm): Feedforward(
#     (linear1): Linear(in_features=128, out_features=128, bias=True)
#     (norm): Identity()
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=7849, bias=True)
#   )
#   (input_activate): Feedforward(
#     (linear1): Linear(in_features=320, out_features=128, bias=False)
#     (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (activation): GELU(approximate='none')
#     (linear2): Linear(in_features=128, out_features=128, bias=True)
#   )
# )
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 786 - ----- make model complete. -----
# 2022-12-31 18:18:24 - INFO - run_for_KGC.py - 531 - load trainer and evaluator. then end
# 13704 16821

# %%
from run_for_KGC import get_all_tokens
to_token = "{}".format
PAD_E = to_token("pad_e")
CLS_E = to_token('cls_e')
MASK_E: Final[str] = to_token('mask_e')
SEP_E: Final[str] = to_token('sep_e')
BOS_E: Final[str] = to_token('bos_e')
PAD_R: Final[str] = to_token('pad_r')
CLS_R: Final[str] = to_token('cls_r')
MASK_R: Final[str] = to_token('mask_r')
SEP_R: Final[str] = to_token('sep_r')
BOS_R: Final[str] = to_token('bos_r')

((pad_token_e, pad_token_r), (cls_token_e, cls_token_r), (mask_token_e, mask_token_r),
     (sep_token_e, sep_token_r), (bos_token_e, bos_token_r)) = get_all_tokens(args)

data_helper.set_special_names(
    index2name_entity={pad_token_e: PAD_E, cls_token_e: CLS_E, mask_token_e: MASK_E, sep_token_e: SEP_E, bos_token_e: BOS_E},
    index2name_relation={pad_token_r: PAD_R, cls_token_r: CLS_R, mask_token_r: MASK_R, sep_token_r: SEP_R, bos_token_r: BOS_R},
)

# %%
entities = data_helper.processed_entities
d_e = {e: i for i, e in enumerate(entities)}
relations = data_helper.processed_relations
d_r = {r: i for i, r in enumerate(relations)}
triple_df = pd.DataFrame([(entities[_t[0]], relations[_t[1]], entities[_t[2]]) for _t in triple], columns=['head', 'relation', 'tail']) 
# story_entities = triple_df
# triple_df

# %%
def extract(model, target, inputs):
    feature = None

    def forward_hook(module, inputs, _):
        # 順伝搬の出力を features というグローバル変数に記録する
        global features
        # 1. detach でグラフから切り離す。
        # 2. clone() でテンソルを複製する。モデルのレイヤーで ReLU(inplace=True) のように
        #    inplace で行う層があると、値がその後のレイヤーで書き換えられてまい、
        #    指定した層の出力が取得できない可能性があるため、clone() が必要。
        x, _, _ = inputs
        outputs = module.forward(x, x, x, need_weights=True)[1]
        features = outputs.detach().clone()

    # コールバック関数を登録する。
    handle = target.register_forward_hook(forward_hook)

    # 推論する
    model.eval()
    model(inputs, torch.LongTensor([[]]), torch.LongTensor([[]]), torch.LongTensor([[]]))

    # コールバック関数を解除する。
    handle.remove()

    return features

# %%
def heatmap_(index):
    input_ = dataset[index]
    # display([(i, entities[h], relations[r], entities[t]) for i, (h, r, t) in enumerate(input_)])
    features = extract(model, encoder_last_layer.self_attn, dataset[0][None, :])[0]
    df_atten = pd.DataFrame([[entities[h], relations[r], entities[t]]+[features[j, i].item() for j in range(len(features))] for i, (h, r, t) in enumerate(input_)])
    df_atten.columns=['head', 'relation', 'tail',] + [f'atten_from{i}' for i in range(len(df_atten.columns)-3)]
    display(df_atten)
    # ヒートマップの作成
    # sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
    for i in range(len(df_atten)):
        display(i, df_atten.iloc[i,:3].tolist())
        display(df_atten.sort_values(f'atten_from{i}', ascending=False).iloc[:10,:3])
        print("----------")
    plt.show()
# heatmap_(300)

# %%
def make_heatmap2_(input_):
    assert len(input_) == 1
    features = extract(model, encoder_last_layer.self_attn, input_)[0]
    df_atten = pd.DataFrame([[entities[h], relations[r], entities[t]]+[features[j, i].item() for j in range(len(features))] for i, (h, r, t) in enumerate(input_[0])])
    df_atten.columns=['head', 'relation', 'tail',] + [f'atten_from{i}' for i in range(len(df_atten.columns)-3)]
    sns.heatmap(df_atten.iloc[:,3:])
    plt.show()
    return df_atten

# %%
story_entities = triple_df['head'].tolist()
# print(story_entities)

# %%
def make_ranking(_from, _to, _predicate, _whom, _subject, _why, _what, _where):
    if not (_from is None and _to is None):
        _start_index = story_entities.index(_from)-1 
        _end_index = len(story_entities) - story_entities[::-1].index(_to)
    else: 
        _start_index = 0
        _end_index = 0
    question_ = torch.tensor(
        [
            [d_e['bos_e'],d_r['bos_r'],d_e['bos_e']],
            [d_e['mask_e'],d_r['kgc:infoSource'],d_e['AllTitle:Holmes']],
            [d_e['mask_e'],d_r['kgc:hasPredicate'],d_e[_predicate]],
            [d_e['mask_e'],d_r['kgc:whom'],d_e[_whom]],
            [d_e['mask_e'],d_r['kgc:subject'],d_e[_subject]],
            [d_e['mask_e'],d_r['kgc:why'],d_e[_why]],
            [d_e['mask_e'],d_r['kgc:what'],d_e[_what]],
            [d_e['mask_e'],d_r['kgc:where'],d_e[_where]],
        ]
    )
    mask_ = torch.tensor(
        [
            [False, False, False],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
            [True, False, True],
        ]
    )
    questions = torch.cat([triple[_start_index: _end_index], question_], dim=0).unsqueeze(0)
    masks = torch.cat([torch.zeros(_end_index-_start_index,3), mask_], dim=0).to(torch.bool).transpose(1,0).unsqueeze(0)
    tmp = []
    with torch.no_grad():
        _, (story_pred, relation_pred, entity_pred) = model(questions, masks[:,0], masks[:,1], masks[:,2])
        sorted_ = torch.argsort(entity_pred.to('cpu'), dim=1, descending=True)
        for i in range(sorted_.shape[1]):
            ans_= sorted_[:, i]
            info_source_, predicate_, whom_, subj_, why_, what_, where_ = ans_
            tmp.append([entities[predicate_], entities[whom_], entities[subj_], entities[why_], entities[what_], entities[where_]])
    df_ranking = pd.DataFrame(tmp, columns=['predicate', 'whom', 'subject', 'why', 'what', 'where'])
    df_attension = make_heatmap2_(questions)
    return df_ranking, df_attension

# %%
MASK_E = 'mask_e'
KILL = 'word.predicate:kill'
TAKE = 'word.predicate:take'
BRING = 'word.predicate:bring'
DIE = 'word.predicate:die'
HIDE = 'word.predicate:hide'

# %% [markdown]
# ### 僧坊荘園
# Who killed Lord Blackenstall? (criminal & explanation)
# 被害者: Sir_Eustace_Brackenstall
# 犯人:
# 犯行動機:

# %%
victim = 'AbbeyGrange:Sir_Eustace_Brackenstall'
df_ranking_AbbeyGrange, df_attension_AbbeyGrange = make_ranking(
    f'AbbeyGrange:{310-80+1}', 'AbbeyGrange:310', KILL, victim, MASK_E, MASK_E, MASK_E, MASK_E)

display(df_ranking_AbbeyGrange.iloc[:20,:])
# display(df_attension_SpeckledBand)
# ヒートマップの作成
# sns.heatmap(df_atten.iloc[:,3:].iloc[:32,:32])
len_ = len(df_attension_AbbeyGrange)
for i in range(len_-20, len_):
    display(i, df_attension_AbbeyGrange.iloc[i,:3].tolist())
    display(df_attension_AbbeyGrange.sort_values(f'atten_from{i}', ascending=False).iloc[:20,[0,1,2,3+i]])
    print("----------")
# Out:
#                      predicate                                   whom  \
# 0         word.predicate:exist                   AbbeyGrange:Criminal
# 1          word.predicate:kill          AbbeyGrange:Lady_Brackenstall
# 2           word.predicate:sit                        AllTitle:Holmes
# 3           word.predicate:say   AbbeyGrange:Sir_Eustace_Brackenstall
# 4          word.predicate:find             ACaseOfIdentity:Sutherland
# 5         word.predicate:enter                AbbeyGrange:Jack_Croker
# 6          word.predicate:have                     CrookedMan:Barclay
# 7            word.predicate:go            SilverBlaze:Fitzroy_Simpson
# 8      word.predicate:notExist                SilverBlaze:Silas_Brown
# 9   ACaseOfIdentity:Sutherland                    AbbeyGrange:Theresa
# 10       word.predicate:wander                      CrookedMan:Murphy
# 11         word.predicate:meet                     CrookedMan:Rasheen
# 12        word.predicate:goOut               SilverBlaze:Silver_Blaze
# 13      word.predicate:examine           DateTime:1898-08-13T03:02:00
# 14          CrookedMan:Barclay                       CrookedMan:Henry
# 15       word.predicate:arrive              ResidentPatient:Young_man
# 16          word.predicate:cut  AbbeyGrange:Burglary_team_of_Lewisham
# 17         word.predicate:good              ACaseOfIdentity:Windibank
# 18         word.predicate:stop                      DevilsFoot:Brenda
# 19          word.predicate:hit                    CrookedMan:Morrison
#
#                                   subject  \
# 0                 AbbeyGrange:Jack_Croker
# 1           AbbeyGrange:Lady_Brackenstall
# 2                    AbbeyGrange:Criminal
# 3    AbbeyGrange:Sir_Eustace_Brackenstall
# 4                      CrookedMan:Rasheen
# 5                     AbbeyGrange:Theresa
# 6            DateTime:1898-08-13T03:02:00
# 7                         AllTitle:Holmes
# 8                      CrookedMan:Barclay
# 9             AbbeyGrange:Stanley_Hopkins
# 10            SilverBlaze:Fitzroy_Simpson
# 11             ACaseOfIdentity:Sutherland
# 12                    CrookedMan:Morrison
# 13               SilverBlaze:Silver_Blaze
# 14                SilverBlaze:Silas_Brown
# 15                 ACaseOfIdentity:Hosmer
# 16                       CrookedMan:beast
# 17                     SpeckledBand:Helen
# 18  AbbeyGrange:Burglary_team_of_Lewisham
# 19          AbbeyGrange:Thought_of_Holmes
#
#                                      why  \
# 0          AbbeyGrange:Lady_Brackenstall
# 1   AbbeyGrange:Sir_Eustace_Brackenstall
# 2                    CrookedMan:Morrison
# 3                 ACaseOfIdentity:Hosmer
# 4                       CrookedMan:Teddy
# 5                    AbbeyGrange:Theresa
# 6                       AbbeyGrange:dust
# 7                     word.predicate:see
# 8                   AbbeyGrange:Criminal
# 9                   DancingMen:Horse_boy
# 10                       AbbeyGrange:041
# 11               AbbeyGrange:Jack_Croker
# 12                      CrookedMan:Henry
# 13            ACaseOfIdentity:Sutherland
# 14                    CrookedMan:Barclay
# 15                DevilsFoot:living_room
# 16                      CrookedMan:beast
# 17                    SpeckledBand:Julia
# 18                   word.predicate:thin
# 19                   DevilsFoot:Roundhay
#
#                                       what  \
# 0               ACaseOfIdentity:Sutherland
# 1                          AllTitle:Holmes
# 2     AbbeyGrange:Sir_Eustace_Brackenstall
# 3            AbbeyGrange:Lady_Brackenstall
# 4                        CrookedMan:Murphy
# 5                   ACaseOfIdentity:Hosmer
# 6                  AbbeyGrange:Jack_Croker
# 7                          AllTitle:Watson
# 8                       CrookedMan:Barclay
# 9                         CrookedMan:Henry
# 10  AbbeyGrange:Thought_of_Stanley_Hopkins
# 11                    AbbeyGrange:Criminal
# 12                      SpeckledBand:Julia
# 13            DateTime:1898-08-13T03:02:00
# 14              AbbeyGrange:cork_of_bottle
# 15                   ACaseOfIdentity:Woman
# 16                      SpeckledBand:Helen
# 17                AbbeyGrange:cord_of_bell
# 18                      CrookedMan:Rasheen
# 19                 SilverBlaze:Silas_Brown
#
#                                      where
# 0                          AllTitle:Holmes
# 1                      AbbeyGrange:Theresa
# 2                  AbbeyGrange:dining_room
# 3            AbbeyGrange:Lady_Brackenstall
# 4               ACaseOfIdentity:Sutherland
# 5             DateTime:1898-08-13T03:02:00
# 6   AbbeyGrange:Thought_of_Stanley_Hopkins
# 7                   DevilsFoot:living_room
# 8              AbbeyGrange:Stanley_Hopkins
# 9                 SilverBlaze:Silver_Blaze
# 10           AbbeyGrange:Thought_of_Holmes
# 11                       CrookedMan:Murphy
# 12                      CrookedMan:Barclay
# 13                    DancingMen:Horse_boy
# 14                AbbeyGrange:Abbey_Grange
# 15    AbbeyGrange:Sir_Eustace_Brackenstall
# 16                AbbeyGrange:cord_of_bell
# 17                    AbbeyGrange:Criminal
# 18                CrookedMan:Royal_Mallows
# 19                 AbbeyGrange:Jack_Croker
# 413
# ['AbbeyGrange:307', 'kgc:when', 'AbbeyGrange:end_of_case']
#                  head         relation  \
# 349   AbbeyGrange:296      kgc:subject
# 322   AbbeyGrange:291         kgc:what
# 384   AbbeyGrange:302      kgc:subject
# 273   AbbeyGrange:283  kgc:hasProperty
# 376   AbbeyGrange:300         kgc:what
# 271   AbbeyGrange:283      kgc:subject
# 345   AbbeyGrange:295      kgc:subject
# 375   AbbeyGrange:300         kgc:what
# 272   AbbeyGrange:283  kgc:hasProperty
# 268   AbbeyGrange:282      kgc:subject
# 234   AbbeyGrange:274         kgc:time
# 352   AbbeyGrange:296   kgc:infoSource
# 377   AbbeyGrange:300         kgc:what
# 418   AbbeyGrange:309      kgc:subject
# 357   AbbeyGrange:297   kgc:infoSource
# 351   AbbeyGrange:296         kgc:what
# 230   AbbeyGrange:274      kgc:subject
# 415   AbbeyGrange:308      kgc:subject
# 332  AbbeyGrange:292a         kgc:what
# 407   AbbeyGrange:306         kgc:what
#
#                                        tail  atten_from413
# 349               AbbeyGrange:Holes_of_pond       0.015013
# 322                         AbbeyGrange:290       0.012258
# 384                      AbbeyGrange:police       0.009627
# 273                 word.predicate:faithful       0.009495
# 376                         AbbeyGrange:298       0.009482
# 271                 AbbeyGrange:Jack_Croker       0.008807
# 345              AbbeyGrange:pond_of_garden       0.008651
# 375                         AbbeyGrange:297       0.008603
# 272                 word.predicate:Friendly       0.008497
# 268                 AbbeyGrange:Jack_Croker       0.008494
# 234            DateTime:1897-02-01T12:00:00       0.008262
# 352           AbbeyGrange:Thought_of_Holmes       0.008182
# 377                         AbbeyGrange:299       0.007829
# 418                 AbbeyGrange:Jack_Croker       0.007592
# 357  AbbeyGrange:Thought_of_Stanley_Hopkins       0.007583
# 351                       AbbeyGrange:cache       0.007339
# 230                 AbbeyGrange:Jack_Croker       0.007318
# 415                 AbbeyGrange:Jack_Croker       0.007270
# 332    AbbeyGrange:bottom_of_pond_of_garden       0.007245
# 407            AbbeyGrange:Private_decision       0.007148
# ----------
# 414
# ['bos_e', 'bos_r', 'bos_e']
#                 head          relation                  tail  atten_from414
# 21             bos_e             bos_r                 bos_e       0.006657
# 15             bos_e             bos_r                 bos_e       0.006493
# 219  AbbeyGrange:272  kgc:hasPredicate  word.predicate:exist       0.006356
# 32             bos_e             bos_r                 bos_e       0.006183
# 26             bos_e             bos_r                 bos_e       0.006121
# 10             bos_e             bos_r                 bos_e       0.005992
# 105            bos_e             bos_r                 bos_e       0.005951
# 109            bos_e             bos_r                 bos_e       0.005947
# 212  AbbeyGrange:271  kgc:hasPredicate  word.predicate:exist       0.005925
# 92             bos_e             bos_r                 bos_e       0.005878
# 146            bos_e             bos_r                 bos_e       0.005808
# 372            bos_e             bos_r                 bos_e       0.005764
# 59             bos_e             bos_r                 bos_e       0.005750
# 140            bos_e             bos_r                 bos_e       0.005658
# 53             bos_e             bos_r                 bos_e       0.005640
# 100            bos_e             bos_r                 bos_e       0.005601
# 324            bos_e             bos_r                 bos_e       0.005594
# 137            bos_e             bos_r                 bos_e       0.005584
# 6              bos_e             bos_r                 bos_e       0.005560
# 363            bos_e             bos_r                 bos_e       0.005542
# ----------
# 415
# ['AbbeyGrange:308', 'kgc:subject', 'AbbeyGrange:Jack_Croker']
#                 head         relation  \
# 418  AbbeyGrange:309      kgc:subject
# 415  AbbeyGrange:308      kgc:subject
# 260  AbbeyGrange:280      kgc:subject
# 352  AbbeyGrange:296   kgc:infoSource
# 357  AbbeyGrange:297   kgc:infoSource
# 349  AbbeyGrange:296      kgc:subject
# 405  AbbeyGrange:306      kgc:subject
# 338  AbbeyGrange:293   kgc:infoSource
# 347  AbbeyGrange:295   kgc:infoSource
# 255  AbbeyGrange:279      kgc:subject
# 268  AbbeyGrange:282      kgc:subject
# 422  AbbeyGrange:310      kgc:subject
# 384  AbbeyGrange:302      kgc:subject
# 362  AbbeyGrange:298   kgc:infoSource
# 272  AbbeyGrange:283  kgc:hasProperty
# 158  AbbeyGrange:260      kgc:subject
# 269  AbbeyGrange:282  kgc:hasProperty
# 401  AbbeyGrange:305      kgc:subject
# 367  AbbeyGrange:299   kgc:infoSource
# 364  AbbeyGrange:299      kgc:subject
#
#                                         tail  atten_from415
# 418                  AbbeyGrange:Jack_Croker       0.020947
# 415                  AbbeyGrange:Jack_Croker       0.013985
# 260                  AbbeyGrange:Jack_Croker       0.013040
# 352            AbbeyGrange:Thought_of_Holmes       0.012946
# 357   AbbeyGrange:Thought_of_Stanley_Hopkins       0.012295
# 349                AbbeyGrange:Holes_of_pond       0.011314
# 405              AbbeyGrange:Stanley_Hopkins       0.011218
# 338            AbbeyGrange:Thought_of_Holmes       0.010872
# 347            AbbeyGrange:Thought_of_Holmes       0.010846
# 255                  AbbeyGrange:Jack_Croker       0.010654
# 268                  AbbeyGrange:Jack_Croker       0.010622
# 422                  AbbeyGrange:Jack_Croker       0.010565
# 384                       AbbeyGrange:police       0.010398
# 362   AbbeyGrange:Thought_of_Stanley_Hopkins       0.009988
# 272                  word.predicate:Friendly       0.009988
# 158            AbbeyGrange:Lady_Brackenstall       0.009591
# 269                 word.predicate:inpatient       0.009573
# 401  AbbeyGrange:Findings_of_Stanley_Hopkins       0.009453
# 367   AbbeyGrange:Thought_of_Stanley_Hopkins       0.009383
# 364                     AbbeyGrange:Criminal       0.009307
# ----------
# 416
# ['AbbeyGrange:308', 'kgc:hasProperty', 'word.predicate:manly']
#                 head     relation                                     tail  \
# 264  AbbeyGrange:281  kgc:subject   AbbeyGrange:Personality_of_Jack_Croker
# 255  AbbeyGrange:279  kgc:subject                  AbbeyGrange:Jack_Croker
# 422  AbbeyGrange:310  kgc:subject                  AbbeyGrange:Jack_Croker
# 268  AbbeyGrange:282  kgc:subject                  AbbeyGrange:Jack_Croker
# 418  AbbeyGrange:309  kgc:subject                  AbbeyGrange:Jack_Croker
# 230  AbbeyGrange:274  kgc:subject                  AbbeyGrange:Jack_Croker
# 415  AbbeyGrange:308  kgc:subject                  AbbeyGrange:Jack_Croker
# 271  AbbeyGrange:283  kgc:subject                  AbbeyGrange:Jack_Croker
# 260  AbbeyGrange:280  kgc:subject                  AbbeyGrange:Jack_Croker
# 224  AbbeyGrange:273  kgc:subject                  AbbeyGrange:Jack_Croker
# 247  AbbeyGrange:277  kgc:subject                  AbbeyGrange:Jack_Croker
# 228  AbbeyGrange:273     kgc:time             DateTime:1895-02-01T12:00:00
# 234  AbbeyGrange:274     kgc:time             DateTime:1897-02-01T12:00:00
# 251  AbbeyGrange:278  kgc:subject        AbbeyGrange:Career_of_Jack_Croker
# 258  AbbeyGrange:279    kgc:where                     AbbeyGrange:any_ship
# 211  AbbeyGrange:271  kgc:subject            AbbeyGrange:Rock-of-Gibraltar
# 401  AbbeyGrange:305  kgc:subject  AbbeyGrange:Findings_of_Stanley_Hopkins
# 262  AbbeyGrange:280     kgc:what                         AbbeyGrange:ship
# 384  AbbeyGrange:302  kgc:subject                       AbbeyGrange:police
# 236  AbbeyGrange:275  kgc:subject                AbbeyGrange:The_Bays_Rock
#
#      atten_from416
# 264       0.013878
# 255       0.013533
# 422       0.012525
# 268       0.012091
# 418       0.011719
# 230       0.011076
# 415       0.010981
# 271       0.009998
# 260       0.009543
# 224       0.009507
# 247       0.008815
# 228       0.007784
# 234       0.007552
# 251       0.007447
# 258       0.006762
# 211       0.006659
# 401       0.006425
# 262       0.006340
# 384       0.006232
# 236       0.006207
# ----------
# 417
# ['bos_e', 'bos_r', 'bos_e']
#                 head          relation                  tail  atten_from417
# 21             bos_e             bos_r                 bos_e       0.006689
# 15             bos_e             bos_r                 bos_e       0.006513
# 219  AbbeyGrange:272  kgc:hasPredicate  word.predicate:exist       0.006448
# 32             bos_e             bos_r                 bos_e       0.006193
# 26             bos_e             bos_r                 bos_e       0.006161
# 212  AbbeyGrange:271  kgc:hasPredicate  word.predicate:exist       0.006052
# 10             bos_e             bos_r                 bos_e       0.005979
# 105            bos_e             bos_r                 bos_e       0.005954
# 109            bos_e             bos_r                 bos_e       0.005940
# 92             bos_e             bos_r                 bos_e       0.005907
# 372            bos_e             bos_r                 bos_e       0.005816
# 59             bos_e             bos_r                 bos_e       0.005810
# 146            bos_e             bos_r                 bos_e       0.005788
# 53             bos_e             bos_r                 bos_e       0.005698
# 100            bos_e             bos_r                 bos_e       0.005630
# 140            bos_e             bos_r                 bos_e       0.005620
# 363            bos_e             bos_r                 bos_e       0.005617
# 324            bos_e             bos_r                 bos_e       0.005611
# 6              bos_e             bos_r                 bos_e       0.005589
# 137            bos_e             bos_r                 bos_e       0.005568
# ----------
# 418
# ['AbbeyGrange:309', 'kgc:subject', 'AbbeyGrange:Jack_Croker']
#                 head         relation                                    tail  \
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 255  AbbeyGrange:279      kgc:subject                 AbbeyGrange:Jack_Croker
# 260  AbbeyGrange:280      kgc:subject                 AbbeyGrange:Jack_Croker
# 422  AbbeyGrange:310      kgc:subject                 AbbeyGrange:Jack_Croker
# 272  AbbeyGrange:283  kgc:hasProperty                 word.predicate:Friendly
# 416  AbbeyGrange:308  kgc:hasProperty                    word.predicate:manly
# 268  AbbeyGrange:282      kgc:subject                 AbbeyGrange:Jack_Croker
# 269  AbbeyGrange:282  kgc:hasProperty                word.predicate:inpatient
# 349  AbbeyGrange:296      kgc:subject               AbbeyGrange:Holes_of_pond
# 264  AbbeyGrange:281      kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 352  AbbeyGrange:296   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 271  AbbeyGrange:283      kgc:subject                 AbbeyGrange:Jack_Croker
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 273  AbbeyGrange:283  kgc:hasProperty                 word.predicate:faithful
# 247  AbbeyGrange:277      kgc:subject                 AbbeyGrange:Jack_Croker
# 405  AbbeyGrange:306      kgc:subject             AbbeyGrange:Stanley_Hopkins
# 364  AbbeyGrange:299      kgc:subject                    AbbeyGrange:Criminal
# 359  AbbeyGrange:298      kgc:subject                    AbbeyGrange:Criminal
# 354  AbbeyGrange:297      kgc:subject                    AbbeyGrange:Criminal
#
#      atten_from418
# 418       0.040759
# 415       0.018629
# 255       0.017505
# 260       0.015802
# 422       0.015074
# 272       0.011697
# 416       0.011541
# 268       0.010953
# 269       0.010768
# 349       0.010399
# 264       0.009638
# 352       0.009430
# 271       0.009339
# 384       0.009244
# 273       0.009169
# 247       0.008977
# 405       0.008902
# 364       0.008457
# 359       0.008430
# 354       0.008394
# ----------
# 419
# ['AbbeyGrange:309', 'kgc:hasPredicate', 'word.predicate:come']
#                 head         relation                                    tail  \
# 255  AbbeyGrange:279      kgc:subject                 AbbeyGrange:Jack_Croker
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 262  AbbeyGrange:280         kgc:what                        AbbeyGrange:ship
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 257  AbbeyGrange:279         kgc:what          AbbeyGrange:Comparable_Officer
# 273  AbbeyGrange:283  kgc:hasProperty                 word.predicate:faithful
# 268  AbbeyGrange:282      kgc:subject                 AbbeyGrange:Jack_Croker
# 416  AbbeyGrange:308  kgc:hasProperty                    word.predicate:manly
# 422  AbbeyGrange:310      kgc:subject                 AbbeyGrange:Jack_Croker
# 264  AbbeyGrange:281      kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 271  AbbeyGrange:283      kgc:subject                 AbbeyGrange:Jack_Croker
# 258  AbbeyGrange:279        kgc:where                    AbbeyGrange:any_ship
# 272  AbbeyGrange:283  kgc:hasProperty                 word.predicate:Friendly
# 230  AbbeyGrange:274      kgc:subject                 AbbeyGrange:Jack_Croker
# 420  AbbeyGrange:309        kgc:where              AbbeyGrange:room_of_Holmes
# 393  AbbeyGrange:303      kgc:subject                    AbbeyGrange:Blinding
# 407  AbbeyGrange:306         kgc:what            AbbeyGrange:Private_decision
# 322  AbbeyGrange:291         kgc:what                         AbbeyGrange:290
# 245  AbbeyGrange:276         kgc:what               AbbeyGrange:The_Bays_Rock
# 269  AbbeyGrange:282  kgc:hasProperty                word.predicate:inpatient
#
#      atten_from419
# 255       0.020132
# 418       0.017873
# 262       0.016954
# 415       0.014531
# 257       0.013817
# 273       0.012001
# 268       0.011029
# 416       0.010894
# 422       0.010748
# 264       0.010191
# 271       0.010179
# 258       0.010103
# 272       0.009922
# 230       0.009895
# 420       0.009221
# 393       0.009154
# 407       0.008703
# 322       0.008662
# 245       0.008621
# 269       0.008485
# ----------
# 420
# ['AbbeyGrange:309', 'kgc:where', 'AbbeyGrange:room_of_Holmes']
#                 head        relation                                    tail  \
# 258  AbbeyGrange:279       kgc:where                    AbbeyGrange:any_ship
# 418  AbbeyGrange:309     kgc:subject                 AbbeyGrange:Jack_Croker
# 420  AbbeyGrange:309       kgc:where              AbbeyGrange:room_of_Holmes
# 262  AbbeyGrange:280        kgc:what                        AbbeyGrange:ship
# 257  AbbeyGrange:279        kgc:what          AbbeyGrange:Comparable_Officer
# 255  AbbeyGrange:279     kgc:subject                 AbbeyGrange:Jack_Croker
# 260  AbbeyGrange:280     kgc:subject                 AbbeyGrange:Jack_Croker
# 268  AbbeyGrange:282     kgc:subject                 AbbeyGrange:Jack_Croker
# 415  AbbeyGrange:308     kgc:subject                 AbbeyGrange:Jack_Croker
# 247  AbbeyGrange:277     kgc:subject                 AbbeyGrange:Jack_Croker
# 230  AbbeyGrange:274     kgc:subject                 AbbeyGrange:Jack_Croker
# 349  AbbeyGrange:296     kgc:subject               AbbeyGrange:Holes_of_pond
# 422  AbbeyGrange:310     kgc:subject                 AbbeyGrange:Jack_Croker
# 271  AbbeyGrange:283     kgc:subject                 AbbeyGrange:Jack_Croker
# 264  AbbeyGrange:281     kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 249  AbbeyGrange:277       kgc:where                    AbbeyGrange:Sydenham
# 407  AbbeyGrange:306        kgc:what            AbbeyGrange:Private_decision
# 387  AbbeyGrange:302       kgc:where                    AbbeyGrange:New_York
# 224  AbbeyGrange:273     kgc:subject                 AbbeyGrange:Jack_Croker
# 367  AbbeyGrange:299  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
#
#      atten_from420
# 258       0.016988
# 418       0.015837
# 420       0.015550
# 262       0.015419
# 257       0.013652
# 255       0.013621
# 260       0.012453
# 268       0.011884
# 415       0.011162
# 247       0.010482
# 230       0.009986
# 349       0.009986
# 422       0.009376
# 271       0.009309
# 264       0.009268
# 249       0.008547
# 407       0.008338
# 387       0.008074
# 224       0.007988
# 367       0.007719
# ----------
# 421
# ['bos_e', 'bos_r', 'bos_e']
#                 head          relation                  tail  atten_from421
# 21             bos_e             bos_r                 bos_e       0.006643
# 219  AbbeyGrange:272  kgc:hasPredicate  word.predicate:exist       0.006642
# 15             bos_e             bos_r                 bos_e       0.006492
# 212  AbbeyGrange:271  kgc:hasPredicate  word.predicate:exist       0.006483
# 32             bos_e             bos_r                 bos_e       0.006148
# 26             bos_e             bos_r                 bos_e       0.006104
# 10             bos_e             bos_r                 bos_e       0.005959
# 105            bos_e             bos_r                 bos_e       0.005934
# 109            bos_e             bos_r                 bos_e       0.005930
# 92             bos_e             bos_r                 bos_e       0.005921
# 372            bos_e             bos_r                 bos_e       0.005790
# 59             bos_e             bos_r                 bos_e       0.005785
# 146            bos_e             bos_r                 bos_e       0.005734
# 53             bos_e             bos_r                 bos_e       0.005659
# 100            bos_e             bos_r                 bos_e       0.005587
# 363            bos_e             bos_r                 bos_e       0.005573
# 324            bos_e             bos_r                 bos_e       0.005568
# 140            bos_e             bos_r                 bos_e       0.005561
# 6              bos_e             bos_r                 bos_e       0.005537
# 84             bos_e             bos_r                 bos_e       0.005529
# ----------
# 422
# ['AbbeyGrange:310', 'kgc:subject', 'AbbeyGrange:Jack_Croker']
#                 head         relation                                    tail  \
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 422  AbbeyGrange:310      kgc:subject                 AbbeyGrange:Jack_Croker
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 260  AbbeyGrange:280      kgc:subject                 AbbeyGrange:Jack_Croker
# 416  AbbeyGrange:308  kgc:hasProperty                    word.predicate:manly
# 357  AbbeyGrange:297   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 255  AbbeyGrange:279      kgc:subject                 AbbeyGrange:Jack_Croker
# 362  AbbeyGrange:298   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 364  AbbeyGrange:299      kgc:subject                    AbbeyGrange:Criminal
# 268  AbbeyGrange:282      kgc:subject                 AbbeyGrange:Jack_Croker
# 367  AbbeyGrange:299   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 352  AbbeyGrange:296   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 269  AbbeyGrange:282  kgc:hasProperty                word.predicate:inpatient
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 224  AbbeyGrange:273      kgc:subject                 AbbeyGrange:Jack_Croker
# 230  AbbeyGrange:274      kgc:subject                 AbbeyGrange:Jack_Croker
# 423  AbbeyGrange:310  kgc:hasProperty            word.predicate:nimble-footed
# 359  AbbeyGrange:298      kgc:subject                    AbbeyGrange:Criminal
# 264  AbbeyGrange:281      kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 158  AbbeyGrange:260      kgc:subject           AbbeyGrange:Lady_Brackenstall
#
#      atten_from422
# 418       0.024780
# 422       0.018158
# 415       0.014414
# 260       0.014035
# 416       0.012329
# 357       0.012227
# 255       0.011218
# 362       0.011120
# 364       0.010839
# 268       0.010702
# 367       0.010586
# 352       0.010083
# 269       0.009942
# 384       0.009749
# 224       0.009663
# 230       0.009595
# 423       0.009322
# 359       0.009217
# 264       0.009049
# 158       0.008926
# ----------
# 423
# ['AbbeyGrange:310', 'kgc:hasProperty', 'word.predicate:nimble-footed']
#                 head         relation                                    tail  \
# 230  AbbeyGrange:274      kgc:subject                 AbbeyGrange:Jack_Croker
# 268  AbbeyGrange:282      kgc:subject                 AbbeyGrange:Jack_Croker
# 422  AbbeyGrange:310      kgc:subject                 AbbeyGrange:Jack_Croker
# 264  AbbeyGrange:281      kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 224  AbbeyGrange:273      kgc:subject                 AbbeyGrange:Jack_Croker
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 255  AbbeyGrange:279      kgc:subject                 AbbeyGrange:Jack_Croker
# 260  AbbeyGrange:280      kgc:subject                 AbbeyGrange:Jack_Croker
# 247  AbbeyGrange:277      kgc:subject                 AbbeyGrange:Jack_Croker
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 211  AbbeyGrange:271      kgc:subject           AbbeyGrange:Rock-of-Gibraltar
# 271  AbbeyGrange:283      kgc:subject                 AbbeyGrange:Jack_Croker
# 228  AbbeyGrange:273         kgc:time            DateTime:1895-02-01T12:00:00
# 251  AbbeyGrange:278      kgc:subject       AbbeyGrange:Career_of_Jack_Croker
# 367  AbbeyGrange:299   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 243  AbbeyGrange:276      kgc:subject                 AbbeyGrange:Jack_Croker
# 416  AbbeyGrange:308  kgc:hasProperty                    word.predicate:manly
# 234  AbbeyGrange:274         kgc:time            DateTime:1897-02-01T12:00:00
# 357  AbbeyGrange:297   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
#
#      atten_from423
# 230       0.012591
# 268       0.012270
# 422       0.011279
# 264       0.010942
# 224       0.010197
# 415       0.009818
# 418       0.009040
# 255       0.008760
# 260       0.008551
# 247       0.008503
# 384       0.007954
# 211       0.007883
# 271       0.007723
# 228       0.007285
# 251       0.006914
# 367       0.006885
# 243       0.006864
# 416       0.006644
# 234       0.006491
# 357       0.006465
# ----------
# 424
# ['AbbeyGrange:310', 'kgc:when', 'AbbeyGrange:309']
#                 head         relation                                    tail  \
# 230  AbbeyGrange:274      kgc:subject                 AbbeyGrange:Jack_Croker
# 268  AbbeyGrange:282      kgc:subject                 AbbeyGrange:Jack_Croker
# 236  AbbeyGrange:275      kgc:subject               AbbeyGrange:The_Bays_Rock
# 264  AbbeyGrange:281      kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 234  AbbeyGrange:274         kgc:time            DateTime:1897-02-01T12:00:00
# 272  AbbeyGrange:283  kgc:hasProperty                 word.predicate:Friendly
# 273  AbbeyGrange:283  kgc:hasProperty                 word.predicate:faithful
# 271  AbbeyGrange:283      kgc:subject                 AbbeyGrange:Jack_Croker
# 422  AbbeyGrange:310      kgc:subject                 AbbeyGrange:Jack_Croker
# 228  AbbeyGrange:273         kgc:time            DateTime:1895-02-01T12:00:00
# 224  AbbeyGrange:273      kgc:subject                 AbbeyGrange:Jack_Croker
# 269  AbbeyGrange:282  kgc:hasProperty                word.predicate:inpatient
# 211  AbbeyGrange:271      kgc:subject           AbbeyGrange:Rock-of-Gibraltar
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 349  AbbeyGrange:296      kgc:subject               AbbeyGrange:Holes_of_pond
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 416  AbbeyGrange:308  kgc:hasProperty                    word.predicate:manly
# 394  AbbeyGrange:303  kgc:hasProperty                     word.predicate:Hint
# 247  AbbeyGrange:277      kgc:subject                 AbbeyGrange:Jack_Croker
#
#      atten_from424
# 230       0.011813
# 268       0.011261
# 236       0.009248
# 264       0.008559
# 234       0.008315
# 272       0.007896
# 273       0.007808
# 271       0.007769
# 422       0.007749
# 228       0.007353
# 224       0.007221
# 269       0.007182
# 211       0.007073
# 418       0.007071
# 384       0.007051
# 349       0.006999
# 415       0.006716
# 416       0.006661
# 394       0.006476
# 247       0.006434
# ----------
# 425
# ['bos_e', 'bos_r', 'bos_e']
#                 head          relation                  tail  atten_from425
# 21             bos_e             bos_r                 bos_e       0.006613
# 219  AbbeyGrange:272  kgc:hasPredicate  word.predicate:exist       0.006594
# 15             bos_e             bos_r                 bos_e       0.006466
# 212  AbbeyGrange:271  kgc:hasPredicate  word.predicate:exist       0.006443
# 32             bos_e             bos_r                 bos_e       0.006142
# 26             bos_e             bos_r                 bos_e       0.006083
# 105            bos_e             bos_r                 bos_e       0.005974
# 109            bos_e             bos_r                 bos_e       0.005965
# 10             bos_e             bos_r                 bos_e       0.005946
# 92             bos_e             bos_r                 bos_e       0.005933
# 146            bos_e             bos_r                 bos_e       0.005764
# 59             bos_e             bos_r                 bos_e       0.005762
# 372            bos_e             bos_r                 bos_e       0.005747
# 53             bos_e             bos_r                 bos_e       0.005639
# 100            bos_e             bos_r                 bos_e       0.005611
# 140            bos_e             bos_r                 bos_e       0.005602
# 324            bos_e             bos_r                 bos_e       0.005548
# 363            bos_e             bos_r                 bos_e       0.005536
# 137            bos_e             bos_r                 bos_e       0.005522
# 6              bos_e             bos_r                 bos_e       0.005518
# ----------
# 426
# ['mask_e', 'kgc:infoSource', 'AllTitle:Holmes']
#                 head         relation                                    tail  \
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 422  AbbeyGrange:310      kgc:subject                 AbbeyGrange:Jack_Croker
# 352  AbbeyGrange:296   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 367  AbbeyGrange:299   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 388  AbbeyGrange:302   kgc:infoSource             AbbeyGrange:Stanley_Hopkins
# 158  AbbeyGrange:260      kgc:subject           AbbeyGrange:Lady_Brackenstall
# 357  AbbeyGrange:297   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 380  AbbeyGrange:301      kgc:subject             AbbeyGrange:Stanley_Hopkins
# 362  AbbeyGrange:298   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 260  AbbeyGrange:280      kgc:subject                 AbbeyGrange:Jack_Croker
# 405  AbbeyGrange:306      kgc:subject             AbbeyGrange:Stanley_Hopkins
# 416  AbbeyGrange:308  kgc:hasProperty                    word.predicate:manly
# 393  AbbeyGrange:303      kgc:subject                    AbbeyGrange:Blinding
# 318  AbbeyGrange:290   kgc:infoSource             AbbeyGrange:Stanley_Hopkins
# 373  AbbeyGrange:300      kgc:subject             AbbeyGrange:Stanley_Hopkins
# 420  AbbeyGrange:309        kgc:where              AbbeyGrange:room_of_Holmes
# 429           mask_e      kgc:subject                                  mask_e
# 410  AbbeyGrange:307      kgc:subject                         AllTitle:Watson
#
#      atten_from426
# 418       0.011801
# 415       0.011142
# 422       0.009680
# 352       0.008940
# 384       0.008819
# 367       0.007960
# 388       0.007954
# 158       0.007826
# 357       0.007774
# 380       0.007730
# 362       0.006736
# 260       0.006472
# 405       0.006410
# 416       0.006078
# 393       0.006071
# 318       0.006025
# 373       0.006011
# 420       0.005867
# 429       0.005866
# 410       0.005860
# ----------
# 427
# ['mask_e', 'kgc:hasPredicate', 'word.predicate:kill']
#                 head         relation                                    tail  \
# 262  AbbeyGrange:280         kgc:what                        AbbeyGrange:ship
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 322  AbbeyGrange:291         kgc:what                         AbbeyGrange:290
# 273  AbbeyGrange:283  kgc:hasProperty                 word.predicate:faithful
# 357  AbbeyGrange:297   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 362  AbbeyGrange:298   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 264  AbbeyGrange:281      kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 255  AbbeyGrange:279      kgc:subject                 AbbeyGrange:Jack_Croker
# 367  AbbeyGrange:299   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 380  AbbeyGrange:301      kgc:subject             AbbeyGrange:Stanley_Hopkins
# 351  AbbeyGrange:296         kgc:what                       AbbeyGrange:cache
# 373  AbbeyGrange:300      kgc:subject             AbbeyGrange:Stanley_Hopkins
# 416  AbbeyGrange:308  kgc:hasProperty                    word.predicate:manly
# 393  AbbeyGrange:303      kgc:subject                    AbbeyGrange:Blinding
# 422  AbbeyGrange:310      kgc:subject                 AbbeyGrange:Jack_Croker
# 268  AbbeyGrange:282      kgc:subject                 AbbeyGrange:Jack_Croker
# 234  AbbeyGrange:274         kgc:time            DateTime:1897-02-01T12:00:00
# 283  AbbeyGrange:285         kgc:what                 AbbeyGrange:information
#
#      atten_from427
# 262       0.011688
# 415       0.010898
# 384       0.010354
# 418       0.009816
# 322       0.009272
# 273       0.009027
# 357       0.008215
# 362       0.008213
# 264       0.007971
# 255       0.007938
# 367       0.007814
# 380       0.007747
# 351       0.007702
# 373       0.007633
# 416       0.007594
# 393       0.007493
# 422       0.007236
# 268       0.007167
# 234       0.007141
# 283       0.007043
# ----------
# 428
# ['mask_e', 'kgc:whom', 'AbbeyGrange:Sir_Eustace_Brackenstall']
#                 head         relation                                    tail  \
# 357  AbbeyGrange:297   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 352  AbbeyGrange:296   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 367  AbbeyGrange:299   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 362  AbbeyGrange:298   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 338  AbbeyGrange:293   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 347  AbbeyGrange:295   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 364  AbbeyGrange:299      kgc:subject                    AbbeyGrange:Criminal
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 388  AbbeyGrange:302   kgc:infoSource             AbbeyGrange:Stanley_Hopkins
# 342  AbbeyGrange:294   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 269  AbbeyGrange:282  kgc:hasProperty                word.predicate:inpatient
# 410  AbbeyGrange:307      kgc:subject                         AllTitle:Watson
# 172  AbbeyGrange:263  kgc:hasProperty                   word.predicate:freeze
# 265  AbbeyGrange:281  kgc:hasProperty                 word.predicate:Reckless
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 359  AbbeyGrange:298      kgc:subject                    AbbeyGrange:Criminal
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 158  AbbeyGrange:260      kgc:subject           AbbeyGrange:Lady_Brackenstall
# 354  AbbeyGrange:297      kgc:subject                    AbbeyGrange:Criminal
# 405  AbbeyGrange:306      kgc:subject             AbbeyGrange:Stanley_Hopkins
#
#      atten_from428
# 357       0.021560
# 352       0.017744
# 367       0.016604
# 362       0.016199
# 338       0.015454
# 347       0.013703
# 364       0.012179
# 418       0.012014
# 388       0.011066
# 342       0.010780
# 269       0.010669
# 410       0.010473
# 172       0.010195
# 265       0.009449
# 384       0.008484
# 359       0.008320
# 415       0.008068
# 158       0.008038
# 354       0.007683
# 405       0.007668
# ----------
# 429
# ['mask_e', 'kgc:subject', 'mask_e']
#                 head        relation                                    tail  \
# 352  AbbeyGrange:296  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 357  AbbeyGrange:297  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 338  AbbeyGrange:293  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 158  AbbeyGrange:260     kgc:subject           AbbeyGrange:Lady_Brackenstall
# 347  AbbeyGrange:295  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 367  AbbeyGrange:299  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 362  AbbeyGrange:298  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 364  AbbeyGrange:299     kgc:subject                    AbbeyGrange:Criminal
# 410  AbbeyGrange:307     kgc:subject                         AllTitle:Watson
# 384  AbbeyGrange:302     kgc:subject                      AbbeyGrange:police
# 342  AbbeyGrange:294  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 418  AbbeyGrange:309     kgc:subject                 AbbeyGrange:Jack_Croker
# 335  AbbeyGrange:293     kgc:subject                    AbbeyGrange:Criminal
# 260  AbbeyGrange:280     kgc:subject                 AbbeyGrange:Jack_Croker
# 354  AbbeyGrange:297     kgc:subject                    AbbeyGrange:Criminal
# 349  AbbeyGrange:296     kgc:subject               AbbeyGrange:Holes_of_pond
# 340  AbbeyGrange:294     kgc:subject                    AbbeyGrange:Criminal
# 359  AbbeyGrange:298     kgc:subject                    AbbeyGrange:Criminal
# 388  AbbeyGrange:302  kgc:infoSource             AbbeyGrange:Stanley_Hopkins
# 408  AbbeyGrange:306  kgc:infoSource                         AllTitle:Holmes
#
#      atten_from429
# 352       0.018065
# 357       0.017556
# 338       0.017185
# 158       0.013733
# 347       0.013274
# 367       0.012979
# 362       0.012549
# 364       0.012431
# 410       0.012094
# 384       0.011613
# 342       0.011396
# 418       0.010807
# 335       0.010502
# 260       0.009827
# 354       0.009632
# 349       0.009593
# 340       0.009246
# 359       0.009168
# 388       0.009032
# 408       0.008803
# ----------
# 430
# ['mask_e', 'kgc:why', 'mask_e']
#                 head        relation                                    tail  \
# 415  AbbeyGrange:308     kgc:subject                 AbbeyGrange:Jack_Croker
# 407  AbbeyGrange:306        kgc:what            AbbeyGrange:Private_decision
# 418  AbbeyGrange:309     kgc:subject                 AbbeyGrange:Jack_Croker
# 262  AbbeyGrange:280        kgc:what                        AbbeyGrange:ship
# 255  AbbeyGrange:279     kgc:subject                 AbbeyGrange:Jack_Croker
# 357  AbbeyGrange:297  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 349  AbbeyGrange:296     kgc:subject               AbbeyGrange:Holes_of_pond
# 352  AbbeyGrange:296  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 264  AbbeyGrange:281     kgc:subject  AbbeyGrange:Personality_of_Jack_Croker
# 367  AbbeyGrange:299  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 234  AbbeyGrange:274        kgc:time            DateTime:1897-02-01T12:00:00
# 338  AbbeyGrange:293  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 260  AbbeyGrange:280     kgc:subject                 AbbeyGrange:Jack_Croker
# 405  AbbeyGrange:306     kgc:subject             AbbeyGrange:Stanley_Hopkins
# 268  AbbeyGrange:282     kgc:subject                 AbbeyGrange:Jack_Croker
# 410  AbbeyGrange:307     kgc:subject                         AllTitle:Watson
# 322  AbbeyGrange:291        kgc:what                         AbbeyGrange:290
# 258  AbbeyGrange:279       kgc:where                    AbbeyGrange:any_ship
# 408  AbbeyGrange:306  kgc:infoSource                         AllTitle:Holmes
# 370  AbbeyGrange:299        kgc:time            DateTime:1897-03-01T12:00:00
#
#      atten_from430
# 415       0.011876
# 407       0.011112
# 418       0.009380
# 262       0.008593
# 255       0.008427
# 357       0.008398
# 349       0.008377
# 352       0.008145
# 264       0.007964
# 367       0.007809
# 234       0.007807
# 338       0.007675
# 260       0.007582
# 405       0.007101
# 268       0.006821
# 410       0.006717
# 322       0.006672
# 258       0.006496
# 408       0.006331
# 370       0.006266
# ----------
# 431
# ['mask_e', 'kgc:what', 'mask_e']
#                 head         relation                                    tail  \
# 415  AbbeyGrange:308      kgc:subject                 AbbeyGrange:Jack_Croker
# 418  AbbeyGrange:309      kgc:subject                 AbbeyGrange:Jack_Croker
# 338  AbbeyGrange:293   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 262  AbbeyGrange:280         kgc:what                        AbbeyGrange:ship
# 352  AbbeyGrange:296   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 357  AbbeyGrange:297   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 347  AbbeyGrange:295   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 172  AbbeyGrange:263  kgc:hasProperty                   word.predicate:freeze
# 342  AbbeyGrange:294   kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 260  AbbeyGrange:280      kgc:subject                 AbbeyGrange:Jack_Croker
# 386  AbbeyGrange:302         kgc:whom   AbbeyGrange:Burglary_team_of_Lewisham
# 384  AbbeyGrange:302      kgc:subject                      AbbeyGrange:police
# 370  AbbeyGrange:299         kgc:time            DateTime:1897-03-01T12:00:00
# 410  AbbeyGrange:307      kgc:subject                         AllTitle:Watson
# 407  AbbeyGrange:306         kgc:what            AbbeyGrange:Private_decision
# 387  AbbeyGrange:302        kgc:where                    AbbeyGrange:New_York
# 234  AbbeyGrange:274         kgc:time            DateTime:1897-02-01T12:00:00
# 367  AbbeyGrange:299   kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 337  AbbeyGrange:293         kgc:what             AbbeyGrange:Silver_products
# 431           mask_e         kgc:what                                  mask_e
#
#      atten_from431
# 415       0.010982
# 418       0.009369
# 338       0.008800
# 262       0.008538
# 352       0.008444
# 357       0.008245
# 347       0.007520
# 172       0.007408
# 342       0.007341
# 260       0.007047
# 386       0.006872
# 384       0.006816
# 370       0.006752
# 410       0.006750
# 407       0.006673
# 387       0.006515
# 234       0.006374
# 367       0.006056
# 337       0.005866
# 431       0.005670
# ----------
# 432
# ['mask_e', 'kgc:where', 'mask_e']
#                  head        relation                                    tail  \
# 357   AbbeyGrange:297  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 352   AbbeyGrange:296  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 367   AbbeyGrange:299  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 338   AbbeyGrange:293  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 262   AbbeyGrange:280        kgc:what                        AbbeyGrange:ship
# 362   AbbeyGrange:298  kgc:infoSource  AbbeyGrange:Thought_of_Stanley_Hopkins
# 342   AbbeyGrange:294  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 283   AbbeyGrange:285        kgc:what                 AbbeyGrange:information
# 347   AbbeyGrange:295  kgc:infoSource           AbbeyGrange:Thought_of_Holmes
# 388   AbbeyGrange:302  kgc:infoSource             AbbeyGrange:Stanley_Hopkins
# 349   AbbeyGrange:296     kgc:subject               AbbeyGrange:Holes_of_pond
# 279   AbbeyGrange:284       kgc:where                 AbbeyGrange:Southampton
# 318   AbbeyGrange:290  kgc:infoSource             AbbeyGrange:Stanley_Hopkins
# 278   AbbeyGrange:284       kgc:where                    AbbeyGrange:Adelaide
# 234   AbbeyGrange:274        kgc:time            DateTime:1897-02-01T12:00:00
# 415   AbbeyGrange:308     kgc:subject                 AbbeyGrange:Jack_Croker
# 161   AbbeyGrange:260  kgc:infoSource           AbbeyGrange:Lady_Brackenstall
# 407   AbbeyGrange:306        kgc:what            AbbeyGrange:Private_decision
# 333  AbbeyGrange:292a  kgc:infoSource                         AllTitle:Holmes
# 418   AbbeyGrange:309     kgc:subject                 AbbeyGrange:Jack_Croker
#
#      atten_from432
# 357       0.015959
# 352       0.015557
# 367       0.014901
# 338       0.012754
# 262       0.010089
# 362       0.009810
# 342       0.009537
# 283       0.009527
# 347       0.009454
# 388       0.008569
# 349       0.008287
# 279       0.007942
# 318       0.007772
# 278       0.007646
# 234       0.007615
# 415       0.007470
# 161       0.007173
# 407       0.007090
# 333       0.007041
# 418       0.006948
# ----------
